# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate, Layer, Dropout, Reshape, GlobalAveragePooling1D, GlobalMaxPooling1D, Add
from tensorflow.keras.models import Model
from tensorflow import keras
from transformers import TFBertModel, AutoTokenizer
import tensorflow.keras.backend as K

# Document processing imports
from docx import Document
from PyPDF2 import PdfReader
import textract
import json
from pprint import pprint

# System and utility imports
import os
import subprocess
import chardet
import time
# Out:
# 2024-08-03 19:35:59.869618: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-03 19:36:00.696890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# File Paths
tfrecord_file = '/home/vignes/Patent_Files/tfrecords/Dataset_json.tfrecord'
patent_folder = '/home/vignes/Patent_Files/zip-Patents/'
standard_folder = '/home/vignes/Patent_Files/Mount_Std/'

# %%
def extract_patent_text(patent_file):
    patent_text = ""
    json_file = patent_file + ".json"
    if os.path.isfile(json_file):
        try:
            with open(json_file, 'r', encoding='utf-8') as file:
                data = json.load(file)
                # print(f"Type of data in {json_file}: {type(data)}")
                if isinstance(data, dict):
                    if 'text' in data:
                        patent_text = data['text']
                    else:
                        print(f"Available keys in {json_file}: {data.keys()}")
                elif isinstance(data, list):
                    print(f"Data is a list with {len(data)} items")
                    if len(data) > 0:
                        print(f"Type of first item: {type(data[0])}")
                elif isinstance(data, str):
                    print(f"Data is a string of length {len(data)}")
                    patent_text = data
                else:
                    print(f"Unexpected data type in {json_file}: {type(data)}")
        except json.JSONDecodeError as e:
            print(f"JSON decoding error in {json_file}: {e}")
        except Exception as e:
            print(f"Error reading {json_file}: {e}")
    else:
        print(f"File not found: {json_file}")
    
    return patent_text

def extract_docx_text(docx_file):
    try:
        doc = Document(docx_file)
        return '\n'.join([paragraph.text for paragraph in doc.paragraphs])
    except Exception as e:
        print(f"Exception during DOCX text extraction: {e}")
    return ""

def extract_doc_text(doc_file):
    try:
        command = f"antiword '{doc_file}'"
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        if result.returncode == 0:
            return result.stdout
        else:
            raise Exception(f"antiword failed: {result.stderr}")
    except Exception as e:
        print(f"Exception during DOC text extraction: {e}")
    return ""

def extract_text(file_path):
    if file_path.endswith('.docx'):
        return extract_docx_text(file_path)
    elif file_path.endswith('.doc'):
        return extract_doc_text(file_path)
    else:
        return ""

def ensure_directory_path(directory_path):
    if not directory_path.endswith('/'):
        directory_path += '/'
    return directory_path

def extract_standard_text(standard_dir):
    standard_text = ""
    standard_dir = ensure_directory_path(os.path.splitext(standard_dir)[0])  # Remove the .zip extension
    if os.path.exists(standard_dir):
        for root, _, files in os.walk(standard_dir):
            for file in files:
                file_path = os.path.join(root, file)
                text = extract_text(file_path)
                standard_text += text + "\n"
    else:
        print(f"Standard directory {standard_dir} does not exist.")
    return standard_text

# %%
bert_model_name = 'bert-base-uncased'
bert_model = TFBertModel.from_pretrained(bert_model_name)
tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
# Out:
# 2024-08-03 19:36:04.628182: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.629233: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.631191: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.632148: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.632951: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.633912: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.970184: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.971180: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.971999: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.972952: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.975694: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:04.976643: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.013637: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.016083: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.016944: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.017954: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.018832: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.019780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# 2024-08-03 19:36:05.020446: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-03 19:36:05.021238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10522 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:44:00.0, compute capability: 6.1
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
def parse_tfrecord(example):
    feature_description = {
        'patent': tf.io.FixedLenFeature([], tf.string),
        'standard': tf.io.FixedLenFeature([], tf.string),
        'match': tf.io.FixedLenFeature([], tf.int64),
    }
    example = tf.io.parse_single_example(example, feature_description)
    return example['patent'], example['standard'], example['match']

# Load the TFRecord dataset
dataset = tf.data.TFRecordDataset(tfrecord_file)
parsed_dataset = dataset.map(parse_tfrecord)

# %%
num_samples = 0
for _ in parsed_dataset:
    num_samples += 1
print(f"Total number of samples in the dataset: {num_samples}")

# Define ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate sizes
train_size = int(train_ratio * num_samples)
val_size = int(val_ratio * num_samples)
test_size = num_samples - train_size - val_size  # Ensure we use all remaining samples

print(f"Number of samples in the training set: {train_size}")
print(f"Number of samples in the validation set: {val_size}")
print(f"Number of samples in the test set: {test_size}")

# Split the dataset into training and validation sets
train_dataset = parsed_dataset.take(train_size)
val_dataset = parsed_dataset.take(val_size)
test_dataset = parsed_dataset.take(test_size)
# Out:
# Total number of samples in the dataset: 130476
# Number of samples in the training set: 91333
# Number of samples in the validation set: 19571
# Number of samples in the test set: 19572
# 2024-08-03 19:36:24.582992: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def chunk_text(text, max_length):
    words = text.split()
    chunks = []
    for i in range(0, len(words), max_length):
        chunk = words[i:i + max_length]
        chunk = chunk + [''] * (max_length - len(chunk))  # Pad with empty strings
        chunks.append(' '.join(chunk))
    return chunks

# %%
max_length = 100
def data_generator(dataset, tokenizer, max_length=100, max_chunks=10):
    for patent, standard, match in dataset:
        patent_text = extract_patent_text(os.path.join(patent_folder, patent.numpy().decode()))
        standard_text = extract_standard_text(os.path.join(standard_folder, standard.numpy().decode()))

        if not patent_text.strip() or not standard_text.strip():
            print(f"\nSkipping sample: {patent.numpy().decode()},Standard={standard.numpy().decode()}die to empty text.")
            continue 
        
        patent_chunks = chunk_text(patent_text, max_length)
        standard_chunks = chunk_text(standard_text, max_length)

        if not patent_chunks or not standard_chunks:
            print(f"\nSkipping sample: Patent={patent.numpy().decode()}, Standard={standard.numpy().decode()} due to empty chunks.")
            continue
        
        patent_inputs = tokenizer(patent_chunks, padding=True, truncation=True, return_tensors='tf', max_length=max_length)
        standard_inputs = tokenizer(standard_chunks, padding=True, truncation=True, return_tensors='tf', max_length=max_length)
        
        patent_input_ids = patent_inputs['input_ids']
        patent_attention_mask = patent_inputs['attention_mask']
        standard_input_ids = standard_inputs['input_ids']
        standard_attention_mask = standard_inputs['attention_mask']
        
        patent_input_ids = patent_input_ids[:max_chunks]
        patent_attention_mask = patent_attention_mask[:max_chunks]
        standard_input_ids = standard_input_ids[:max_chunks]
        standard_attention_mask = standard_attention_mask[:max_chunks]
        
        patent_input_ids = tf.pad(patent_input_ids, [[0, max_chunks - tf.shape(patent_input_ids)[0]], [0, 0]], constant_values=0)
        patent_attention_mask = tf.pad(patent_attention_mask, [[0, max_chunks - tf.shape(patent_attention_mask)[0]], [0, 0]], constant_values=0)
        standard_input_ids = tf.pad(standard_input_ids, [[0, max_chunks - tf.shape(standard_input_ids)[0]], [0, 0]], constant_values=0)
        standard_attention_mask = tf.pad(standard_attention_mask, [[0, max_chunks - tf.shape(standard_attention_mask)[0]], [0, 0]], constant_values=0)
        
        # print("Patent input IDs shape:", patent_input_ids.shape)
        # print("Patent attention mask shape:", patent_attention_mask.shape)
        # print("Standard input IDs shape:", standard_input_ids.shape)
        # print("Standard attention mask shape:", standard_attention_mask.shape)
        # print("Match value:", match.numpy())
        # print("---")
        
        yield (
            {
                'patent_input_ids': tf.reshape(patent_input_ids, [1, max_chunks * max_length]),
                'patent_attention_mask': tf.reshape(patent_attention_mask, [1, max_chunks * max_length]),
                'standard_input_ids': tf.reshape(standard_input_ids, [1, max_chunks * max_length]),
                'standard_attention_mask': tf.reshape(standard_attention_mask, [1, max_chunks * max_length])
            },
            tf.reshape(tf.constant(match, dtype=tf.int64), [1])
        )

max_chunks = 50# Define the max_chunks variable
batch_size= 2
train_tf_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(train_dataset, tokenizer, max_length=100, max_chunks=max_chunks),
    output_signature=(
        {
            'patent_input_ids': tf.TensorSpec(shape=(1, max_chunks*max_length), dtype=tf.int32),
            'patent_attention_mask': tf.TensorSpec(shape=(1,max_chunks*max_length), dtype=tf.int32),
            'standard_input_ids': tf.TensorSpec(shape=(1,max_chunks*max_length), dtype=tf.int32),
            'standard_attention_mask': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
        },
        tf.TensorSpec(shape=(1,), dtype=tf.int32)
    )
).batch(batch_size)

val_tf_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(val_dataset, tokenizer, max_length=100, max_chunks=max_chunks),
    output_signature=(
        {
            'patent_input_ids': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
            'patent_attention_mask': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
            'standard_input_ids': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
            'standard_attention_mask': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
        },
        tf.TensorSpec(shape=(1,), dtype=tf.int32)
    )
).batch(batch_size)

test_tf_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(test_dataset, tokenizer, max_length = 100, max_chunks= max_chunks),
    output_signature = (
        {
            'patent_input_ids' : tf.TensorSpec(shape=(1, max_chunks * max_length), dtype = tf.int32),
            'patent_attention_mask' : tf.TensorSpec(shape =(1, max_chunks * max_length), dtype = tf.int32), 
            'standard_input_ids' : tf.TensorSpec(shape=(1,max_chunks*max_length), dtype = tf.int32),
            'standard_attention_mask': tf.TensorSpec(shape = (1, max_chunks * max_length), dtype= tf.int32),
        },
        tf.TensorSpec(shape=(1,),dtype= tf.int32)
    )
).batch(batch_size)

# %%
class BertModelLayer(keras.layers.Layer):
    def __init__(self, bert_model, **kwargs):
        super(BertModelLayer, self).__init__(**kwargs)
        self.bert_model = bert_model

    def call(self, inputs):
        input_ids, attention_mask = inputs
        input_ids = tf.cast(input_ids, tf.int32)  # Cast input_ids to int32
        attention_mask = tf.cast(attention_mask, tf.int32)  # Cast attention_mask to int32
        outputs = self.bert_model(input_ids, attention_mask=attention_mask)
        return outputs.last_hidden_state

    def get_config(self):
        base_config = super(BertModelLayer, self).get_config()
        config = {
            "bert_model": tf.keras.legacy.saving.serialize_keras_object(self.bert_model),
        }
        return {**base_config, **config}

    @classmethod
    def from_config(cls, config):
        bert_model_config = config.pop("bert_model")
        bert_model = keras.saving.deserialize_keras_object(bert_model_config)
        return cls(bert_model=bert_model, **config)

class ReshapeLayer(Layer):
    def __init__(self, target_shape, **kwargs):
        super(ReshapeLayer, self).__init__(**kwargs)
        self.target_shape = target_shape

    def call(self, inputs):
        return tf.reshape(inputs, shape=self.target_shape)

class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                                 initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1),
                                 initializer="zeros")
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = K.squeeze(K.tanh(K.dot(x, self.W) + self.b), axis=-1)
        at = K.softmax(et)
        at = K.expand_dims(at, axis=-1)
        output = x * at
        return K.sum(output, axis=1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[-1])

class CrossAttention(Layer):
    def __init__(self, **kwargs):
        super(CrossAttention, self).__init__(**kwargs)

    def call(self, inputs):
        query, key, value = inputs
        attention_scores = tf.matmul(query, key, transpose_b=True)
        attention_scores = tf.nn.softmax(attention_scores, axis=-1)
        return tf.matmul(attention_scores, value)

# def cross_attention(query, key, value):
#     attention_scores = tf.matmul(query, key, transpose_b=True)
#     attention_scores = tf.nn.softmax(attention_scores, axis=-1)
#     return tf.matmul(attention_scores, value)

class ResidualBlock(Layer):
    def __init__(self, units, **kwargs):
        super(ResidualBlock, self).__init__(**kwargs)
        self.units = units
        self.dense1 = Dense(units, activation='relu')
        self.dense2 = Dense(units, activation='linear')

    def build(self, input_shape):
        self.dense2 = Dense(input_shape[-1], activation='linear')
        super(ResidualBlock, self).build(input_shape)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return Add()([inputs, x])

    def get_config(self):
        config = super(ResidualBlock, self).get_config()
        config.update({"units": self.units})
        return config
        
def create_model(max_length, max_chunks):
    # Input layers
    patent_input_ids = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='patent_input_ids')
    patent_attention_mask = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='patent_attention_mask')
    standard_input_ids = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='standard_input_ids')
    standard_attention_mask = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='standard_attention_mask')

    # Reshape layers
    reshape_layer = ReshapeLayer(target_shape=(-1, max_chunks*max_length))
    patent_input_ids_reshaped = reshape_layer(patent_input_ids)
    patent_attention_mask_reshaped = reshape_layer(patent_attention_mask)
    standard_input_ids_reshaped = reshape_layer(standard_input_ids)
    standard_attention_mask_reshaped = reshape_layer(standard_attention_mask)

    # BERT layers
    patent_bert = BertModelLayer(TFBertModel.from_pretrained('bert-base-uncased'), trainable=True)
    standard_bert = BertModelLayer(TFBertModel.from_pretrained('bert-base-uncased'), trainable=True)

    # BERT embeddings
    patent_embeddings = patent_bert([patent_input_ids_reshaped, patent_attention_mask_reshaped])
    standard_embeddings = standard_bert([standard_input_ids_reshaped, standard_attention_mask_reshaped])

    # Cross-attention
    cross_attention_layer = CrossAttention()
    patent_cross = cross_attention_layer([patent_embeddings, standard_embeddings, standard_embeddings])
    standard_cross = cross_attention_layer([standard_embeddings, patent_embeddings, patent_embeddings])

    patent_combined = Concatenate()([patent_embeddings, patent_cross])
    standard_combined = Concatenate()([standard_embeddings, standard_cross])

    # Pooling
    patent_max_pooled = GlobalMaxPooling1D()(patent_combined)
    patent_avg_pooled = GlobalAveragePooling1D()(patent_combined)
    patent_attention = AttentionLayer()(patent_combined)
    patent_pooled = Concatenate()([patent_max_pooled, patent_avg_pooled, patent_attention])

    standard_max_pooled = GlobalMaxPooling1D()(standard_combined)
    standard_avg_pooled = GlobalAveragePooling1D()(standard_combined)
    standard_attention = AttentionLayer()(standard_combined)
    standard_pooled = Concatenate()([standard_max_pooled, standard_avg_pooled, standard_attention])

    # Concatenate pooled outputs
    concatenated = Concatenate()([patent_pooled, standard_pooled])

    # Dense layers with residual connections
    x = Dense(1024, activation='relu')(concatenated)
    x = ResidualBlock(512)(x)
    x = Dropout(0.5)(x)
    x = ResidualBlock(256)(x)
    x = Dropout(0.5)(x)
    x = ResidualBlock(128)(x)
    x = Dropout(0.5)(x)

    # Final dense layers
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    # Model
    model = Model(inputs=[patent_input_ids, patent_attention_mask, standard_input_ids, standard_attention_mask], outputs=output)

    return model

# Create and compile the model
model = create_model(max_length, max_chunks)

initial_learning_rate = 0.001  # Assuming this was your initial rate
new_learning_rate = initial_learning_rate * 2  # Double it

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    new_learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
num_epochs=2

# Create a directory for saving models if it doesn't exist
model_dir = 'saved_models_BERTcomplex'
os.makedirs(model_dir, exist_ok=True)

# Define a custom callback for periodic saving
class PeriodicSaver(tf.keras.callbacks.Callback):
    def __init__(self, save_freq=300, save_path='saved_models_BERTcomplex'):
        super(PeriodicSaver, self).__init__()
        self.save_freq = save_freq  # Save frequency in seconds
        self.save_path = save_path
        self.last_save_time = time.time()

    def on_batch_end(self, batch, logs=None):
        if time.time() - self.last_save_time > self.save_freq:
            print("\nSaving periodic model checkpoint...")
            self.model.save(os.path.join(self.save_path, f'periodic_model_{int(time.time())}.keras'))
            self.last_save_time = time.time()

# Define the callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(model_dir, 'model.{epoch:02d}--{val_loss:.2f}.keras'), 
        monitor='val_accuracy', 
        save_best_only=True
    ),
    PeriodicSaver(save_freq=300, save_path=model_dir)  # Save every 5 minutes
]

final_model_path = None # Initialize the variable

try:
    # Start training
    model.fit(train_tf_dataset,
              epochs=num_epochs,
              callbacks=callbacks,
              validation_data=val_tf_dataset)

    # If training completes successfully, save the final model
    final_model_path = os.path.join(model_dir, 'final_model.keras')
    model.save(final_model_path)
    print("Training completed. Final model saved.")

except Exception as e:
    print(f"An error occurred during training: {e}")
    # The last periodic save will be the most recent model state
    periodic_saves = [f for f in os.listdir(model_dir) if f.startswith('periodic_model_')]
    if periodic_saves:
        latest_save = max(periodic_saves, key=lambda x: int(x.split('_')[2].split('.')[0]))
        final_model_path = os.path.join(model_dir, latest_save)
        print(f"Using the most recent periodic save: {final_model_path}")
    else:
        print("No periodic saves found. Unable to evaluate the model.")

finally:
    # This block will be executed whether there's an exception or not
    print("Training process finished.")
# Out:
# Epoch 1/2
# Data is a string of length 74466
# Data is a string of length 70203
# Data is a string of length 66217
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722728231.043387 2293736 service.cc:145] XLA service 0x2bf85930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1722728231.043438 2293736 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# I0000 00:00:1722728231.043443 2293736 service.cc:153]   StreamExecutor device (1): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# Data is a string of length 41435
# 2024-08-03 19:37:12.291046: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1722728232.847978 2293736 assert_op.cc:38] Ignoring Assert operator functional_1_1/bert_model_layer_1_1/tf_bert_model_2/bert/embeddings/assert_less/Assert/Assert
# W0000 00:00:1722728232.852398 2293736 assert_op.cc:38] Ignoring Assert operator functional_1_1/bert_model_layer_2/tf_bert_model_1/bert/embeddings/assert_less/Assert/Assert
# 2024-08-03 19:37:17.177609: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# I0000 00:00:1722728252.396650 2293736 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#       1/Unknown 47s 47s/step - accuracy: 0.0000e+00 - loss: 5.7392Data is a string of length 79689
#       2/Unknown 49s 2s/step - accuracy: 0.0000e+00 - loss: 7.5344 Data is a string of length 116738
# Data is a string of length 76258
#       3/Unknown 54s 3s/step - accuracy: 0.0556 - loss: 9.0320    Data is a string of length 92048
# Data is a string of length 99918
#       4/Unknown 57s 3s/step - accuracy: 0.1354 - loss: 9.0291Data is a string of length 115843
# Data is a string of length 80657
# Data is a string of length 119004
#       5/Unknown 60s 3s/step - accuracy: 0.1883 - loss: 28.4280Data is a string of length 232200
#       6/Unknown 64s 3s/step - accuracy: 0.2403 - loss: 38.4155Data is a string of length 51929
# Data is a string of length 103652
# Data is a string of length 49709
#       7/Unknown 66s 3s/step - accuracy: 0.2774 - loss: 46.8673Data is a string of length 58826
#       8/Unknown 69s 3s/step - accuracy: 0.3052 - loss: 55.7997Data is a string of length 105344
# Data is a string of length 76603
#       9/Unknown 71s 3s/step - accuracy: 0.3207 - loss: 66.1535Data is a string of length 92526
# Data is a string of length 100970
#      10/Unknown 75s 3s/step - accuracy: 0.3336 - loss: 73.5187Data is a string of length 135458
# Data is a string of length 64801
# Data is a string of length 151481
#      11/Unknown 79s 3s/step - accuracy: 0.3405 - loss: 79.2909Data is a string of length 270921
#      12/Unknown 81s 3s/step - accuracy: 0.3468 - loss: 83.2257Data is a string of length 68232
# Data is a string of length 78184
# Data is a string of length 210126
#      13/Unknown 85s 3s/step - accuracy: 0.3527 - loss: 85.8628Data is a string of length 27003
#      14/Unknown 88s 3s/step - accuracy: 0.3607 - loss: 87.5236
# Data is a string of length 56269
#      15/Unknown 91s 3s/step - accuracy: 0.3677 - loss: 89.6797Data is a string of length 141340
# Data is a string of length 40485
#      16/Unknown 94s 3s/step - accuracy: 0.3721 - loss: 94.4214Data is a string of length 159294
# Data is a string of length 118542
#      17/Unknown 96s 3s/step - accuracy: 0.3779 - loss: 98.0325Data is a string of length 81980
# Data is a string of length 95065
# Data is a string of length 74770
#      18/Unknown 101s 3s/step - accuracy: 0.3831 - loss: 101.0429Data is a string of length 85396
# Data is a string of length 49395
#      19/Unknown 103s 3s/step - accuracy: 0.3879 - loss: 103.3232Data is a string of length 120063
#      20/Unknown 107s 3s/step - accuracy: 0.3935 - loss: 105.0145Data is a string of length 47647
# Data is a string of length 204205
#      21/Unknown 110s 3s/step - accuracy: 0.3986 - loss: 106.5243Data is a string of length 26553
# Data is a string of length 102862
#      22/Unknown 114s 3s/step - accuracy: 0.4032 - loss: 107.7599Data is a string of length 46405
# Data is a string of length 263700
# Data is a string of length 113716
#      23/Unknown 117s 3s/step - accuracy: 0.4064 - loss: 108.8205Data is a string of length 48403
#      24/Unknown 119s 3s/step - accuracy: 0.4103 - loss: 109.5632Data is a string of length 43636
# Data is a string of length 159685
# Data is a string of length 52907
#      25/Unknown 121s 3s/step - accuracy: 0.4139 - loss: 110.0655Data is a string of length 115043
#      26/Unknown 129s 3s/step - accuracy: 0.4172 - loss: 110.4034Data is a string of length 83637
# Data is a string of length 38241
#      27/Unknown 131s 3s/step - accuracy: 0.4203 - loss: 110.6748Data is a string of length 65630
# Data is a string of length 113073
#      28/Unknown 135s 3s/step - accuracy: 0.4225 - loss: 110.8045Data is a string of length 65687
# Data is a string of length 39265
#      29/Unknown 138s 3s/step - accuracy: 0.4246 - loss: 110.7974Data is a string of length 120017
# Data is a string of length 196945
#      30/Unknown 142s 3s/step - accuracy: 0.4260 - loss: 110.7521Data is a string of length 120977
# Data is a string of length 111020
#      31/Unknown 144s 3s/step - accuracy: 0.4273 - loss: 110.6697Data is a string of length 94164
# Data is a string of length 71174
# Data is a string of length 47236
#      32/Unknown 148s 3s/step - accuracy: 0.4286 - loss: 110.5124Data is a string of length 62986
#      33/Unknown 150s 3s/step - accuracy: 0.4299 - loss: 110.2957
# Data is a string of length 79923
#      34/Unknown 153s 3s/step - accuracy: 0.4311 - loss: 110.1007Data is a string of length 53258
# Data is a string of length 99229
# Data is a string of length 113391
#      35/Unknown 157s 3s/step - accuracy: 0.4326 - loss: 109.8321Data is a string of length 64778
# Data is a string of length 259878
#      36/Unknown 161s 3s/step - accuracy: 0.4341 - loss: 109.5097Data is a string of length 92031
#      37/Unknown 163s 3s/step - accuracy: 0.4359 - loss: 109.1330Data is a string of length 46641
# Data is a string of length 68288
#      38/Unknown 166s 3s/step - accuracy: 0.4376 - loss: 108.7114Data is a string of length 58253
# Data is a string of length 206720
#      39/Unknown 173s 3s/step - accuracy: 0.4389 - loss: 108.2733Data is a string of length 92500
# Data is a string of length 116428
# Data is a string of length 91933
#      40/Unknown 176s 3s/step - accuracy: 0.4401 - loss: 107.8040Data is a string of length 68527
#      41/Unknown 179s 3s/step - accuracy: 0.4415 - loss: 107.3043Data is a string of length 160835
# Data is a string of length 103807
#      42/Unknown 182s 3s/step - accuracy: 0.4426 - loss: 106.8094Data is a string of length 82254
# Data is a string of length 81002
#      43/Unknown 185s 3s/step - accuracy: 0.4437 - loss: 106.2953Data is a string of length 133188
# Data is a string of length 113615
# Data is a string of length 49457
#      44/Unknown 187s 3s/step - accuracy: 0.4447 - loss: 105.7713Data is a string of length 87575
# Data is a string of length 106844
#      45/Unknown 191s 3s/step - accuracy: 0.4457 - loss: 105.2339Data is a string of length 100206
#      46/Unknown 198s 3s/step - accuracy: 0.4469 - loss: 104.6814Data is a string of length 98595
# Data is a string of length 65875
#      47/Unknown 202s 3s/step - accuracy: 0.4480 - loss: 104.1521Data is a string of length 28222
# Data is a string of length 55868
# Data is a string of length 41938
#      48/Unknown 204s 3s/step - accuracy: 0.4491 - loss: 103.6205Data is a string of length 61754
#      49/Unknown 207s 3s/step - accuracy: 0.4501 - loss: 103.1387Data is a string of length 71730
# Data is a string of length 157618
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2003072290 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 68686
#      50/Unknown 210s 3s/step - accuracy: 0.4511 - loss: 102.6562Data is a string of length 82213
# Data is a string of length 61142
#      51/Unknown 214s 3s/step - accuracy: 0.4523 - loss: 102.1621Data is a string of length 95912
# Data is a string of length 97021
#      52/Unknown 217s 3s/step - accuracy: 0.4534 - loss: 101.6838Data is a string of length 77245
# Data is a string of length 40738
#      53/Unknown 220s 3s/step - accuracy: 0.4544 - loss: 101.1978Data is a string of length 83864
# Data is a string of length 198585
#      54/Unknown 222s 3s/step - accuracy: 0.4556 - loss: 100.7037Data is a string of length 38033
# Data is a string of length 172116
#      55/Unknown 224s 3s/step - accuracy: 0.4568 - loss: 100.2038Data is a string of length 216590
# Data is a string of length 47158
#      56/Unknown 227s 3s/step - accuracy: 0.4580 - loss: 99.6984 Data is a string of length 108502
# Data is a string of length 131347
#      57/Unknown 229s 3s/step - accuracy: 0.4592 - loss: 99.1999Data is a string of length 316083
# Data is a string of length 73366
#      58/Unknown 234s 3s/step - accuracy: 0.4604 - loss: 98.7035Data is a string of length 41987
# Data is a string of length 110803
#      59/Unknown 236s 3s/step - accuracy: 0.4616 - loss: 98.2037Data is a string of length 76058
# Data is a string of length 66684
#      60/Unknown 239s 3s/step - accuracy: 0.4627 - loss: 97.7165Data is a string of length 37180
# Data is a string of length 47645
#      61/Unknown 241s 3s/step - accuracy: 0.4636 - loss: 97.2321Data is a string of length 30413
# Data is a string of length 62496
# Data is a string of length 84860
#      62/Unknown 244s 3s/step - accuracy: 0.4645 - loss: 96.7456Data is a string of length 71580
#      63/Unknown 246s 3s/step - accuracy: 0.4656 - loss: 96.2577Data is a string of length 58752
# Data is a string of length 52048
#      64/Unknown 249s 3s/step - accuracy: 0.4666 - loss: 95.7695Data is a string of length 160925
# Data is a string of length 51937
# Data is a string of length 65591
#      65/Unknown 251s 3s/step - accuracy: 0.4676 - loss: 95.2876Data is a string of length 162861
#      66/Unknown 254s 3s/step - accuracy: 0.4684 - loss: 94.8118Data is a string of length 102211
# Data is a string of length 76482
#      67/Unknown 258s 3s/step - accuracy: 0.4693 - loss: 94.3379Data is a string of length 180994
# Data is a string of length 146310
#      68/Unknown 262s 3s/step - accuracy: 0.4700 - loss: 93.8649Data is a string of length 50196
# Data is a string of length 195677
#      69/Unknown 265s 3s/step - accuracy: 0.4708 - loss: 93.3947Data is a string of length 47980
# Data is a string of length 185625
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: CN110521146 A,Standard=TS 33.501.501die to empty text.
# Data is a string of length 96904
#      70/Unknown 267s 3s/step - accuracy: 0.4716 - loss: 92.9253Data is a string of length 43086
# Data is a string of length 173725
# Data is a string of length 69435
#      71/Unknown 270s 3s/step - accuracy: 0.4724 - loss: 92.4582Data is a string of length 91003
# Data is a string of length 103230
#      72/Unknown 273s 3s/step - accuracy: 0.4732 - loss: 91.9966Data is a string of length 46349
#      73/Unknown 277s 3s/step - accuracy: 0.4739 - loss: 91.5477Data is a string of length 57884
# Data is a string of length 83341
#      74/Unknown 280s 3s/step - accuracy: 0.4746 - loss: 91.1060Data is a string of length 95185
# Data is a string of length 67936
# Data is a string of length 123531
#      75/Unknown 284s 3s/step - accuracy: 0.4753 - loss: 90.6657Data is a string of length 68362
#      76/Unknown 288s 3s/step - accuracy: 0.4760 - loss: 90.2288Data is a string of length 103658
# Data is a string of length 92301
#      77/Unknown 290s 3s/step - accuracy: 0.4766 - loss: 89.7967Data is a string of length 84021
# Data is a string of length 86533
#      78/Unknown 293s 3s/step - accuracy: 0.4774 - loss: 89.3663Data is a string of length 118791
# Data is a string of length 53379
# Data is a string of length 93335
#      79/Unknown 296s 3s/step - accuracy: 0.4780 - loss: 88.9394Data is a string of length 90601
#      80/Unknown 299s 3s/step - accuracy: 0.4787 - loss: 88.5154Data is a string of length 73497
# Data is a string of length 33822
#
# Saving periodic model checkpoint...
# Data is a string of length 76423
# Data is a string of length 56162
#      81/Unknown 302s 3s/step - accuracy: 0.4794 - loss: 88.0959Data is a string of length 61629
#      82/Unknown 304s 3s/step - accuracy: 0.4799 - loss: 87.6813Data is a string of length 104515
# Data is a string of length 35673
#      83/Unknown 307s 3s/step - accuracy: 0.4804 - loss: 87.2706Data is a string of length 126824
#      84/Unknown 309s 3s/step - accuracy: 0.4809 - loss: 86.8644Data is a string of length 101990
# Data is a string of length 111196
#      85/Unknown 312s 3s/step - accuracy: 0.4815 - loss: 86.4605Data is a string of length 38477
# Data is a string of length 35724
# Data is a string of length 21393
#      86/Unknown 315s 3s/step - accuracy: 0.4820 - loss: 86.0629Data is a string of length 93214
#      87/Unknown 317s 3s/step - accuracy: 0.4825 - loss: 85.6707Data is a string of length 44513
# Data is a string of length 92686
# Data is a string of length 129617
#      88/Unknown 319s 3s/step - accuracy: 0.4830 - loss: 85.2808Data is a string of length 88257
# Data is a string of length 70967
#      89/Unknown 322s 3s/step - accuracy: 0.4836 - loss: 84.8931Data is a string of length 73027
#      90/Unknown 324s 3s/step - accuracy: 0.4841 - loss: 84.5108Data is a string of length 45490
# Data is a string of length 75978
#      91/Unknown 327s 3s/step - accuracy: 0.4845 - loss: 84.1323Data is a string of length 111066
# Data is a string of length 74381
#      92/Unknown 329s 3s/step - accuracy: 0.4849 - loss: 83.7563Data is a string of length 349353
# Data is a string of length 49861
#      93/Unknown 331s 3s/step - accuracy: 0.4852 - loss: 83.3850Data is a string of length 65525
# Data is a string of length 92929
#      94/Unknown 334s 3s/step - accuracy: 0.4855 - loss: 83.0161Data is a string of length 53521
# Data is a string of length 38550
#      95/Unknown 337s 3s/step - accuracy: 0.4859 - loss: 82.6503Data is a string of length 113219
# Data is a string of length 77799
# Data is a string of length 119310
#      96/Unknown 339s 3s/step - accuracy: 0.4862 - loss: 82.2868Data is a string of length 97451
#      97/Unknown 342s 3s/step - accuracy: 0.4865 - loss: 81.9270Data is a string of length 90882
# Data is a string of length 106520
#      98/Unknown 345s 3s/step - accuracy: 0.4868 - loss: 81.5704Data is a string of length 131657
# Data is a string of length 88986
#      99/Unknown 366s 3s/step - accuracy: 0.4870 - loss: 81.2163Data is a string of length 209119
# Data is a string of length 26333
#     100/Unknown 368s 3s/step - accuracy: 0.4872 - loss: 80.8646Data is a string of length 139214
# Data is a string of length 63804
#     101/Unknown 370s 3s/step - accuracy: 0.4875 - loss: 80.5155Data is a string of length 60431
# Data is a string of length 67136
#     102/Unknown 376s 3s/step - accuracy: 0.4877 - loss: 80.1705Data is a string of length 95303
# Data is a string of length 93220
# Data is a string of length 73144
#     103/Unknown 378s 3s/step - accuracy: 0.4879 - loss: 79.8284Data is a string of length 64780
#     104/Unknown 381s 3s/step - accuracy: 0.4881 - loss: 79.4890Data is a string of length 35213
# Data is a string of length 154177
#     105/Unknown 383s 3s/step - accuracy: 0.4884 - loss: 79.1522Data is a string of length 169921
# Data is a string of length 64295
# Data is a string of length 86142
#     106/Unknown 388s 3s/step - accuracy: 0.4885 - loss: 78.8181Data is a string of length 119599
#     107/Unknown 392s 3s/step - accuracy: 0.4887 - loss: 78.4880Data is a string of length 81821
# Data is a string of length 63141
#     108/Unknown 394s 3s/step - accuracy: 0.4888 - loss: 78.1603Data is a string of length 71248
# Data is a string of length 27713
#     109/Unknown 396s 3s/step - accuracy: 0.4890 - loss: 77.8350Data is a string of length 73588
# Data is a string of length 84244
# Data is a string of length 92258
#     110/Unknown 400s 3s/step - accuracy: 0.4892 - loss: 77.5122Data is a string of length 50091
#     111/Unknown 403s 3s/step - accuracy: 0.4894 - loss: 77.1919Data is a string of length 59351
# Data is a string of length 77047
#     112/Unknown 405s 3s/step - accuracy: 0.4895 - loss: 76.8739Data is a string of length 66215
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US11337228 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 146319
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US8850203 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 77140
# Data is a string of length 238754
#     113/Unknown 410s 3s/step - accuracy: 0.4897 - loss: 76.5586Data is a string of length 115650
# Data is a string of length 41056
#     114/Unknown 413s 3s/step - accuracy: 0.4899 - loss: 76.2461Data is a string of length 84692
# Data is a string of length 71638
#     115/Unknown 417s 3s/step - accuracy: 0.4901 - loss: 75.9360Data is a string of length 36852
# Data is a string of length 118853
#     116/Unknown 423s 3s/step - accuracy: 0.4902 - loss: 75.6305Data is a string of length 53044
# Data is a string of length 78365
# Data is a string of length 48155
#     117/Unknown 425s 3s/step - accuracy: 0.4904 - loss: 75.3272Data is a string of length 124137
#     118/Unknown 428s 3s/step - accuracy: 0.4906 - loss: 75.0275Data is a string of length 128846
# Data is a string of length 113760
# Data is a string of length 36400
#     119/Unknown 433s 3s/step - accuracy: 0.4907 - loss: 74.7301Data is a string of length 44125
# Data is a string of length 61187
#     120/Unknown 436s 3s/step - accuracy: 0.4909 - loss: 74.4349Data is a string of length 206348
#     121/Unknown 439s 3s/step - accuracy: 0.4910 - loss: 74.1421Data is a string of length 91440
# Data is a string of length 56821
#     122/Unknown 441s 3s/step - accuracy: 0.4912 - loss: 73.8517Data is a string of length 104863
# Data is a string of length 175965
#     123/Unknown 443s 3s/step - accuracy: 0.4913 - loss: 73.5634Data is a string of length 79150
# Data is a string of length 41422
#     124/Unknown 447s 3s/step - accuracy: 0.4914 - loss: 73.2773Data is a string of length 141380
# Data is a string of length 120276
#     125/Unknown 451s 3s/step - accuracy: 0.4916 - loss: 72.9934Data is a string of length 57544
# Data is a string of length 163950
#     126/Unknown 453s 3s/step - accuracy: 0.4918 - loss: 72.7117Data is a string of length 174624
# Data is a string of length 90490
#     127/Unknown 458s 3s/step - accuracy: 0.4919 - loss: 72.4328Data is a string of length 103570
# Data is a string of length 43917
#     128/Unknown 460s 3s/step - accuracy: 0.4921 - loss: 72.1559Data is a string of length 130750
# Data is a string of length 163523
#     129/Unknown 464s 3s/step - accuracy: 0.4922 - loss: 71.8812Data is a string of length 56461
# Data is a string of length 146179
# Data is a string of length 97627
#     130/Unknown 466s 3s/step - accuracy: 0.4925 - loss: 71.6085Data is a string of length 79202
# Data is a string of length 121329
#     131/Unknown 469s 3s/step - accuracy: 0.4927 - loss: 71.3383Data is a string of length 94794
# Data is a string of length 52352
#     132/Unknown 472s 3s/step - accuracy: 0.4929 - loss: 71.0701Data is a string of length 61498
#     133/Unknown 474s 3s/step - accuracy: 0.4931 - loss: 70.8040
# Data is a string of length 39121
#     134/Unknown 477s 3s/step - accuracy: 0.4934 - loss: 70.5400Data is a string of length 44850
# Data is a string of length 57123
#     135/Unknown 479s 3s/step - accuracy: 0.4936 - loss: 70.2781Data is a string of length 63316
# Data is a string of length 169215
#     136/Unknown 482s 3s/step - accuracy: 0.4938 - loss: 70.0182Data is a string of length 255282
# Data is a string of length 52696
#     137/Unknown 486s 3s/step - accuracy: 0.4940 - loss: 69.7605Data is a string of length 109600
# Data is a string of length 53959
#     138/Unknown 488s 3s/step - accuracy: 0.4942 - loss: 69.5047Data is a string of length 88910
# Data is a string of length 67149
#     139/Unknown 491s 3s/step - accuracy: 0.4945 - loss: 69.2508Data is a string of length 73478
# Data is a string of length 98407
#     140/Unknown 512s 3s/step - accuracy: 0.4947 - loss: 68.9989Data is a string of length 55549
# Data is a string of length 88002
# Data is a string of length 56055
#     141/Unknown 515s 3s/step - accuracy: 0.4949 - loss: 68.7490Data is a string of length 115527
#     142/Unknown 517s 3s/step - accuracy: 0.4951 - loss: 68.5011Data is a string of length 109409
# Data is a string of length 115527
# Data is a string of length 118056
#     143/Unknown 521s 3s/step - accuracy: 0.4953 - loss: 68.2550Data is a string of length 101577
# Data is a string of length 42861
#     144/Unknown 524s 3s/step - accuracy: 0.4955 - loss: 68.0111Data is a string of length 78500
# Data is a string of length 37835
#     145/Unknown 528s 3s/step - accuracy: 0.4957 - loss: 67.7689Data is a string of length 62584
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2017055152 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 100755
#     146/Unknown 530s 3s/step - accuracy: 0.4960 - loss: 67.5285Data is a string of length 69901
# Data is a string of length 125914
#     147/Unknown 535s 3s/step - accuracy: 0.4962 - loss: 67.2900Data is a string of length 35724
# Data is a string of length 82479
#     148/Unknown 537s 3s/step - accuracy: 0.4964 - loss: 67.0532Data is a string of length 368802
# Data is a string of length 129253
#     149/Unknown 540s 3s/step - accuracy: 0.4966 - loss: 66.8182Data is a string of length 38102
# Data is a string of length 36927
#     150/Unknown 547s 3s/step - accuracy: 0.4968 - loss: 66.5852Data is a string of length 74771
# Data is a string of length 54302
#     151/Unknown 550s 3s/step - accuracy: 0.4970 - loss: 66.3539Data is a string of length 86071
# Data is a string of length 64582
#     152/Unknown 552s 3s/step - accuracy: 0.4971 - loss: 66.1243Data is a string of length 61646
# Data is a string of length 96764
#     153/Unknown 554s 3s/step - accuracy: 0.4973 - loss: 65.8964Data is a string of length 67788
# Data is a string of length 89261
# Data is a string of length 105656
#     154/Unknown 558s 3s/step - accuracy: 0.4975 - loss: 65.6701Data is a string of length 34450
# Data is a string of length 80490
#     155/Unknown 562s 3s/step - accuracy: 0.4976 - loss: 65.4463Data is a string of length 68642
# Data is a string of length 84447
#     156/Unknown 564s 3s/step - accuracy: 0.4978 - loss: 65.2240Data is a string of length 52519
# Data is a string of length 153871
#     157/Unknown 566s 3s/step - accuracy: 0.4980 - loss: 65.0034Data is a string of length 93761
#     158/Unknown 569s 3s/step - accuracy: 0.4982 - loss: 64.7844Data is a string of length 115415
# Data is a string of length 61049
# Data is a string of length 63581
#     159/Unknown 571s 3s/step - accuracy: 0.4984 - loss: 64.5669Data is a string of length 71340
# Data is a string of length 112228
#     160/Unknown 574s 3s/step - accuracy: 0.4986 - loss: 64.3510Data is a string of length 111580
#     161/Unknown 576s 3s/step - accuracy: 0.4988 - loss: 64.1366Data is a string of length 114197
# Data is a string of length 43515
# Data is a string of length 43001
#     162/Unknown 579s 3s/step - accuracy: 0.4990 - loss: 63.9240Data is a string of length 78418
#     163/Unknown 581s 3s/step - accuracy: 0.4992 - loss: 63.7130Data is a string of length 98656
# Data is a string of length 37236
#     164/Unknown 584s 3s/step - accuracy: 0.4994 - loss: 63.5035Data is a string of length 82669
# Data is a string of length 50063
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2022104021 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 53586
#     165/Unknown 586s 3s/step - accuracy: 0.4996 - loss: 63.2955Data is a string of length 59343
# Data is a string of length 50146
#     166/Unknown 589s 3s/step - accuracy: 0.4998 - loss: 63.0890Data is a string of length 57472
# Data is a string of length 65329
# Data is a string of length 42437
#     167/Unknown 592s 3s/step - accuracy: 0.5000 - loss: 62.8839Data is a string of length 82407
# Data is a string of length 72756
#     168/Unknown 594s 3s/step - accuracy: 0.5002 - loss: 62.6802Data is a string of length 62029
# Data is a string of length 45738
#     169/Unknown 597s 3s/step - accuracy: 0.5004 - loss: 62.4780Data is a string of length 80144
# Data is a string of length 66705
#     170/Unknown 601s 3s/step - accuracy: 0.5006 - loss: 62.2772Data is a string of length 80619
#
# Saving periodic model checkpoint...
#     171/Unknown 605s 3s/step - accuracy: 0.5008 - loss: 62.0778Data is a string of length 117272
# Data is a string of length 57749
#     172/Unknown 607s 3s/step - accuracy: 0.5010 - loss: 61.8798Data is a string of length 71331
# Data is a string of length 51838
# Data is a string of length 60473
#     173/Unknown 611s 3s/step - accuracy: 0.5012 - loss: 61.6832Data is a string of length 56194
#     174/Unknown 615s 3s/step - accuracy: 0.5014 - loss: 61.4880Data is a string of length 108815
# Data is a string of length 76268
#     175/Unknown 618s 3s/step - accuracy: 0.5017 - loss: 61.2941Data is a string of length 99311
# Data is a string of length 46449
#     176/Unknown 621s 3s/step - accuracy: 0.5019 - loss: 61.1015Data is a string of length 137885
# Data is a string of length 45856
# Data is a string of length 40583
#     177/Unknown 623s 3s/step - accuracy: 0.5021 - loss: 60.9102Data is a string of length 230108
#     178/Unknown 626s 3s/step - accuracy: 0.5023 - loss: 60.7203Data is a string of length 77581
# Data is a string of length 218579
#     179/Unknown 629s 3s/step - accuracy: 0.5026 - loss: 60.5317Data is a string of length 59714
# Data is a string of length 115253
#     180/Unknown 631s 3s/step - accuracy: 0.5028 - loss: 60.3444Data is a string of length 104024
# Data is a string of length 58244
#     181/Unknown 638s 3s/step - accuracy: 0.5030 - loss: 60.1586Data is a string of length 146140
# Data is a string of length 55289
#     182/Unknown 640s 3s/step - accuracy: 0.5033 - loss: 59.9742Data is a string of length 357556
# Data is a string of length 90429
#     183/Unknown 643s 3s/step - accuracy: 0.5035 - loss: 59.7909Data is a string of length 85682
# Data is a string of length 67201
#     184/Unknown 645s 3s/step - accuracy: 0.5037 - loss: 59.6089Data is a string of length 60728
# Data is a string of length 204055
#     185/Unknown 648s 3s/step - accuracy: 0.5039 - loss: 59.4281Data is a string of length 95379
# Data is a string of length 155374
# Data is a string of length 41909
#     186/Unknown 650s 3s/step - accuracy: 0.5041 - loss: 59.2484Data is a string of length 129201
# Data is a string of length 62804
#     187/Unknown 655s 3s/step - accuracy: 0.5043 - loss: 59.0700Data is a string of length 65746
# Data is a string of length 95035
#     188/Unknown 657s 3s/step - accuracy: 0.5045 - loss: 58.8928Data is a string of length 90327
#     189/Unknown 660s 3s/step - accuracy: 0.5047 - loss: 58.7168Data is a string of length 105508
# Data is a string of length 344211
# Data is a string of length 93107
#     190/Unknown 663s 3s/step - accuracy: 0.5049 - loss: 58.5420Data is a string of length 91621
# Data is a string of length 79122
#     191/Unknown 666s 3s/step - accuracy: 0.5051 - loss: 58.3683Data is a string of length 128892
#     192/Unknown 669s 3s/step - accuracy: 0.5053 - loss: 58.1958Data is a string of length 37343
# Data is a string of length 147031
# Data is a string of length 37163
#     193/Unknown 672s 3s/step - accuracy: 0.5055 - loss: 58.0244Data is a string of length 73340
#     194/Unknown 674s 3s/step - accuracy: 0.5056 - loss: 57.8541Data is a string of length 34852
# Data is a string of length 52440
#     195/Unknown 678s 3s/step - accuracy: 0.5058 - loss: 57.6851Data is a string of length 60305
# Data is a string of length 84466
#     196/Unknown 680s 3s/step - accuracy: 0.5059 - loss: 57.5172Data is a string of length 158371
# Data is a string of length 140725
# Data is a string of length 43493
#     197/Unknown 685s 3s/step - accuracy: 0.5061 - loss: 57.3503Data is a string of length 61636
#     198/Unknown 689s 3s/step - accuracy: 0.5062 - loss: 57.1845Data is a string of length 87469
# Data is a string of length 149366
#     199/Unknown 692s 3s/step - accuracy: 0.5064 - loss: 57.0198Data is a string of length 38843
# Data is a string of length 48357
#     200/Unknown 694s 3s/step - accuracy: 0.5065 - loss: 56.8561Data is a string of length 94461
# Data is a string of length 220296
# Data is a string of length 102275
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2016294811 A1,Standard=TS 33.501.501die to empty text.
#     201/Unknown 697s 3s/step - accuracy: 0.5067 - loss: 56.6935Data is a string of length 97243
# Data is a string of length 43515
# Data is a string of length 47725
#     202/Unknown 700s 3s/step - accuracy: 0.5068 - loss: 56.5319Data is a string of length 46225
# Data is a string of length 39761
#     203/Unknown 702s 3s/step - accuracy: 0.5070 - loss: 56.3714Data is a string of length 61177
#     204/Unknown 704s 3s/step - accuracy: 0.5071 - loss: 56.2118Data is a string of length 73158
# Data is a string of length 87406
# Data is a string of length 65768
#     205/Unknown 707s 3s/step - accuracy: 0.5073 - loss: 56.0533Data is a string of length 56633
# Data is a string of length 26738
#     206/Unknown 709s 3s/step - accuracy: 0.5074 - loss: 55.8957Data is a string of length 51481
#     207/Unknown 712s 3s/step - accuracy: 0.5076 - loss: 55.7391Data is a string of length 102361
# Data is a string of length 106871
#     208/Unknown 714s 3s/step - accuracy: 0.5077 - loss: 55.5835Data is a string of length 75155
# Data is a string of length 76122
#     209/Unknown 718s 3s/step - accuracy: 0.5079 - loss: 55.4289Data is a string of length 75272
# Data is a string of length 70040
#     210/Unknown 720s 3s/step - accuracy: 0.5081 - loss: 55.2752Data is a string of length 19765
# Data is a string of length 160498
# Data is a string of length 55758
#     211/Unknown 723s 3s/step - accuracy: 0.5083 - loss: 55.1225Data is a string of length 71231
#     212/Unknown 725s 3s/step - accuracy: 0.5084 - loss: 54.9707Data is a string of length 114218
# Data is a string of length 91072
#     213/Unknown 728s 3s/step - accuracy: 0.5086 - loss: 54.8198Data is a string of length 128230
# Data is a string of length 133825
#     214/Unknown 730s 3s/step - accuracy: 0.5088 - loss: 54.6698Data is a string of length 53434
# Data is a string of length 53963
# Data is a string of length 67443
#     215/Unknown 733s 3s/step - accuracy: 0.5090 - loss: 54.5208Data is a string of length 72414
#     216/Unknown 735s 3s/step - accuracy: 0.5092 - loss: 54.3727Data is a string of length 31805
# Data is a string of length 104305
#     217/Unknown 737s 3s/step - accuracy: 0.5094 - loss: 54.2257Data is a string of length 61222
# Data is a string of length 69127
#     218/Unknown 740s 3s/step - accuracy: 0.5096 - loss: 54.0797Data is a string of length 139263
# Data is a string of length 336404
# Data is a string of length 51168
#     219/Unknown 742s 3s/step - accuracy: 0.5098 - loss: 53.9345Data is a string of length 266892
# Data is a string of length 71352
#     220/Unknown 745s 3s/step - accuracy: 0.5100 - loss: 53.7905Data is a string of length 52222
#     221/Unknown 747s 3s/step - accuracy: 0.5102 - loss: 53.6473Data is a string of length 50536
# Data is a string of length 57660
#     222/Unknown 749s 3s/step - accuracy: 0.5104 - loss: 53.5051Data is a string of length 71076
# Data is a string of length 61524
#     223/Unknown 752s 3s/step - accuracy: 0.5106 - loss: 53.3636Data is a string of length 90436
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.203/ does not exist.
#
# Skipping sample: US9660713 B2,Standard=TS 33.203.203die to empty text.
# Data is a string of length 56224
# Data is a string of length 33146
#     224/Unknown 756s 3s/step - accuracy: 0.5108 - loss: 53.2230Data is a string of length 30489
# Data is a string of length 238109
#     225/Unknown 760s 3s/step - accuracy: 0.5110 - loss: 53.0833Data is a string of length 175315
# Data is a string of length 60738
#     226/Unknown 762s 3s/step - accuracy: 0.5112 - loss: 52.9443Data is a string of length 60773
# Data is a string of length 112821
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US10299115 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 65329
#     227/Unknown 765s 3s/step - accuracy: 0.5114 - loss: 52.8062Data is a string of length 75461
# Data is a string of length 94799
# Data is a string of length 51589
#     228/Unknown 767s 3s/step - accuracy: 0.5116 - loss: 52.6689Data is a string of length 25995
#     229/Unknown 769s 3s/step - accuracy: 0.5117 - loss: 52.5324Data is a string of length 184530
# Data is a string of length 68493
# Data is a string of length 53807
#     230/Unknown 773s 3s/step - accuracy: 0.5119 - loss: 52.3967Data is a string of length 83134
#     231/Unknown 776s 3s/step - accuracy: 0.5121 - loss: 52.2618Data is a string of length 95659
# Data is a string of length 102570
#     232/Unknown 779s 3s/step - accuracy: 0.5123 - loss: 52.1276Data is a string of length 81061
# Data is a string of length 116496
#     233/Unknown 781s 3s/step - accuracy: 0.5124 - loss: 51.9943Data is a string of length 78272
# Data is a string of length 79773
# Data is a string of length 76929
#     234/Unknown 785s 3s/step - accuracy: 0.5126 - loss: 51.8617Data is a string of length 80286
#     235/Unknown 787s 3s/step - accuracy: 0.5128 - loss: 51.7298Data is a string of length 187814
# Data is a string of length 66390
#     236/Unknown 789s 3s/step - accuracy: 0.5129 - loss: 51.5987
# Data is a string of length 144165
#     237/Unknown 793s 3s/step - accuracy: 0.5131 - loss: 51.4684Data is a string of length 154172
# Data is a string of length 49038
#     238/Unknown 795s 3s/step - accuracy: 0.5132 - loss: 51.3388Data is a string of length 65253
# Data is a string of length 173602
#     239/Unknown 798s 3s/step - accuracy: 0.5134 - loss: 51.2100Data is a string of length 89551
# Data is a string of length 88809
# Data is a string of length 145506
#     240/Unknown 801s 3s/step - accuracy: 0.5135 - loss: 51.0818Data is a string of length 33677
#     241/Unknown 803s 3s/step - accuracy: 0.5136 - loss: 50.9544Data is a string of length 246961
# Data is a string of length 90292
#     242/Unknown 807s 3s/step - accuracy: 0.5138 - loss: 50.8277Data is a string of length 69701
# Data is a string of length 71640
#     243/Unknown 812s 3s/step - accuracy: 0.5139 - loss: 50.7018Data is a string of length 36590
# Data is a string of length 107893
# Data is a string of length 190690
#     244/Unknown 814s 3s/step - accuracy: 0.5141 - loss: 50.5765Data is a string of length 58831
#     245/Unknown 816s 3s/step - accuracy: 0.5142 - loss: 50.4519Data is a string of length 95035
# Data is a string of length 55154
#     246/Unknown 836s 3s/step - accuracy: 0.5144 - loss: 50.3280Data is a string of length 54145
# Data is a string of length 102766
#     247/Unknown 840s 3s/step - accuracy: 0.5145 - loss: 50.2048Data is a string of length 164183
# Data is a string of length 67525
#     248/Unknown 843s 3s/step - accuracy: 0.5147 - loss: 50.0823Data is a string of length 74118
# Data is a string of length 68885
#     249/Unknown 846s 3s/step - accuracy: 0.5148 - loss: 49.9604Data is a string of length 97631
# Data is a string of length 98177
#     250/Unknown 848s 3s/step - accuracy: 0.5150 - loss: 49.8393Data is a string of length 53380
# Data is a string of length 66994
#     251/Unknown 850s 3s/step - accuracy: 0.5151 - loss: 49.7188Data is a string of length 114057
# Data is a string of length 156297
#     252/Unknown 853s 3s/step - accuracy: 0.5153 - loss: 49.5990Data is a string of length 142562
# Data is a string of length 290922
#     253/Unknown 857s 3s/step - accuracy: 0.5154 - loss: 49.4798Data is a string of length 102491
# Data is a string of length 230585
#     254/Unknown 861s 3s/step - accuracy: 0.5156 - loss: 49.3613Data is a string of length 67172
# Data is a string of length 115030
#     255/Unknown 863s 3s/step - accuracy: 0.5157 - loss: 49.2434Data is a string of length 79690
# Data is a string of length 115453
#     256/Unknown 866s 3s/step - accuracy: 0.5158 - loss: 49.1261Data is a string of length 49521
# Data is a string of length 153898
#     257/Unknown 868s 3s/step - accuracy: 0.5160 - loss: 49.0095Data is a string of length 45734
# Data is a string of length 82836
# Data is a string of length 73743
#     258/Unknown 873s 3s/step - accuracy: 0.5161 - loss: 48.8936Data is a string of length 94452
#     259/Unknown 876s 3s/step - accuracy: 0.5163 - loss: 48.7782Data is a string of length 82429
# Data is a string of length 143824
#     260/Unknown 878s 3s/step - accuracy: 0.5164 - loss: 48.6635Data is a string of length 54105
# Data is a string of length 94414
#     261/Unknown 881s 3s/step - accuracy: 0.5165 - loss: 48.5493Data is a string of length 51397
# Data is a string of length 58517
#     262/Unknown 884s 3s/step - accuracy: 0.5167 - loss: 48.4358Data is a string of length 79581
# Data is a string of length 59482
#     263/Unknown 886s 3s/step - accuracy: 0.5168 - loss: 48.3229Data is a string of length 90167
# Data is a string of length 122828
#     264/Unknown 889s 3s/step - accuracy: 0.5169 - loss: 48.2106Data is a string of length 116734
# Data is a string of length 71710
#     265/Unknown 891s 3s/step - accuracy: 0.5170 - loss: 48.0989Data is a string of length 89353
# Data is a string of length 52519
#     266/Unknown 894s 3s/step - accuracy: 0.5172 - loss: 47.9878Data is a string of length 119670
# Data is a string of length 84395
#     267/Unknown 896s 3s/step - accuracy: 0.5173 - loss: 47.8772Data is a string of length 102519
# Data is a string of length 212896
# Data is a string of length 48546
#     268/Unknown 898s 3s/step - accuracy: 0.5174 - loss: 47.7673Data is a string of length 183976
#     269/Unknown 902s 3s/step - accuracy: 0.5175 - loss: 47.6579Data is a string of length 67045
# Data is a string of length 139548
#     270/Unknown 904s 3s/step - accuracy: 0.5177 - loss: 47.5491Data is a string of length 121852
# Data is a string of length 138310
#
# Saving periodic model checkpoint...
# Data is a string of length 241601
#     271/Unknown 908s 3s/step - accuracy: 0.5178 - loss: 47.4408Data is a string of length 110203
#     272/Unknown 912s 3s/step - accuracy: 0.5179 - loss: 47.3331Data is a string of length 36964
# Data is a string of length 105441
#     273/Unknown 915s 3s/step - accuracy: 0.5181 - loss: 47.2260Data is a string of length 97353
# Data is a string of length 33183
#     274/Unknown 919s 3s/step - accuracy: 0.5182 - loss: 47.1194Data is a string of length 59120
# Data is a string of length 84198
# Data is a string of length 79738
#     275/Unknown 922s 3s/step - accuracy: 0.5183 - loss: 47.0133Data is a string of length 47590
#     276/Unknown 924s 3s/step - accuracy: 0.5184 - loss: 46.9078Data is a string of length 33804
# Data is a string of length 67198
# Data is a string of length 78495
#     277/Unknown 927s 3s/step - accuracy: 0.5185 - loss: 46.8029Data is a string of length 66762
#     278/Unknown 931s 3s/step - accuracy: 0.5187 - loss: 46.6985Data is a string of length 115300
# Data is a string of length 59376
#     279/Unknown 933s 3s/step - accuracy: 0.5188 - loss: 46.5946Data is a string of length 107212
# Data is a string of length 46468
# Data is a string of length 69959
#     280/Unknown 936s 3s/step - accuracy: 0.5189 - loss: 46.4912Data is a string of length 34580
#     281/Unknown 939s 3s/step - accuracy: 0.5190 - loss: 46.3883Data is a string of length 144289
# Data is a string of length 196158
#     282/Unknown 941s 3s/step - accuracy: 0.5191 - loss: 46.2860Data is a string of length 140077
# Data is a string of length 78850
#     283/Unknown 944s 3s/step - accuracy: 0.5192 - loss: 46.1842Data is a string of length 89225
# Data is a string of length 83221
# Data is a string of length 57749
#     284/Unknown 947s 3s/step - accuracy: 0.5193 - loss: 46.0829Data is a string of length 64680
#     285/Unknown 950s 3s/step - accuracy: 0.5194 - loss: 45.9821Data is a string of length 79510
# Data is a string of length 55594
# Data is a string of length 57665
#     286/Unknown 952s 3s/step - accuracy: 0.5195 - loss: 45.8818Data is a string of length 53809
#     287/Unknown 955s 3s/step - accuracy: 0.5195 - loss: 45.7820Data is a string of length 99597
# Data is a string of length 65919
#     288/Unknown 958s 3s/step - accuracy: 0.5196 - loss: 45.6827Data is a string of length 50603
# Data is a string of length 42917
#     289/Unknown 961s 3s/step - accuracy: 0.5197 - loss: 45.5839Data is a string of length 54622
# Data is a string of length 158371
#     290/Unknown 965s 3s/step - accuracy: 0.5198 - loss: 45.4856Data is a string of length 112952
# Data is a string of length 57836
#     291/Unknown 969s 3s/step - accuracy: 0.5199 - loss: 45.3878Data is a string of length 53705
# Data is a string of length 59731
#     292/Unknown 972s 3s/step - accuracy: 0.5199 - loss: 45.2904Data is a string of length 86154
# Data is a string of length 116739
#     293/Unknown 977s 3s/step - accuracy: 0.5200 - loss: 45.1935Data is a string of length 43900
# Data is a string of length 76750
# Data is a string of length 349919
#     294/Unknown 981s 3s/step - accuracy: 0.5201 - loss: 45.0971Data is a string of length 63363
# Data is a string of length 58344
#     295/Unknown 985s 3s/step - accuracy: 0.5202 - loss: 45.0012Data is a string of length 100693
# Data is a string of length 101993
#     296/Unknown 987s 3s/step - accuracy: 0.5203 - loss: 44.9057Data is a string of length 157431
#     297/Unknown 990s 3s/step - accuracy: 0.5203 - loss: 44.8107Data is a string of length 63243
# Data is a string of length 120659
#     298/Unknown 993s 3s/step - accuracy: 0.5204 - loss: 44.7161Data is a string of length 80896
# Data is a string of length 155243
# Data is a string of length 53342
#     299/Unknown 996s 3s/step - accuracy: 0.5205 - loss: 44.6220Data is a string of length 58287
#     300/Unknown 1001s 3s/step - accuracy: 0.5205 - loss: 44.5284Data is a string of length 39972
# Data is a string of length 73288
#     301/Unknown 1003s 3s/step - accuracy: 0.5206 - loss: 44.4352Data is a string of length 108766
# Data is a string of length 128340
# Data is a string of length 122505
#     302/Unknown 1005s 3s/step - accuracy: 0.5206 - loss: 44.3424Data is a string of length 126588
#     303/Unknown 1013s 3s/step - accuracy: 0.5207 - loss: 44.2501Data is a string of length 44676
# Data is a string of length 61136
#     304/Unknown 1018s 3s/step - accuracy: 0.5208 - loss: 44.1582Data is a string of length 83946
# Data is a string of length 46021
#     305/Unknown 1020s 3s/step - accuracy: 0.5209 - loss: 44.0668Data is a string of length 87133
# Data is a string of length 178158
#     306/Unknown 1025s 3s/step - accuracy: 0.5209 - loss: 43.9758Data is a string of length 93128
# Data is a string of length 53859
# Data is a string of length 60345
#     307/Unknown 1028s 3s/step - accuracy: 0.5210 - loss: 43.8852Data is a string of length 60972
# Data is a string of length 56055
#     308/Unknown 1031s 3s/step - accuracy: 0.5211 - loss: 43.7950Data is a string of length 70747
#     309/Unknown 1034s 3s/step - accuracy: 0.5211 - loss: 43.7053Data is a string of length 71630
# Data is a string of length 89157
#     310/Unknown 1036s 3s/step - accuracy: 0.5212 - loss: 43.6160Data is a string of length 132233
# Data is a string of length 72223
#     311/Unknown 1039s 3s/step - accuracy: 0.5212 - loss: 43.5271Data is a string of length 104462
# Data is a string of length 57256
#     312/Unknown 1044s 3s/step - accuracy: 0.5213 - loss: 43.4386Data is a string of length 143776
# Data is a string of length 91916
# Data is a string of length 92889
#     313/Unknown 1046s 3s/step - accuracy: 0.5214 - loss: 43.3505Data is a string of length 53284
#     314/Unknown 1048s 3s/step - accuracy: 0.5214 - loss: 43.2628Data is a string of length 81703
# Data is a string of length 38516
#     315/Unknown 1051s 3s/step - accuracy: 0.5215 - loss: 43.1755Data is a string of length 104171
# Data is a string of length 42255
#     316/Unknown 1054s 3s/step - accuracy: 0.5216 - loss: 43.0887Data is a string of length 73689
# Data is a string of length 55146
#     317/Unknown 1057s 3s/step - accuracy: 0.5216 - loss: 43.0022Data is a string of length 60577
# Data is a string of length 63666
#     318/Unknown 1061s 3s/step - accuracy: 0.5217 - loss: 42.9161Data is a string of length 61483
# Data is a string of length 59468
#     319/Unknown 1064s 3s/step - accuracy: 0.5218 - loss: 42.8304Data is a string of length 176668
# Data is a string of length 77113
#     320/Unknown 1069s 3s/step - accuracy: 0.5219 - loss: 42.7452Data is a string of length 97497
# Data is a string of length 53420
#     321/Unknown 1071s 3s/step - accuracy: 0.5219 - loss: 42.6603Data is a string of length 66747
# Data is a string of length 36103
#     322/Unknown 1075s 3s/step - accuracy: 0.5220 - loss: 42.5757Data is a string of length 215273
# Data is a string of length 51348
#     323/Unknown 1077s 3s/step - accuracy: 0.5221 - loss: 42.4916Data is a string of length 38209
# Data is a string of length 65668
#     324/Unknown 1080s 3s/step - accuracy: 0.5222 - loss: 42.4078Data is a string of length 81291
# Data is a string of length 36669
#     325/Unknown 1084s 3s/step - accuracy: 0.5223 - loss: 42.3244Data is a string of length 54024
# Data is a string of length 93492
#     326/Unknown 1087s 3s/step - accuracy: 0.5223 - loss: 42.2414Data is a string of length 45101
# Data is a string of length 111348
#     327/Unknown 1090s 3s/step - accuracy: 0.5224 - loss: 42.1588Data is a string of length 82957
# Data is a string of length 60690
# Data is a string of length 217373
#     328/Unknown 1092s 3s/step - accuracy: 0.5225 - loss: 42.0765Data is a string of length 76594
# Data is a string of length 55945
#     329/Unknown 1095s 3s/step - accuracy: 0.5226 - loss: 41.9946Data is a string of length 118194
#     330/Unknown 1097s 3s/step - accuracy: 0.5227 - loss: 41.9131Data is a string of length 66496
# Data is a string of length 82106
#     331/Unknown 1104s 3s/step - accuracy: 0.5228 - loss: 41.8319Data is a string of length 105995
# Data is a string of length 64947
#     332/Unknown 1108s 3s/step - accuracy: 0.5229 - loss: 41.7511Data is a string of length 83717
# Data is a string of length 40231
#     333/Unknown 1111s 3s/step - accuracy: 0.5230 - loss: 41.6707Data is a string of length 140079
# Data is a string of length 82054
#     334/Unknown 1113s 3s/step - accuracy: 0.5230 - loss: 41.5906Data is a string of length 120063
# Data is a string of length 103658
# Data is a string of length 42461
#     335/Unknown 1116s 3s/step - accuracy: 0.5231 - loss: 41.5108Data is a string of length 72320
#     336/Unknown 1119s 3s/step - accuracy: 0.5232 - loss: 41.4314Data is a string of length 60660
# Data is a string of length 440272
#     337/Unknown 1121s 3s/step - accuracy: 0.5233 - loss: 41.3523Data is a string of length 137846
# Data is a string of length 73891
#     338/Unknown 1125s 3s/step - accuracy: 0.5234 - loss: 41.2736Data is a string of length 109407
# Data is a string of length 115381
#     339/Unknown 1128s 3s/step - accuracy: 0.5234 - loss: 41.1953Data is a string of length 88851
# Data is a string of length 22445
# Data is a string of length 67451
#     340/Unknown 1130s 3s/step - accuracy: 0.5235 - loss: 41.1173Data is a string of length 64446
#     341/Unknown 1133s 3s/step - accuracy: 0.5236 - loss: 41.0396Data is a string of length 79548
# Data is a string of length 109301
#     342/Unknown 1135s 3s/step - accuracy: 0.5237 - loss: 40.9622Data is a string of length 121167
# Data is a string of length 96780
#     343/Unknown 1138s 3s/step - accuracy: 0.5238 - loss: 40.8852Data is a string of length 126452
# Data is a string of length 262085
#     344/Unknown 1141s 3s/step - accuracy: 0.5238 - loss: 40.8085Data is a string of length 82085
# Data is a string of length 89415
#     345/Unknown 1144s 3s/step - accuracy: 0.5239 - loss: 40.7322Data is a string of length 83249
# Data is a string of length 106037
# Data is a string of length 102489
# ...
# Data is a string of length 157102
#    5268/Unknown 18599s 4s/step - accuracy: 0.5881 - loss: 5.7760Data is a string of length 105903
# Data is a string of length 84051
#    5269/Unknown 18602s 4s/step - accuracy: 0.5881 - loss: 5.7752Data is a string of length 72736
# Data is a string of length 141643
#    5270/Unknown 18604s 4s/step - accuracy: 0.5881 - loss: 5.7744Data is a string of length 102532
# Data is a string of length 99474
#    5271/Unknown 18607s 4s/step - accuracy: 0.5881 - loss: 5.7736Data is a string of length 89423
# Data is a string of length 162460
# Data is a string of length 169252
#    5272/Unknown 18610s 4s/step - accuracy: 0.5881 - loss: 5.7728Data is a string of length 56315
#    5273/Unknown 18613s 4s/step - accuracy: 0.5881 - loss: 5.7721Data is a string of length 127527
# Data is a string of length 122407
#    5274/Unknown 18616s 4s/step - accuracy: 0.5881 - loss: 5.7713Data is a string of length 179318
# Data is a string of length 209746
#    5275/Unknown 18620s 4s/step - accuracy: 0.5881 - loss: 5.7705Data is a string of length 78854
# Data is a string of length 162287
#    5276/Unknown 18623s 4s/step - accuracy: 0.5881 - loss: 5.7697
# Data is a string of length 174859
#    5277/Unknown 18625s 4s/step - accuracy: 0.5881 - loss: 5.7689Data is a string of length 102988
# Data is a string of length 35339
#    5278/Unknown 18628s 4s/step - accuracy: 0.5881 - loss: 5.7681Data is a string of length 76339
# Data is a string of length 106213
#    5279/Unknown 18633s 4s/step - accuracy: 0.5881 - loss: 5.7673Data is a string of length 63613
# Data is a string of length 182782
#    5280/Unknown 18635s 4s/step - accuracy: 0.5881 - loss: 5.7665Data is a string of length 30843
# Data is a string of length 93636
#    5281/Unknown 18640s 4s/step - accuracy: 0.5881 - loss: 5.7657Data is a string of length 103792
# Data is a string of length 124783
# Data is a string of length 78306
#    5282/Unknown 18643s 4s/step - accuracy: 0.5882 - loss: 5.7649Data is a string of length 67791
#    5283/Unknown 18647s 4s/step - accuracy: 0.5882 - loss: 5.7641Data is a string of length 57397
# Data is a string of length 232448
#    5284/Unknown 18650s 4s/step - accuracy: 0.5882 - loss: 5.7634Data is a string of length 274117
# Data is a string of length 65758
# Data is a string of length 47287
#    5285/Unknown 18655s 4s/step - accuracy: 0.5882 - loss: 5.7626Data is a string of length 156518
#    5286/Unknown 18658s 4s/step - accuracy: 0.5882 - loss: 5.7618Data is a string of length 219537
# Data is a string of length 71707
#    5287/Unknown 18662s 4s/step - accuracy: 0.5882 - loss: 5.7610Data is a string of length 112891
# Data is a string of length 56958
# Data is a string of length 59012
#    5288/Unknown 18664s 4s/step - accuracy: 0.5882 - loss: 5.7602Data is a string of length 112001
#    5289/Unknown 18667s 4s/step - accuracy: 0.5882 - loss: 5.7594Data is a string of length 67344
# Data is a string of length 110632
#    5290/Unknown 18672s 4s/step - accuracy: 0.5882 - loss: 5.7586Data is a string of length 84296
# Data is a string of length 281998
# Data is a string of length 177315
#    5291/Unknown 18676s 4s/step - accuracy: 0.5882 - loss: 5.7578Data is a string of length 137194
# Data is a string of length 72565
#    5292/Unknown 18679s 4s/step - accuracy: 0.5882 - loss: 5.7570Data is a string of length 170342
#    5293/Unknown 18681s 4s/step - accuracy: 0.5882 - loss: 5.7563Data is a string of length 60821
# Data is a string of length 89507
#    5294/Unknown 18684s 4s/step - accuracy: 0.5882 - loss: 5.7555Data is a string of length 53239
# Data is a string of length 41130
# Data is a string of length 65239
#    5295/Unknown 18687s 4s/step - accuracy: 0.5882 - loss: 5.7547Data is a string of length 67839
#    5296/Unknown 18695s 4s/step - accuracy: 0.5882 - loss: 5.7539Data is a string of length 145429
# Data is a string of length 38561
#    5297/Unknown 18699s 4s/step - accuracy: 0.5882 - loss: 5.7531Data is a string of length 192668
# Data is a string of length 46773
#    5298/Unknown 18703s 4s/step - accuracy: 0.5882 - loss: 5.7523Data is a string of length 80843
# Data is a string of length 45389
#    5299/Unknown 18712s 4s/step - accuracy: 0.5882 - loss: 5.7515Data is a string of length 120659
# Data is a string of length 76439
#    5300/Unknown 18716s 4s/step - accuracy: 0.5882 - loss: 5.7508Data is a string of length 49387
# Data is a string of length 110902
#    5301/Unknown 18718s 4s/step - accuracy: 0.5882 - loss: 5.7500Data is a string of length 121963
# Data is a string of length 140529
#    5302/Unknown 18721s 4s/step - accuracy: 0.5882 - loss: 5.7492Data is a string of length 39027
# Data is a string of length 159774
#    5303/Unknown 18725s 4s/step - accuracy: 0.5882 - loss: 5.7484Data is a string of length 58653
# Data is a string of length 83760
#    5304/Unknown 18728s 4s/step - accuracy: 0.5882 - loss: 5.7476Data is a string of length 55031
# Data is a string of length 82351
# Data is a string of length 88860
#    5305/Unknown 18732s 4s/step - accuracy: 0.5882 - loss: 5.7468Data is a string of length 62843
#    5306/Unknown 18736s 4s/step - accuracy: 0.5882 - loss: 5.7460Data is a string of length 59622
# Data is a string of length 131915
#    5307/Unknown 18739s 4s/step - accuracy: 0.5882 - loss: 5.7453Data is a string of length 272298
# Data is a string of length 87185
# Data is a string of length 96080
#    5308/Unknown 18742s 4s/step - accuracy: 0.5882 - loss: 5.7445Data is a string of length 101693
#    5309/Unknown 18744s 4s/step - accuracy: 0.5882 - loss: 5.7437Data is a string of length 36741
# Data is a string of length 60261
#    5310/Unknown 18746s 4s/step - accuracy: 0.5882 - loss: 5.7429Data is a string of length 181995
# Data is a string of length 34501
#    5311/Unknown 18749s 4s/step - accuracy: 0.5882 - loss: 5.7421Data is a string of length 42604
# Data is a string of length 94314
# Data is a string of length 48143
#    5312/Unknown 18752s 4s/step - accuracy: 0.5882 - loss: 5.7414Data is a string of length 169577
#    5313/Unknown 18756s 4s/step - accuracy: 0.5882 - loss: 5.7406Data is a string of length 120048
# Data is a string of length 108194
#    5314/Unknown 18761s 4s/step - accuracy: 0.5882 - loss: 5.7398Data is a string of length 37001
# Data is a string of length 103520
#    5315/Unknown 18764s 4s/step - accuracy: 0.5882 - loss: 5.7390Data is a string of length 181539
# Data is a string of length 50816
# Data is a string of length 291447
#    5316/Unknown 18767s 4s/step - accuracy: 0.5882 - loss: 5.7382Data is a string of length 141618
#    5317/Unknown 18769s 4s/step - accuracy: 0.5882 - loss: 5.7374Data is a string of length 171230
# Data is a string of length 195431
#    5318/Unknown 18772s 4s/step - accuracy: 0.5882 - loss: 5.7367Data is a string of length 122825
# Data is a string of length 86291
#
# Saving periodic model checkpoint...
# Data is a string of length 68465
#    5319/Unknown 18775s 4s/step - accuracy: 0.5882 - loss: 5.7359Data is a string of length 72905
#    5320/Unknown 18778s 4s/step - accuracy: 0.5882 - loss: 5.7351Data is a string of length 55058
# Data is a string of length 112628
#    5321/Unknown 18781s 4s/step - accuracy: 0.5882 - loss: 5.7343Data is a string of length 104046
# Data is a string of length 134213
# Data is a string of length 57497
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US8902907 B2,Standard=TS 33.501.501die to empty text.
#    5322/Unknown 18784s 4s/step - accuracy: 0.5882 - loss: 5.7335Data is a string of length 49831
# Data is a string of length 37141
#    5323/Unknown 18786s 4s/step - accuracy: 0.5882 - loss: 5.7328Data is a string of length 78750
# Data is a string of length 78464
#    5324/Unknown 18789s 4s/step - accuracy: 0.5882 - loss: 5.7320Data is a string of length 117982
# Data is a string of length 93809
#    5325/Unknown 18791s 4s/step - accuracy: 0.5882 - loss: 5.7312Data is a string of length 61281
# Data is a string of length 62933
#    5326/Unknown 18794s 4s/step - accuracy: 0.5882 - loss: 5.7304Data is a string of length 33528
# Data is a string of length 59033
#    5327/Unknown 18797s 4s/step - accuracy: 0.5882 - loss: 5.7296Data is a string of length 117411
# Data is a string of length 56916
#    5328/Unknown 18799s 4s/step - accuracy: 0.5882 - loss: 5.7289Data is a string of length 43498
# Data is a string of length 218307
#    5329/Unknown 18801s 4s/step - accuracy: 0.5882 - loss: 5.7281Data is a string of length 60410
# Data is a string of length 61409
#    5330/Unknown 18805s 4s/step - accuracy: 0.5882 - loss: 5.7273Data is a string of length 86013
# Data is a string of length 72652
#    5331/Unknown 18807s 4s/step - accuracy: 0.5882 - loss: 5.7265Data is a string of length 132780
# Data is a string of length 57088
#    5332/Unknown 18809s 4s/step - accuracy: 0.5882 - loss: 5.7258Data is a string of length 104688
# Data is a string of length 135288
#    5333/Unknown 18813s 4s/step - accuracy: 0.5882 - loss: 5.7250Data is a string of length 176606
# Data is a string of length 48215
#    5334/Unknown 18816s 4s/step - accuracy: 0.5882 - loss: 5.7242Data is a string of length 45310
# Data is a string of length 309089
#    5335/Unknown 18818s 4s/step - accuracy: 0.5883 - loss: 5.7234Data is a string of length 84345
# Data is a string of length 64547
#    5336/Unknown 18822s 4s/step - accuracy: 0.5883 - loss: 5.7227Data is a string of length 44708
# Data is a string of length 45925
# Training process finished.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 36
#      32 final_model_path = None # Initialize the variable
#      34 try:
#      35     # Start training
# ---> 36     model.fit(train_tf_dataset,
#      37               epochs=num_epochs,
#      38               callbacks=callbacks,
#      39               validation_data=val_tf_dataset)
#      41     # If training completes successfully, save the final model
#      42     final_model_path = os.path.join(model_dir, 'final_model.keras')
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~/miniconda3/envs/patents/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
# Data is a string of length 79145
# Data is a string of length 71634
# Data is a string of length 113746
# Data is a string of length 85087
# Data is a string of length 68539
# Data is a string of length 48134
# Data is a string of length 31306

# %%
predictions = model.predict(test_tf_dataset)
# Out:
# Data is a string of length 74466
# Data is a string of length 70203
# Data is a string of length 66217
# Data is a string of length 41435
# W0000 00:00:1722747076.526418 2293736 assert_op.cc:38] Ignoring Assert operator functional_1_1/bert_model_layer_1_1/tf_bert_model_2/bert/embeddings/assert_less/Assert/Assert
# W0000 00:00:1722747076.529821 2293736 assert_op.cc:38] Ignoring Assert operator functional_1_1/bert_model_layer_2/tf_bert_model_1/bert/embeddings/assert_less/Assert/Assert
#       1/Unknown 10s 10s/stepData is a string of length 79689
# Data is a string of length 116738
#       2/Unknown 12s 2s/step Data is a string of length 76258
#       3/Unknown 14s 2s/stepData is a string of length 92048
# Data is a string of length 99918
#       4/Unknown 17s 3s/stepData is a string of length 115843
# Data is a string of length 80657
#       5/Unknown 21s 3s/stepData is a string of length 119004
# Data is a string of length 232200
#       6/Unknown 24s 3s/stepData is a string of length 51929
# Data is a string of length 103652
#       7/Unknown 26s 3s/stepData is a string of length 49709
# Data is a string of length 58826
#       8/Unknown 29s 3s/stepData is a string of length 105344
# Data is a string of length 76603
#       9/Unknown 31s 3s/stepData is a string of length 92526
# Data is a string of length 100970
#      10/Unknown 36s 3s/stepData is a string of length 135458
# Data is a string of length 64801
#      11/Unknown 39s 3s/stepData is a string of length 151481
# Data is a string of length 270921
#      12/Unknown 41s 3s/stepData is a string of length 68232
# Data is a string of length 78184
#      13/Unknown 45s 3s/stepData is a string of length 210126
# Data is a string of length 27003
#      14/Unknown 48s 3s/stepData is a string of length 60115
# Data is a string of length 56269
#      15/Unknown 51s 3s/stepData is a string of length 141340
# Data is a string of length 40485
#      16/Unknown 54s 3s/stepData is a string of length 159294
# Data is a string of length 118542
#      17/Unknown 56s 3s/stepData is a string of length 81980
# Data is a string of length 95065
#      18/Unknown 61s 3s/stepData is a string of length 74770
# Data is a string of length 85396
#      19/Unknown 63s 3s/stepData is a string of length 49395
# Data is a string of length 120063
#      20/Unknown 65s 3s/stepData is a string of length 47647
# Data is a string of length 204205
#      21/Unknown 69s 3s/stepData is a string of length 26553
# Data is a string of length 102862
#      22/Unknown 73s 3s/stepData is a string of length 46405
# Data is a string of length 263700
#      23/Unknown 75s 3s/stepData is a string of length 113716
# Data is a string of length 48403
#      24/Unknown 78s 3s/stepData is a string of length 43636
# Data is a string of length 159685
#      25/Unknown 80s 3s/stepData is a string of length 52907
# Data is a string of length 115043
#      26/Unknown 90s 3s/stepData is a string of length 83637
# Data is a string of length 38241
#      27/Unknown 92s 3s/stepData is a string of length 65630
# Data is a string of length 113073
#      28/Unknown 96s 3s/stepData is a string of length 65687
# Data is a string of length 39265
#      29/Unknown 99s 3s/stepData is a string of length 120017
# Data is a string of length 196945
#      30/Unknown 103s 3s/stepData is a string of length 120977
# Data is a string of length 111020
#      31/Unknown 105s 3s/stepData is a string of length 94164
# Data is a string of length 71174
#      32/Unknown 109s 3s/stepData is a string of length 47236
# Data is a string of length 62986
#      33/Unknown 111s 3s/stepData is a string of length 98657
# Data is a string of length 79923
#      34/Unknown 114s 3s/stepData is a string of length 53258
# Data is a string of length 99229
#      35/Unknown 118s 3s/stepData is a string of length 113391
# Data is a string of length 64778
#      36/Unknown 122s 3s/stepData is a string of length 259878
# Data is a string of length 92031
#      37/Unknown 124s 3s/stepData is a string of length 46641
# Data is a string of length 68288
#      38/Unknown 127s 3s/stepData is a string of length 58253
# Data is a string of length 206720
#      39/Unknown 134s 3s/stepData is a string of length 92500
# Data is a string of length 116428
#      40/Unknown 137s 3s/stepData is a string of length 91933
# Data is a string of length 68527
#      41/Unknown 140s 3s/stepData is a string of length 160835
# Data is a string of length 103807
#      42/Unknown 142s 3s/stepData is a string of length 82254
# Data is a string of length 81002
#      43/Unknown 145s 3s/stepData is a string of length 133188
# Data is a string of length 113615
#      44/Unknown 147s 3s/stepData is a string of length 49457
# Data is a string of length 87575
#      45/Unknown 151s 3s/stepData is a string of length 106844
# Data is a string of length 100206
#      46/Unknown 160s 3s/stepData is a string of length 98595
# Data is a string of length 65875
#      47/Unknown 163s 3s/stepData is a string of length 28222
# Data is a string of length 55868
#      48/Unknown 166s 3s/stepData is a string of length 41938
# Data is a string of length 61754
#      49/Unknown 168s 3s/stepData is a string of length 71730
# Data is a string of length 157618
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2003072290 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 68686
#      50/Unknown 171s 3s/stepData is a string of length 82213
# Data is a string of length 61142
#      51/Unknown 175s 3s/stepData is a string of length 95912
# Data is a string of length 97021
#      52/Unknown 178s 3s/stepData is a string of length 77245
# Data is a string of length 40738
#      53/Unknown 181s 3s/stepData is a string of length 83864
# Data is a string of length 198585
#      54/Unknown 183s 3s/stepData is a string of length 38033
# Data is a string of length 172116
#      55/Unknown 186s 3s/stepData is a string of length 216590
# Data is a string of length 47158
#      56/Unknown 188s 3s/stepData is a string of length 108502
# Data is a string of length 131347
#      57/Unknown 190s 3s/stepData is a string of length 316083
# Data is a string of length 73366
#      58/Unknown 194s 3s/stepData is a string of length 41987
# Data is a string of length 110803
#      59/Unknown 196s 3s/stepData is a string of length 76058
# Data is a string of length 66684
#      60/Unknown 199s 3s/stepData is a string of length 37180
# Data is a string of length 47645
#      61/Unknown 201s 3s/stepData is a string of length 30413
# Data is a string of length 62496
#      62/Unknown 204s 3s/stepData is a string of length 84860
# Data is a string of length 71580
#      63/Unknown 208s 3s/stepData is a string of length 58752
# Data is a string of length 52048
#      64/Unknown 210s 3s/stepData is a string of length 160925
# Data is a string of length 51937
#      65/Unknown 212s 3s/stepData is a string of length 65591
# Data is a string of length 162861
#      66/Unknown 215s 3s/stepData is a string of length 102211
# Data is a string of length 76482
#      67/Unknown 219s 3s/stepData is a string of length 180994
# Data is a string of length 146310
#      68/Unknown 223s 3s/stepData is a string of length 50196
# Data is a string of length 195677
#      69/Unknown 226s 3s/stepData is a string of length 47980
# Data is a string of length 185625
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: CN110521146 A,Standard=TS 33.501.501die to empty text.
# Data is a string of length 96904
#      70/Unknown 228s 3s/stepData is a string of length 43086
# Data is a string of length 173725
#      71/Unknown 231s 3s/stepData is a string of length 69435
# Data is a string of length 91003
#      72/Unknown 234s 3s/stepData is a string of length 103230
# Data is a string of length 46349
#      73/Unknown 238s 3s/stepData is a string of length 57884
# Data is a string of length 83341
#      74/Unknown 242s 3s/stepData is a string of length 95185
# Data is a string of length 67936
#      75/Unknown 246s 3s/stepData is a string of length 123531
# Data is a string of length 68362
#      76/Unknown 249s 3s/stepData is a string of length 103658
# Data is a string of length 92301
#      77/Unknown 252s 3s/stepData is a string of length 84021
# Data is a string of length 86533
#      78/Unknown 254s 3s/stepData is a string of length 118791
# Data is a string of length 53379
#      79/Unknown 258s 3s/stepData is a string of length 93335
# Data is a string of length 90601
#      80/Unknown 261s 3s/stepData is a string of length 73497
# Data is a string of length 33822
#      81/Unknown 263s 3s/stepData is a string of length 76423
# Data is a string of length 56162
#      82/Unknown 265s 3s/stepData is a string of length 61629
# Data is a string of length 104515
#      83/Unknown 268s 3s/stepData is a string of length 35673
# Data is a string of length 126824
#      84/Unknown 270s 3s/stepData is a string of length 101990
# Data is a string of length 111196
#      85/Unknown 273s 3s/stepData is a string of length 38477
# Data is a string of length 35724
#      86/Unknown 276s 3s/stepData is a string of length 21393
# Data is a string of length 93214
#      87/Unknown 278s 3s/stepData is a string of length 44513
# Data is a string of length 92686
#      88/Unknown 280s 3s/stepData is a string of length 129617
# Data is a string of length 88257
#      89/Unknown 283s 3s/stepData is a string of length 70967
# Data is a string of length 73027
#      90/Unknown 285s 3s/stepData is a string of length 45490
# Data is a string of length 75978
#      91/Unknown 287s 3s/stepData is a string of length 111066
# Data is a string of length 74381
#      92/Unknown 292s 3s/stepData is a string of length 349353
# Data is a string of length 49861
#      93/Unknown 294s 3s/stepData is a string of length 65525
# Data is a string of length 92929
#      94/Unknown 296s 3s/stepData is a string of length 53521
# Data is a string of length 38550
#      95/Unknown 299s 3s/stepData is a string of length 113219
# Data is a string of length 77799
#      96/Unknown 302s 3s/stepData is a string of length 119310
# Data is a string of length 97451
#      97/Unknown 304s 3s/stepData is a string of length 90882
# Data is a string of length 106520
#      98/Unknown 307s 3s/stepData is a string of length 131657
# Data is a string of length 88986
#      99/Unknown 331s 3s/stepData is a string of length 209119
# Data is a string of length 26333
#     100/Unknown 334s 3s/stepData is a string of length 139214
# Data is a string of length 63804
#     101/Unknown 336s 3s/stepData is a string of length 60431
# Data is a string of length 67136
#     102/Unknown 339s 3s/stepData is a string of length 95303
# Data is a string of length 93220
#     103/Unknown 341s 3s/stepData is a string of length 73144
# Data is a string of length 64780
#     104/Unknown 343s 3s/stepData is a string of length 35213
# Data is a string of length 154177
#     105/Unknown 346s 3s/stepData is a string of length 169921
# Data is a string of length 64295
#     106/Unknown 351s 3s/stepData is a string of length 86142
# Data is a string of length 119599
#     107/Unknown 354s 3s/stepData is a string of length 81821
# Data is a string of length 63141
#     108/Unknown 356s 3s/stepData is a string of length 71248
# Data is a string of length 27713
#     109/Unknown 359s 3s/stepData is a string of length 73588
# Data is a string of length 84244
#     110/Unknown 362s 3s/stepData is a string of length 92258
# Data is a string of length 50091
#     111/Unknown 365s 3s/stepData is a string of length 59351
# Data is a string of length 77047
#     112/Unknown 368s 3s/stepData is a string of length 66215
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US11337228 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 146319
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US8850203 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 77140
# Data is a string of length 238754
#     113/Unknown 373s 3s/stepData is a string of length 115650
# Data is a string of length 41056
#     114/Unknown 376s 3s/stepData is a string of length 84692
# Data is a string of length 71638
#     115/Unknown 380s 3s/stepData is a string of length 36852
# Data is a string of length 118853
#     116/Unknown 385s 3s/stepData is a string of length 53044
# Data is a string of length 78365
#     117/Unknown 388s 3s/stepData is a string of length 48155
# Data is a string of length 124137
#     118/Unknown 391s 3s/stepData is a string of length 128846
# Data is a string of length 113760
#     119/Unknown 395s 3s/stepData is a string of length 36400
# Data is a string of length 44125
#     120/Unknown 399s 3s/stepData is a string of length 61187
# Data is a string of length 206348
#     121/Unknown 402s 3s/stepData is a string of length 91440
# Data is a string of length 56821
#     122/Unknown 404s 3s/stepData is a string of length 104863
# Data is a string of length 175965
#     123/Unknown 407s 3s/stepData is a string of length 79150
# Data is a string of length 41422
#     124/Unknown 410s 3s/stepData is a string of length 141380
# Data is a string of length 120276
#     125/Unknown 414s 3s/stepData is a string of length 57544
# Data is a string of length 163950
#     126/Unknown 417s 3s/stepData is a string of length 174624
# Data is a string of length 90490
#     127/Unknown 421s 3s/stepData is a string of length 103570
# Data is a string of length 43917
#     128/Unknown 423s 3s/stepData is a string of length 130750
# Data is a string of length 163523
#     129/Unknown 428s 3s/stepData is a string of length 56461
# Data is a string of length 146179
#     130/Unknown 430s 3s/stepData is a string of length 97627
# Data is a string of length 79202
#     131/Unknown 432s 3s/stepData is a string of length 121329
# Data is a string of length 94794
#     132/Unknown 435s 3s/stepData is a string of length 52352
# Data is a string of length 61498
#     133/Unknown 438s 3s/stepData is a string of length 31936
# Data is a string of length 39121
#     134/Unknown 440s 3s/stepData is a string of length 44850
# Data is a string of length 57123
#     135/Unknown 442s 3s/stepData is a string of length 63316
# Data is a string of length 169215
#     136/Unknown 446s 3s/stepData is a string of length 255282
# Data is a string of length 52696
#     137/Unknown 448s 3s/stepData is a string of length 109600
# Data is a string of length 53959
#     138/Unknown 451s 3s/stepData is a string of length 88910
# Data is a string of length 67149
#     139/Unknown 454s 3s/stepData is a string of length 73478
# Data is a string of length 98407
#     140/Unknown 473s 3s/stepData is a string of length 55549
# Data is a string of length 88002
#     141/Unknown 475s 3s/stepData is a string of length 56055
# Data is a string of length 115527
#     142/Unknown 478s 3s/stepData is a string of length 109409
# Data is a string of length 115527
#     143/Unknown 482s 3s/stepData is a string of length 118056
# Data is a string of length 101577
#     144/Unknown 484s 3s/stepData is a string of length 42861
# Data is a string of length 78500
#     145/Unknown 491s 3s/stepData is a string of length 37835
# Data is a string of length 62584
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2017055152 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 100755
#     146/Unknown 494s 3s/stepData is a string of length 69901
# Data is a string of length 125914
#     147/Unknown 497s 3s/stepData is a string of length 35724
# Data is a string of length 82479
#     148/Unknown 500s 3s/stepData is a string of length 368802
# Data is a string of length 129253
#     149/Unknown 502s 3s/stepData is a string of length 38102
# Data is a string of length 36927
#     150/Unknown 510s 3s/stepData is a string of length 74771
# Data is a string of length 54302
#     151/Unknown 512s 3s/stepData is a string of length 86071
# Data is a string of length 64582
#     152/Unknown 515s 3s/stepData is a string of length 61646
# Data is a string of length 96764
#     153/Unknown 517s 3s/stepData is a string of length 67788
# Data is a string of length 89261
#     154/Unknown 522s 3s/stepData is a string of length 105656
# Data is a string of length 34450
#     155/Unknown 525s 3s/stepData is a string of length 80490
# Data is a string of length 68642
#     156/Unknown 527s 3s/stepData is a string of length 84447
# Data is a string of length 52519
#     157/Unknown 529s 3s/stepData is a string of length 153871
# Data is a string of length 93761
#     158/Unknown 532s 3s/stepData is a string of length 115415
# Data is a string of length 61049
#     159/Unknown 535s 3s/stepData is a string of length 63581
# Data is a string of length 71340
#     160/Unknown 537s 3s/stepData is a string of length 112228
# Data is a string of length 111580
#     161/Unknown 539s 3s/stepData is a string of length 114197
# Data is a string of length 43515
#     162/Unknown 542s 3s/stepData is a string of length 43001
# Data is a string of length 78418
#     163/Unknown 544s 3s/stepData is a string of length 98656
# Data is a string of length 37236
#     164/Unknown 547s 3s/stepData is a string of length 82669
# Data is a string of length 50063
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2022104021 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 53586
#     165/Unknown 549s 3s/stepData is a string of length 59343
# Data is a string of length 50146
#     166/Unknown 552s 3s/stepData is a string of length 57472
# Data is a string of length 65329
#     167/Unknown 555s 3s/stepData is a string of length 42437
# Data is a string of length 82407
#     168/Unknown 557s 3s/stepData is a string of length 72756
# Data is a string of length 62029
#     169/Unknown 560s 3s/stepData is a string of length 45738
# Data is a string of length 80144
#     170/Unknown 564s 3s/stepData is a string of length 66705
# Data is a string of length 80619
#     171/Unknown 568s 3s/stepData is a string of length 117272
# Data is a string of length 57749
#     172/Unknown 570s 3s/stepData is a string of length 71331
# Data is a string of length 51838
#     173/Unknown 574s 3s/stepData is a string of length 60473
# Data is a string of length 56194
#     174/Unknown 578s 3s/stepData is a string of length 108815
# Data is a string of length 76268
#     175/Unknown 581s 3s/stepData is a string of length 99311
# Data is a string of length 46449
#     176/Unknown 583s 3s/stepData is a string of length 137885
# Data is a string of length 45856
#     177/Unknown 585s 3s/stepData is a string of length 40583
# Data is a string of length 230108
#     178/Unknown 591s 3s/stepData is a string of length 77581
# Data is a string of length 218579
#     179/Unknown 593s 3s/stepData is a string of length 59714
# Data is a string of length 115253
#     180/Unknown 595s 3s/stepData is a string of length 104024
# Data is a string of length 58244
#     181/Unknown 601s 3s/stepData is a string of length 146140
# Data is a string of length 55289
#     182/Unknown 603s 3s/stepData is a string of length 357556
# Data is a string of length 90429
#     183/Unknown 606s 3s/stepData is a string of length 85682
# Data is a string of length 67201
#     184/Unknown 609s 3s/stepData is a string of length 60728
# Data is a string of length 204055
#     185/Unknown 611s 3s/stepData is a string of length 95379
# Data is a string of length 155374
#     186/Unknown 613s 3s/stepData is a string of length 41909
# Data is a string of length 129201
#     187/Unknown 617s 3s/stepData is a string of length 62804
# Data is a string of length 65746
#     188/Unknown 620s 3s/stepData is a string of length 95035
# Data is a string of length 90327
#     189/Unknown 622s 3s/stepData is a string of length 105508
# Data is a string of length 344211
#     190/Unknown 626s 3s/stepData is a string of length 93107
# Data is a string of length 91621
#     191/Unknown 629s 3s/stepData is a string of length 79122
# Data is a string of length 128892
#     192/Unknown 632s 3s/stepData is a string of length 37343
# Data is a string of length 147031
#     193/Unknown 635s 3s/stepData is a string of length 37163
# Data is a string of length 73340
#     194/Unknown 637s 3s/stepData is a string of length 34852
# Data is a string of length 52440
#     195/Unknown 639s 3s/stepData is a string of length 60305
# Data is a string of length 84466
#     196/Unknown 642s 3s/stepData is a string of length 158371
# Data is a string of length 140725
#     197/Unknown 647s 3s/stepData is a string of length 43493
# Data is a string of length 61636
#     198/Unknown 653s 3s/stepData is a string of length 87469
# Data is a string of length 149366
#     199/Unknown 655s 3s/stepData is a string of length 38843
# Data is a string of length 48357
#     200/Unknown 658s 3s/stepData is a string of length 94461
# Data is a string of length 220296
#     201/Unknown 661s 3s/stepData is a string of length 102275
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2016294811 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 97243
# Data is a string of length 43515
#     202/Unknown 663s 3s/stepData is a string of length 47725
# Data is a string of length 46225
#     203/Unknown 666s 3s/stepData is a string of length 39761
# Data is a string of length 61177
#     204/Unknown 668s 3s/stepData is a string of length 73158
# Data is a string of length 87406
#     205/Unknown 671s 3s/stepData is a string of length 65768
# Data is a string of length 56633
#     206/Unknown 673s 3s/stepData is a string of length 26738
# Data is a string of length 51481
#     207/Unknown 675s 3s/stepData is a string of length 102361
# Data is a string of length 106871
#     208/Unknown 678s 3s/stepData is a string of length 75155
# Data is a string of length 76122
#     209/Unknown 681s 3s/stepData is a string of length 75272
# Data is a string of length 70040
#     210/Unknown 684s 3s/stepData is a string of length 19765
# Data is a string of length 160498
#     211/Unknown 686s 3s/stepData is a string of length 55758
# Data is a string of length 71231
#     212/Unknown 689s 3s/stepData is a string of length 114218
# Data is a string of length 91072
#     213/Unknown 693s 3s/stepData is a string of length 128230
# Data is a string of length 133825
#     214/Unknown 696s 3s/stepData is a string of length 53434
# Data is a string of length 53963
#     215/Unknown 698s 3s/stepData is a string of length 67443
# Data is a string of length 72414
#     216/Unknown 700s 3s/stepData is a string of length 31805
# Data is a string of length 104305
#     217/Unknown 703s 3s/stepData is a string of length 61222
# Data is a string of length 69127
#     218/Unknown 705s 3s/stepData is a string of length 139263
# Data is a string of length 336404
#     219/Unknown 708s 3s/stepData is a string of length 51168
# Data is a string of length 266892
#     220/Unknown 710s 3s/stepData is a string of length 71352
# Data is a string of length 52222
#     221/Unknown 712s 3s/stepData is a string of length 50536
# Data is a string of length 57660
#     222/Unknown 715s 3s/stepData is a string of length 71076
# Data is a string of length 61524
#     223/Unknown 717s 3s/stepData is a string of length 90436
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.203/ does not exist.
#
# Skipping sample: US9660713 B2,Standard=TS 33.203.203die to empty text.
# Data is a string of length 56224
# Data is a string of length 33146
#     224/Unknown 721s 3s/stepData is a string of length 30489
# Data is a string of length 238109
#     225/Unknown 725s 3s/stepData is a string of length 175315
# Data is a string of length 60738
#     226/Unknown 727s 3s/stepData is a string of length 60773
# Data is a string of length 112821
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US10299115 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 65329
#     227/Unknown 730s 3s/stepData is a string of length 75461
# Data is a string of length 94799
#     228/Unknown 732s 3s/stepData is a string of length 51589
# Data is a string of length 25995
#     229/Unknown 734s 3s/stepData is a string of length 184530
# Data is a string of length 68493
#     230/Unknown 740s 3s/stepData is a string of length 53807
# Data is a string of length 83134
#     231/Unknown 743s 3s/stepData is a string of length 95659
# Data is a string of length 102570
#     232/Unknown 746s 3s/stepData is a string of length 81061
# Data is a string of length 116496
#     233/Unknown 748s 3s/stepData is a string of length 78272
# Data is a string of length 79773
#     234/Unknown 752s 3s/stepData is a string of length 76929
# Data is a string of length 80286
#     235/Unknown 754s 3s/stepData is a string of length 187814
# Data is a string of length 66390
#     236/Unknown 756s 3s/stepData is a string of length 58359
# Data is a string of length 144165
#     237/Unknown 760s 3s/stepData is a string of length 154172
# Data is a string of length 49038
#     238/Unknown 762s 3s/stepData is a string of length 65253
# Data is a string of length 173602
#     239/Unknown 765s 3s/stepData is a string of length 89551
# Data is a string of length 88809
#     240/Unknown 767s 3s/stepData is a string of length 145506
# Data is a string of length 33677
#     241/Unknown 769s 3s/stepData is a string of length 246961
# Data is a string of length 90292
#     242/Unknown 775s 3s/stepData is a string of length 69701
# Data is a string of length 71640
#     243/Unknown 779s 3s/stepData is a string of length 36590
# Data is a string of length 107893
#     244/Unknown 782s 3s/stepData is a string of length 190690
# Data is a string of length 58831
#     245/Unknown 784s 3s/stepData is a string of length 95035
# Data is a string of length 55154
#     246/Unknown 800s 3s/stepData is a string of length 54145
# Data is a string of length 102766
#     247/Unknown 804s 3s/stepData is a string of length 164183
# Data is a string of length 67525
#     248/Unknown 806s 3s/stepData is a string of length 74118
# Data is a string of length 68885
#     249/Unknown 810s 3s/stepData is a string of length 97631
# Data is a string of length 98177
#     250/Unknown 812s 3s/stepData is a string of length 53380
# Data is a string of length 66994
#     251/Unknown 814s 3s/stepData is a string of length 114057
# Data is a string of length 156297
#     252/Unknown 817s 3s/stepData is a string of length 142562
# Data is a string of length 290922
#     253/Unknown 825s 3s/stepData is a string of length 102491
# Data is a string of length 230585
#     254/Unknown 829s 3s/stepData is a string of length 67172
# Data is a string of length 115030
#     255/Unknown 831s 3s/stepData is a string of length 79690
# Data is a string of length 115453
#     256/Unknown 834s 3s/stepData is a string of length 49521
# Data is a string of length 153898
#     257/Unknown 836s 3s/stepData is a string of length 45734
# Data is a string of length 82836
#     258/Unknown 840s 3s/stepData is a string of length 73743
# Data is a string of length 94452
#     259/Unknown 842s 3s/stepData is a string of length 82429
# Data is a string of length 143824
#     260/Unknown 845s 3s/stepData is a string of length 54105
# Data is a string of length 94414
#     261/Unknown 848s 3s/stepData is a string of length 51397
# Data is a string of length 58517
#     262/Unknown 851s 3s/stepData is a string of length 79581
# Data is a string of length 59482
#     263/Unknown 853s 3s/stepData is a string of length 90167
# Data is a string of length 122828
#     264/Unknown 855s 3s/stepData is a string of length 116734
# Data is a string of length 71710
#     265/Unknown 858s 3s/stepData is a string of length 89353
# Data is a string of length 52519
#     266/Unknown 860s 3s/stepData is a string of length 119670
# Data is a string of length 84395
#     267/Unknown 863s 3s/stepData is a string of length 102519
# Data is a string of length 212896
#     268/Unknown 865s 3s/stepData is a string of length 48546
# Data is a string of length 183976
#     269/Unknown 869s 3s/stepData is a string of length 67045
# Data is a string of length 139548
#     270/Unknown 871s 3s/stepData is a string of length 121852
# Data is a string of length 138310
#     271/Unknown 875s 3s/stepData is a string of length 241601
# Data is a string of length 110203
#     272/Unknown 879s 3s/stepData is a string of length 36964
# Data is a string of length 105441
#     273/Unknown 882s 3s/stepData is a string of length 97353
# Data is a string of length 33183
#     274/Unknown 887s 3s/stepData is a string of length 59120
# Data is a string of length 84198
#     275/Unknown 889s 3s/stepData is a string of length 79738
# Data is a string of length 47590
#     276/Unknown 891s 3s/stepData is a string of length 33804
# Data is a string of length 67198
#     277/Unknown 894s 3s/stepData is a string of length 78495
# Data is a string of length 66762
#     278/Unknown 898s 3s/stepData is a string of length 115300
# Data is a string of length 59376
#     279/Unknown 900s 3s/stepData is a string of length 107212
# Data is a string of length 46468
#     280/Unknown 903s 3s/stepData is a string of length 69959
# Data is a string of length 34580
#     281/Unknown 906s 3s/stepData is a string of length 144289
# Data is a string of length 196158
#     282/Unknown 908s 3s/stepData is a string of length 140077
# Data is a string of length 78850
#     283/Unknown 911s 3s/stepData is a string of length 89225
# Data is a string of length 83221
#     284/Unknown 914s 3s/stepData is a string of length 57749
# Data is a string of length 64680
#     285/Unknown 917s 3s/stepData is a string of length 79510
# Data is a string of length 55594
#     286/Unknown 919s 3s/stepData is a string of length 57665
# Data is a string of length 53809
#     287/Unknown 923s 3s/stepData is a string of length 99597
# Data is a string of length 65919
#     288/Unknown 926s 3s/stepData is a string of length 50603
# Data is a string of length 42917
#     289/Unknown 930s 3s/stepData is a string of length 54622
# Data is a string of length 158371
#     290/Unknown 933s 3s/stepData is a string of length 112952
# Data is a string of length 57836
#     291/Unknown 937s 3s/stepData is a string of length 53705
# Data is a string of length 59731
#     292/Unknown 940s 3s/stepData is a string of length 86154
# Data is a string of length 116739
#     293/Unknown 946s 3s/stepData is a string of length 43900
# Data is a string of length 76750
#     294/Unknown 948s 3s/stepData is a string of length 349919
# Data is a string of length 63363
#     295/Unknown 954s 3s/stepData is a string of length 58344
# Data is a string of length 100693
#     296/Unknown 956s 3s/stepData is a string of length 101993
# Data is a string of length 157431
#     297/Unknown 959s 3s/stepData is a string of length 63243
# Data is a string of length 120659
#     298/Unknown 962s 3s/stepData is a string of length 80896
# Data is a string of length 155243
#     299/Unknown 965s 3s/stepData is a string of length 53342
# Data is a string of length 58287
#     300/Unknown 968s 3s/stepData is a string of length 39972
# Data is a string of length 73288
#     301/Unknown 971s 3s/stepData is a string of length 108766
# Data is a string of length 128340
#     302/Unknown 973s 3s/stepData is a string of length 122505
# Data is a string of length 126588
#     303/Unknown 980s 3s/stepData is a string of length 44676
# Data is a string of length 61136
#     304/Unknown 987s 3s/stepData is a string of length 83946
# Data is a string of length 46021
#     305/Unknown 990s 3s/stepData is a string of length 87133
# Data is a string of length 178158
#     306/Unknown 993s 3s/stepData is a string of length 93128
# Data is a string of length 53859
#     307/Unknown 996s 3s/stepData is a string of length 60345
# Data is a string of length 60972
#     308/Unknown 999s 3s/stepData is a string of length 56055
# Data is a string of length 70747
#     309/Unknown 1002s 3s/stepData is a string of length 71630
# Data is a string of length 89157
#     310/Unknown 1004s 3s/stepData is a string of length 132233
# Data is a string of length 72223
#     311/Unknown 1008s 3s/stepData is a string of length 104462
# Data is a string of length 57256
#     312/Unknown 1012s 3s/stepData is a string of length 143776
# Data is a string of length 91916
#     313/Unknown 1014s 3s/stepData is a string of length 92889
# Data is a string of length 53284
#     314/Unknown 1017s 3s/stepData is a string of length 81703
# Data is a string of length 38516
#     315/Unknown 1019s 3s/stepData is a string of length 104171
# Data is a string of length 42255
#     316/Unknown 1022s 3s/stepData is a string of length 73689
# Data is a string of length 55146
#     317/Unknown 1025s 3s/stepData is a string of length 60577
# Data is a string of length 63666
#     318/Unknown 1029s 3s/stepData is a string of length 61483
# Data is a string of length 59468
#     319/Unknown 1032s 3s/stepData is a string of length 176668
# Data is a string of length 77113
#     320/Unknown 1036s 3s/stepData is a string of length 97497
# Data is a string of length 53420
#     321/Unknown 1038s 3s/stepData is a string of length 66747
# Data is a string of length 36103
#     322/Unknown 1044s 3s/stepData is a string of length 215273
# Data is a string of length 51348
#     323/Unknown 1047s 3s/stepData is a string of length 38209
# Data is a string of length 65668
#     324/Unknown 1049s 3s/stepData is a string of length 81291
# Data is a string of length 36669
#     325/Unknown 1053s 3s/stepData is a string of length 54024
# Data is a string of length 93492
#     326/Unknown 1055s 3s/stepData is a string of length 45101
# Data is a string of length 111348
#     327/Unknown 1057s 3s/stepData is a string of length 82957
# Data is a string of length 60690
#     328/Unknown 1060s 3s/stepData is a string of length 217373
# Data is a string of length 76594
#     329/Unknown 1062s 3s/stepData is a string of length 55945
# Data is a string of length 118194
#     330/Unknown 1065s 3s/stepData is a string of length 66496
# Data is a string of length 82106
#     331/Unknown 1074s 3s/stepData is a string of length 105995
# Data is a string of length 64947
#     332/Unknown 1077s 3s/stepData is a string of length 83717
# Data is a string of length 40231
#     333/Unknown 1079s 3s/stepData is a string of length 140079
# Data is a string of length 82054
#     334/Unknown 1082s 3s/stepData is a string of length 120063
# Data is a string of length 103658
#     335/Unknown 1084s 3s/stepData is a string of length 42461
# Data is a string of length 72320
#     336/Unknown 1087s 3s/stepData is a string of length 60660
# Data is a string of length 440272
#     337/Unknown 1090s 3s/stepData is a string of length 137846
# Data is a string of length 73891
#     338/Unknown 1094s 3s/stepData is a string of length 109407
# Data is a string of length 115381
#     339/Unknown 1097s 3s/stepData is a string of length 88851
# Data is a string of length 22445
#     340/Unknown 1099s 3s/stepData is a string of length 67451
# Data is a string of length 64446
#     341/Unknown 1101s 3s/stepData is a string of length 79548
# Data is a string of length 109301
#     342/Unknown 1104s 3s/stepData is a string of length 121167
# Data is a string of length 96780
#     343/Unknown 1106s 3s/stepData is a string of length 126452
# Data is a string of length 262085
#     344/Unknown 1110s 3s/stepData is a string of length 82085
# Data is a string of length 89415
#     345/Unknown 1112s 3s/stepData is a string of length 83249
# Data is a string of length 106037
#     346/Unknown 1116s 3s/stepData is a string of length 102489
# Data is a string of length 108221
#     347/Unknown 1119s 3s/stepData is a string of length 120835
# Data is a string of length 113130
#     348/Unknown 1121s 3s/stepData is a string of length 84701
# Data is a string of length 159419
#     349/Unknown 1124s 3s/stepData is a string of length 52398
# Data is a string of length 70843
#     350/Unknown 1126s 3s/stepData is a string of length 129096
# Data is a string of length 101480
#     351/Unknown 1130s 3s/stepData is a string of length 82977
# Data is a string of length 278479
#     352/Unknown 1131s 3s/stepData is a string of length 49937
# Data is a string of length 128831
#     353/Unknown 1134s 3s/stepData is a string of length 67255
# Data is a string of length 91781
#     354/Unknown 1138s 3s/stepData is a string of length 50589
# Data is a string of length 65545
#     355/Unknown 1141s 3s/stepData is a string of length 167634
# Data is a string of length 73912
#     356/Unknown 1143s 3s/stepData is a string of length 119525
# Data is a string of length 75093
#     357/Unknown 1146s 3s/stepData is a string of length 149560
# Data is a string of length 51746
#     358/Unknown 1163s 3s/stepData is a string of length 163161
# Data is a string of length 166137
#     359/Unknown 1165s 3s/stepData is a string of length 81936
# Data is a string of length 46321
#     360/Unknown 1168s 3s/stepData is a string of length 65102
# Data is a string of length 98192
#     361/Unknown 1170s 3s/stepData is a string of length 97387
# Data is a string of length 69922
#     362/Unknown 1173s 3s/stepData is a string of length 66087
# Data is a string of length 83904
#     363/Unknown 1182s 3s/stepData is a string of length 78067
# Data is a string of length 81931
#     364/Unknown 1184s 3s/stepData is a string of length 47862
# Data is a string of length 58478
#     365/Unknown 1187s 3s/stepData is a string of length 98315
# Data is a string of length 43272
#     366/Unknown 1190s 3s/stepData is a string of length 101866
# Data is a string of length 71652
#     367/Unknown 1193s 3s/stepData is a string of length 101905
# Data is a string of length 52057
#     368/Unknown 1198s 3s/stepData is a string of length 102390
# Data is a string of length 62666
#     369/Unknown 1200s 3s/stepData is a string of length 128254
# Data is a string of length 124818
#     370/Unknown 1208s 3s/stepData is a string of length 60815
# Data is a string of length 78203
#     371/Unknown 1211s 3s/stepData is a string of length 39033
# Data is a string of length 194113
#     372/Unknown 1215s 3s/stepData is a string of length 118589
# Data is a string of length 26623
#     373/Unknown 1221s 3s/stepData is a string of length 68625
# Data is a string of length 62081
#     374/Unknown 1223s 3s/stepData is a string of length 94540
# Data is a string of length 71009
#     375/Unknown 1227s 3s/stepData is a string of length 80216
# Data is a string of length 183177
#     376/Unknown 1229s 3s/stepData is a string of length 228514
# Data is a string of length 74384
#     377/Unknown 1232s 3s/stepData is a string of length 143567
# Data is a string of length 66817
#     378/Unknown 1235s 3s/stepData is a string of length 91229
# Data is a string of length 35137
#     379/Unknown 1238s 3s/stepData is a string of length 118051
# Data is a string of length 276213
#     380/Unknown 1240s 3s/stepData is a string of length 52432
# Data is a string of length 63233
#     381/Unknown 1242s 3s/stepData is a string of length 44415
# Data is a string of length 72449
#     382/Unknown 1246s 3s/stepData is a string of length 85182
# Data is a string of length 62117
#     383/Unknown 1248s 3s/stepData is a string of length 104857
# Data is a string of length 42701
#     384/Unknown 1253s 3s/stepData is a string of length 74725
# Data is a string of length 194564
#     385/Unknown 1255s 3s/stepData is a string of length 90331
# Data is a string of length 119276
#     386/Unknown 1258s 3s/stepData is a string of length 67435
# Data is a string of length 68316
#     387/Unknown 1260s 3s/stepData is a string of length 124741
# Data is a string of length 98728
#     388/Unknown 1264s 3s/stepData is a string of length 73014
# Data is a string of length 38165
#     389/Unknown 1268s 3s/stepData is a string of length 68597
# Data is a string of length 254739
#     390/Unknown 1270s 3s/stepData is a string of length 45295
# Data is a string of length 68296
#     391/Unknown 1274s 3s/stepData is a string of length 145133
# Data is a string of length 46902
#     392/Unknown 1277s 3s/stepData is a string of length 241963
# Data is a string of length 70350
#     393/Unknown 1279s 3s/stepData is a string of length 266267
# Data is a string of length 119612
#     394/Unknown 1282s 3s/stepData is a string of length 159929
# Data is a string of length 70906
#     395/Unknown 1286s 3s/stepData is a string of length 94947
# Data is a string of length 40743
#     396/Unknown 1291s 3s/stepData is a string of length 149433
# Data is a string of length 68129
#     397/Unknown 1293s 3s/stepData is a string of length 81533
# Data is a string of length 119335
#     398/Unknown 1298s 3s/stepData is a string of length 150398
# Data is a string of length 68478
#     399/Unknown 1302s 3s/stepData is a string of length 47671
# Data is a string of length 105364
#     400/Unknown 1304s 3s/stepData is a string of length 66551
# Data is a string of length 117912
#     401/Unknown 1308s 3s/stepData is a string of length 43056
# Data is a string of length 59347
#     402/Unknown 1311s 3s/stepData is a string of length 103298
# Data is a string of length 59145
#     403/Unknown 1314s 3s/stepData is a string of length 69006
# Data is a string of length 42675
#     404/Unknown 1316s 3s/stepData is a string of length 145113
# Data is a string of length 102020
#     405/Unknown 1319s 3s/stepData is a string of length 49737
# Data is a string of length 61580
#     406/Unknown 1322s 3s/stepData is a string of length 71134
# Data is a string of length 81425
#     407/Unknown 1324s 3s/stepData is a string of length 282672
# Data is a string of length 39253
#     408/Unknown 1329s 3s/stepData is a string of length 94365
# Data is a string of length 55405
#     409/Unknown 1331s 3s/stepData is a string of length 70811
# Data is a string of length 123518
#     410/Unknown 1334s 3s/stepData is a string of length 113332
# Data is a string of length 88418
#     411/Unknown 1337s 3s/stepData is a string of length 80268
# Data is a string of length 62472
#     412/Unknown 1339s 3s/stepData is a string of length 178857
# Data is a string of length 52920
#     413/Unknown 1342s 3s/stepData is a string of length 67617
# Data is a string of length 39768
#     414/Unknown 1344s 3s/stepData is a string of length 58982
# Data is a string of length 96035
#     415/Unknown 1347s 3s/stepData is a string of length 69381
# Data is a string of length 64213
#     416/Unknown 1351s 3s/stepData is a string of length 73418
# Data is a string of length 73755
#     417/Unknown 1353s 3s/stepData is a string of length 98442
# Data is a string of length 107026
#     418/Unknown 1359s 3s/stepData is a string of length 139182
# Data is a string of length 117651
#     419/Unknown 1361s 3s/stepData is a string of length 94825
# Data is a string of length 306175
#     420/Unknown 1364s 3s/stepData is a string of length 61126
# Data is a string of length 67099
#     421/Unknown 1367s 3s/stepData is a string of length 157872
# Data is a string of length 60382
#     422/Unknown 1370s 3s/stepData is a string of length 82221
# Data is a string of length 141901
#     423/Unknown 1372s 3s/stepData is a string of length 97779
# Data is a string of length 133117
#     424/Unknown 1375s 3s/stepData is a string of length 53212
# Data is a string of length 51940
#     425/Unknown 1378s 3s/stepData is a string of length 71608
# Data is a string of length 47988
#     426/Unknown 1380s 3s/stepData is a string of length 46704
# Data is a string of length 86512
#     427/Unknown 1382s 3s/stepData is a string of length 68373
# Data is a string of length 90782
#     428/Unknown 1385s 3s/stepData is a string of length 86759
# Data is a string of length 83427
#     429/Unknown 1387s 3s/stepData is a string of length 81645
# Data is a string of length 160166
#     430/Unknown 1390s 3s/stepData is a string of length 112048
# Data is a string of length 56505
#     431/Unknown 1392s 3s/stepData is a string of length 93320
# Data is a string of length 65241
#     432/Unknown 1395s 3s/stepData is a string of length 108274
# Data is a string of length 86111
#     433/Unknown 1397s 3s/stepData is a string of length 88700
# Data is a string of length 55862
#     434/Unknown 1400s 3s/stepData is a string of length 72980
# Data is a string of length 98909
#     435/Unknown 1403s 3s/stepData is a string of length 83857
# Data is a string of length 106748
#     436/Unknown 1406s 3s/stepData is a string of length 41714
# Data is a string of length 51479
#     437/Unknown 1408s 3s/stepData is a string of length 59198
# Data is a string of length 79789
#     438/Unknown 1411s 3s/stepData is a string of length 100093
# Data is a string of length 43431
#     439/Unknown 1418s 3s/stepData is a string of length 65458
# Data is a string of length 121961
#     440/Unknown 1420s 3s/stepData is a string of length 53996
# Data is a string of length 107587
#     441/Unknown 1422s 3s/stepData is a string of length 61339
# Data is a string of length 74846
#     442/Unknown 1425s 3s/stepData is a string of length 189573
# Data is a string of length 42437
#     443/Unknown 1428s 3s/stepData is a string of length 73494
# Data is a string of length 410553
#     444/Unknown 1431s 3s/stepData is a string of length 75901
# Data is a string of length 121296
#     445/Unknown 1434s 3s/stepData is a string of length 196200
# Data is a string of length 87159
#     446/Unknown 1437s 3s/stepData is a string of length 70205
# Data is a string of length 91403
#     447/Unknown 1446s 3s/stepData is a string of length 111796
# Data is a string of length 51621
#     448/Unknown 1448s 3s/stepData is a string of length 45613
# Data is a string of length 48345
#     449/Unknown 1451s 3s/stepData is a string of length 182107
# Data is a string of length 111368
#     450/Unknown 1456s 3s/stepData is a string of length 64709
# Data is a string of length 63991
#     451/Unknown 1459s 3s/stepData is a string of length 86653
# Data is a string of length 113603
#     452/Unknown 1461s 3s/stepData is a string of length 71244
# Data is a string of length 57646
#     453/Unknown 1463s 3s/stepData is a string of length 236188
# Data is a string of length 91164
#     454/Unknown 1466s 3s/stepData is a string of length 76338
# Data is a string of length 152469
#     455/Unknown 1469s 3s/stepData is a string of length 103072
# Data is a string of length 57389
#     456/Unknown 1474s 3s/stepData is a string of length 177612
# Data is a string of length 62283
#     457/Unknown 1478s 3s/stepData is a string of length 34413
# Data is a string of length 84809
#     458/Unknown 1480s 3s/stepData is a string of length 80117
# Data is a string of length 99991
#     459/Unknown 1483s 3s/stepData is a string of length 85629
# Data is a string of length 138689
#     460/Unknown 1487s 3s/stepData is a string of length 81413
# Data is a string of length 87332
#     461/Unknown 1490s 3s/stepData is a string of length 45815
# Data is a string of length 53310
#     462/Unknown 1492s 3s/stepData is a string of length 94967
# Data is a string of length 42082
#     463/Unknown 1496s 3s/stepData is a string of length 43527
# Data is a string of length 135412
#     464/Unknown 1499s 3s/stepData is a string of length 38771
# Data is a string of length 75393
#     465/Unknown 1501s 3s/stepData is a string of length 100422
# Data is a string of length 72483
#     466/Unknown 1521s 3s/stepData is a string of length 63005
# Data is a string of length 60234
#     467/Unknown 1524s 3s/stepData is a string of length 46577
# Data is a string of length 43886
#     468/Unknown 1527s 3s/stepData is a string of length 143482
# Data is a string of length 54318
#     469/Unknown 1532s 3s/stepData is a string of length 81385
# Data is a string of length 77410
#     470/Unknown 1535s 3s/stepData is a string of length 84941
# Data is a string of length 62941
#     471/Unknown 1538s 3s/stepData is a string of length 68471
# Data is a string of length 83598
#     472/Unknown 1540s 3s/stepData is a string of length 73875
# Data is a string of length 44518
#     473/Unknown 1543s 3s/stepData is a string of length 38082
# Data is a string of length 95042
#     474/Unknown 1546s 3s/stepData is a string of length 90238
# Data is a string of length 113656
#     475/Unknown 1551s 3s/stepData is a string of length 93183
# Data is a string of length 180162
#     476/Unknown 1559s 3s/stepData is a string of length 78004
# Data is a string of length 136860
#     477/Unknown 1561s 3s/stepData is a string of length 31161
# Data is a string of length 175811
#     478/Unknown 1565s 3s/stepData is a string of length 74039
# Data is a string of length 123215
#     479/Unknown 1570s 3s/stepData is a string of length 109475
# Data is a string of length 88286
#     480/Unknown 1573s 3s/stepData is a string of length 97872
# Data is a string of length 116033
#     481/Unknown 1575s 3s/stepData is a string of length 116653
# Data is a string of length 74439
#     482/Unknown 1579s 3s/stepData is a string of length 45585
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.401/ does not exist.
#
# ...
# Data is a string of length 152106
#    9530/Unknown 33772s 4s/stepData is a string of length 87185
# Data is a string of length 48200
#    9531/Unknown 33776s 4s/stepData is a string of length 37233
# Data is a string of length 119409
#    9532/Unknown 33778s 4s/stepData is a string of length 68024
# Data is a string of length 179285
#    9533/Unknown 33780s 4s/stepData is a string of length 55334
# Data is a string of length 150585
#    9534/Unknown 33783s 4s/stepData is a string of length 131084
# Data is a string of length 84391
#    9535/Unknown 33787s 4s/stepData is a string of length 127792
#    9536/Unknown 33789s 4s/stepData is a string of length 123014
# Data is a string of length 101095
# Data is a string of length 101409
#    9537/Unknown 33791s 4s/stepData is a string of length 54846
# Data is a string of length 32626
#    9538/Unknown 33794s 4s/stepData is a string of length 212466
#    9539/Unknown 33798s 4s/stepData is a string of length 97032
# Data is a string of length 142471
# Data is a string of length 56452
#    9540/Unknown 33802s 4s/stepData is a string of length 84622
# Data is a string of length 62140
#    9541/Unknown 33806s 4s/stepData is a string of length 33635
# Data is a string of length 90150
#    9542/Unknown 33808s 4s/stepData is a string of length 42387
#    9543/Unknown 33810s 4s/stepData is a string of length 141343
# Data is a string of length 140460
# Data is a string of length 75289
#    9544/Unknown 33813s 4s/stepData is a string of length 74831
# Data is a string of length 37944
#    9545/Unknown 33816s 4s/stepData is a string of length 48245
#    9546/Unknown 33819s 4s/stepData is a string of length 142277
# Data is a string of length 105461
# Data is a string of length 85448
#    9547/Unknown 33821s 4s/stepData is a string of length 86676
# Data is a string of length 68241
#    9548/Unknown 33824s 4s/stepData is a string of length 147265
# Data is a string of length 63922
#    9549/Unknown 33828s 4s/stepData is a string of length 65532
# Data is a string of length 37322
#    9550/Unknown 33830s 4s/stepData is a string of length 106237
# Data is a string of length 174524
#    9551/Unknown 33833s 4s/stepData is a string of length 231186
#    9552/Unknown 33835s 4s/stepData is a string of length 53142
# Data is a string of length 56713
#    9553/Unknown 33838s 4s/stepData is a string of length 173469
# Data is a string of length 232476
# Data is a string of length 148169
#    9554/Unknown 33840s 4s/stepData is a string of length 55102
#    9555/Unknown 33843s 4s/stepData is a string of length 90009
# Data is a string of length 48886
# Data is a string of length 49667
#    9556/Unknown 33846s 4s/stepData is a string of length 27270
# Data is a string of length 65525
#    9557/Unknown 33848s 4s/stepData is a string of length 229219
# Data is a string of length 93662
#    9558/Unknown 33851s 4s/stepData is a string of length 70392
# Data is a string of length 75561
#    9559/Unknown 33853s 4s/stepData is a string of length 91239
# Data is a string of length 88888
#    9560/Unknown 33857s 4s/stepData is a string of length 154973
#    9561/Unknown 33859s 4s/stepData is a string of length 138001
# Data is a string of length 93321
# Data is a string of length 195120
#    9562/Unknown 33861s 4s/stepData is a string of length 86891
# Data is a string of length 66657
#    9563/Unknown 33865s 4s/stepData is a string of length 38310
#    9564/Unknown 33871s 4s/stepData is a string of length 99202
# Data is a string of length 104365
#    9565/Unknown 33875s 4s/stepData is a string of length 41473
# Data is a string of length 89573
#    9566/Unknown 33878s 4s/stepData is a string of length 84190
# Data is a string of length 87571
# Data is a string of length 94463
#    9567/Unknown 33880s 4s/stepData is a string of length 76401
#    9568/Unknown 33883s 4s/stepData is a string of length 95622
# Data is a string of length 96802
#    9569/Unknown 33886s 4s/stepData is a string of length 66814
# Data is a string of length 145476
# Data is a string of length 79551
#    9570/Unknown 33888s 4s/stepData is a string of length 109313
#    9571/Unknown 33892s 4s/stepData is a string of length 41566
# Data is a string of length 35609
#    9572/Unknown 33897s 4s/stepData is a string of length 29959
# Data is a string of length 60108
# Data is a string of length 145792
#    9573/Unknown 33899s 4s/stepData is a string of length 87801
# Data is a string of length 97349
#    9574/Unknown 33907s 4s/stepData is a string of length 73552
#    9575/Unknown 33909s 4s/stepData is a string of length 71225
# Data is a string of length 229952
# Data is a string of length 68539
#    9576/Unknown 33912s 4s/stepData is a string of length 117504
# Data is a string of length 49025
#    9577/Unknown 33915s 4s/stepData is a string of length 96811
# Data is a string of length 71599
#    9578/Unknown 33919s 4s/stepData is a string of length 60037
#    9579/Unknown 33922s 4s/stepData is a string of length 208397
# Data is a string of length 71422
#    9580/Unknown 33924s 4s/stepData is a string of length 295993
# Data is a string of length 69909
# Data is a string of length 76339
#    9581/Unknown 33927s 4s/stepData is a string of length 58623
#    9582/Unknown 33929s 4s/stepData is a string of length 80033
# Data is a string of length 184046
#    9583/Unknown 33934s 4s/stepData is a string of length 65316
# Data is a string of length 208812
# Data is a string of length 85994
#    9584/Unknown 33936s 4s/stepData is a string of length 43217
# Data is a string of length 84860
#    9585/Unknown 33938s 4s/stepData is a string of length 99013
# Data is a string of length 146932
#    9586/Unknown 33942s 4s/stepData is a string of length 98872
# Data is a string of length 219650
#    9587/Unknown 33944s 4s/stepData is a string of length 78282
# Data is a string of length 45439
#    9588/Unknown 33947s 4s/stepData is a string of length 140429
# Data is a string of length 99943
#    9589/Unknown 33950s 4s/stepData is a string of length 216869
# Data is a string of length 111270
#    9590/Unknown 33952s 4s/stepData is a string of length 56310
# Data is a string of length 149005
#    9591/Unknown 33957s 4s/stepData is a string of length 50987
#    9592/Unknown 33961s 4s/stepData is a string of length 85866
# Data is a string of length 44162
# Data is a string of length 139869
#    9593/Unknown 33964s 4s/stepData is a string of length 99030
#    9594/Unknown 33966s 4s/stepData is a string of length 156849
# Data is a string of length 83641
# Data is a string of length 88082
#    9595/Unknown 33968s 4s/stepData is a string of length 44606
#    9596/Unknown 33973s 4s/stepData is a string of length 100649
# Data is a string of length 166353
# Data is a string of length 38761
#    9597/Unknown 33976s 4s/stepData is a string of length 74313
# Data is a string of length 176393
#    9598/Unknown 33978s 4s/stepData is a string of length 49178
#    9599/Unknown 33981s 4s/stepData is a string of length 79785
# Data is a string of length 97041
# Data is a string of length 182428
#    9600/Unknown 33983s 4s/stepData is a string of length 124587
#    9601/Unknown 33987s 4s/stepData is a string of length 43636
# Data is a string of length 58920
# Data is a string of length 92027
#    9602/Unknown 33991s 4s/stepData is a string of length 68536
# Data is a string of length 142128
#    9603/Unknown 33995s 4s/stepData is a string of length 144637
# Data is a string of length 26515
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.402/ does not exist.
#
# Skipping sample: US2005003829 A1,Standard=TS 33.402.402die to empty text.
# Data is a string of length 109152
#    9604/Unknown 33998s 4s/stepData is a string of length 77657
# Data is a string of length 146270
#    9605/Unknown 34005s 4s/stepData is a string of length 95352
#    9606/Unknown 34007s 4s/stepData is a string of length 111093
# Data is a string of length 83592
# Data is a string of length 82804
#    9607/Unknown 34010s 4s/stepData is a string of length 56703
# Data is a string of length 68834
#    9608/Unknown 34013s 4s/stepData is a string of length 133417
# Data is a string of length 70768
#    9609/Unknown 34020s 4s/stepData is a string of length 55902
# Data is a string of length 146425
#    9610/Unknown 34022s 4s/stepData is a string of length 93536
#    9611/Unknown 34026s 4s/stepData is a string of length 79001
# Data is a string of length 58623
# Data is a string of length 100067
#    9612/Unknown 34028s 4s/stepData is a string of length 80007
# Data is a string of length 99964
#    9613/Unknown 34032s 4s/stepData is a string of length 95622
# Data is a string of length 51752
#    9614/Unknown 34035s 4s/stepData is a string of length 104610
# Data is a string of length 51408
#    9615/Unknown 34038s 4s/stepData is a string of length 129032
# Data is a string of length 152874
#    9616/Unknown 34041s 4s/stepData is a string of length 83549
# Data is a string of length 79542
#    9617/Unknown 34044s 4s/stepData is a string of length 79595
# Data is a string of length 107363
#    9618/Unknown 34047s 4s/stepData is a string of length 42060
# Data is a string of length 59464
#    9619/Unknown 34050s 4s/stepData is a string of length 79356
# Data is a string of length 47701
#    9620/Unknown 34053s 4s/stepData is a string of length 187814
# Data is a string of length 68849
#    9621/Unknown 34057s 4s/stepData is a string of length 150911
# Data is a string of length 179550
#    9622/Unknown 34059s 4s/stepData is a string of length 50136
# Data is a string of length 81309
#    9623/Unknown 34062s 4s/stepData is a string of length 48836
# Data is a string of length 167152
#    9624/Unknown 34064s 4s/stepData is a string of length 70892
#    9625/Unknown 34068s 4s/stepData is a string of length 146943
# Data is a string of length 109392
#    9626/Unknown 34072s 4s/stepData is a string of length 81632
# Data is a string of length 64887
# Data is a string of length 92239
#    9627/Unknown 34075s 4s/stepData is a string of length 149353
#    9628/Unknown 34078s 4s/stepData is a string of length 93986
# Data is a string of length 159890
# Data is a string of length 47566
#    9629/Unknown 34081s 4s/stepData is a string of length 83890
#    9630/Unknown 34083s 4s/stepData is a string of length 989034
# Data is a string of length 115144
# Data is a string of length 55338
#    9631/Unknown 34086s 4s/stepData is a string of length 85515
# Data is a string of length 84072
#    9632/Unknown 34089s 4s/stepData is a string of length 142761
#    9633/Unknown 34091s 4s/stepData is a string of length 97010
# Data is a string of length 40396
# Data is a string of length 95119
#    9634/Unknown 34094s 4s/stepData is a string of length 110003
# Data is a string of length 247697
#    9635/Unknown 34097s 4s/stepData is a string of length 70864
#    9636/Unknown 34100s 4s/stepData is a string of length 32970
# Data is a string of length 57400
# Data is a string of length 98731
#    9637/Unknown 34102s 4s/stepData is a string of length 184336
#    9638/Unknown 34106s 4s/stepData is a string of length 111335
# Data is a string of length 53578
# Data is a string of length 40542
#    9639/Unknown 34109s 4s/stepData is a string of length 48382
# Data is a string of length 47192
#    9640/Unknown 34111s 4s/stepData is a string of length 88114
# Data is a string of length 61304
#    9641/Unknown 34114s 4s/stepData is a string of length 55082
# Data is a string of length 34086
#    9642/Unknown 34118s 4s/stepData is a string of length 104664
# Data is a string of length 76633
#    9643/Unknown 34120s 4s/stepData is a string of length 70880
#    9644/Unknown 34124s 4s/stepData is a string of length 63502
# Data is a string of length 46614
# Data is a string of length 83221
#    9645/Unknown 34126s 4s/stepData is a string of length 70312
# Data is a string of length 103644
#    9646/Unknown 34129s 4s/stepData is a string of length 99892
# Data is a string of length 64079
#    9647/Unknown 34132s 4s/stepData is a string of length 62152
# Data is a string of length 47756
#    9648/Unknown 34134s 4s/stepData is a string of length 170127
# Data is a string of length 36563
#    9649/Unknown 34136s 4s/stepData is a string of length 64040
# Data is a string of length 78616
#    9650/Unknown 34139s 4s/stepData is a string of length 110128
# Data is a string of length 99305
#    9651/Unknown 34143s 4s/stepData is a string of length 158801
#    9652/Unknown 34145s 4s/stepData is a string of length 66694
# Data is a string of length 65095
# Data is a string of length 69372
#    9653/Unknown 34149s 4s/stepData is a string of length 226690
# Data is a string of length 47789
#    9654/Unknown 34151s 4s/stepData is a string of length 73477
#    9655/Unknown 34156s 4s/stepData is a string of length 106560
# Data is a string of length 91041
#    9656/Unknown 34159s 4s/stepData is a string of length 55902
# Data is a string of length 63531
# Data is a string of length 42749
#    9657/Unknown 34164s 4s/stepData is a string of length 53880
#    9658/Unknown 34168s 4s/stepData is a string of length 80474
# Data is a string of length 49405
#    9659/Unknown 34171s 4s/stepData is a string of length 93501
# Data is a string of length 146824
# Data is a string of length 66567
#    9660/Unknown 34175s 4s/stepData is a string of length 97298
#    9661/Unknown 34178s 4s/step
# Data is a string of length 94999
#    9662/Unknown 34183s 4s/stepData is a string of length 190990
# Data is a string of length 44570
# Data is a string of length 52722
#    9663/Unknown 34189s 4s/stepData is a string of length 64917
#    9664/Unknown 34191s 4s/stepData is a string of length 59040
# Data is a string of length 31016
# Data is a string of length 38323
#    9665/Unknown 34195s 4s/stepData is a string of length 115509
# Data is a string of length 255078
#    9666/Unknown 34197s 4s/stepData is a string of length 77070
#    9667/Unknown 34200s 4s/stepData is a string of length 141046
# Data is a string of length 78785
# Data is a string of length 75663
#    9668/Unknown 34202s 4s/stepData is a string of length 95068
# Data is a string of length 44048
#    9669/Unknown 34207s 4s/stepData is a string of length 97178
#    9670/Unknown 34224s 4s/stepData is a string of length 87014
# Data is a string of length 68081
# Data is a string of length 95298
#    9671/Unknown 34230s 4s/stepData is a string of length 112222
# Data is a string of length 52779
#    9672/Unknown 34233s 4s/stepData is a string of length 100510
# Data is a string of length 116153
#    9673/Unknown 34236s 4s/stepData is a string of length 77929
# Data is a string of length 57463
#    9674/Unknown 34240s 4s/stepData is a string of length 106402
# Data is a string of length 112161
#    9675/Unknown 34244s 4s/stepData is a string of length 193325
# Data is a string of length 110756
#    9676/Unknown 34246s 4s/stepData is a string of length 86085
# Data is a string of length 71138
#    9677/Unknown 34248s 4s/stepData is a string of length 34745
#    9678/Unknown 34251s 4s/stepData is a string of length 35259
# Data is a string of length 88257
#    9679/Unknown 34253s 4s/stepData is a string of length 129301
# Data is a string of length 62918
# Data is a string of length 127677
#    9680/Unknown 34256s 4s/stepData is a string of length 120124
# Data is a string of length 39507
#    9681/Unknown 34258s 4s/stepData is a string of length 137637
# Data is a string of length 107189
#    9682/Unknown 34260s 4s/step
# 2024-08-04 10:22:12.800518: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# W0000 00:00:1722781338.875325 2293734 assert_op.cc:38] Ignoring Assert operator functional_1_1/bert_model_layer_1_1/tf_bert_model_2/bert/embeddings/assert_less/Assert/Assert
# W0000 00:00:1722781338.877485 2293734 assert_op.cc:38] Ignoring Assert operator functional_1_1/bert_model_layer_2/tf_bert_model_1/bert/embeddings/assert_less/Assert/Assert
# 9683/9683 ━━━━━━━━━━━━━━━━━━━━ 34274s 4s/step
# /home/vignes/miniconda3/envs/patents/lib/python3.12/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 2024-08-04 10:22:23.882764: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
predictions
# Out:
# array([[0.39790002],
#        [0.39790002],
#        [0.39790002],
#        ...,
#        [0.39790002],
#        [0.39790002],
#        [0.39790002]], dtype=float32)
