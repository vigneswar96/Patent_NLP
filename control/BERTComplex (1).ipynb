# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate, Layer, Dropout, Reshape, GlobalAveragePooling1D, GlobalMaxPooling1D, Add
from tensorflow.keras.models import Model
from tensorflow import keras
from transformers import TFBertModel, AutoTokenizer
import tensorflow.keras.backend as K

# Document processing imports
from docx import Document
from PyPDF2 import PdfReader
import textract
import json
from pprint import pprint

# System and utility imports
import os
import subprocess
import chardet
import time
# Out:
# 2024-08-04 10:31:03.528599: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-04 10:31:04.702044: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# File Paths
tfrecord_file = '/home/vignes/Patent_Files/tfrecords/Dataset_json.tfrecord'
patent_folder = '/home/vignes/Patent_Files/zip-Patents/'
standard_folder = '/home/vignes/Patent_Files/Mount_Std/'

# %%
def extract_patent_text(patent_file):
    patent_text = ""
    json_file = patent_file + ".json"
    if os.path.isfile(json_file):
        try:
            with open(json_file, 'r', encoding='utf-8') as file:
                data = json.load(file)
                # print(f"Type of data in {json_file}: {type(data)}")
                if isinstance(data, dict):
                    if 'text' in data:
                        patent_text = data['text']
                    else:
                        print(f"Available keys in {json_file}: {data.keys()}")
                elif isinstance(data, list):
                    print(f"Data is a list with {len(data)} items")
                    if len(data) > 0:
                        print(f"Type of first item: {type(data[0])}")
                elif isinstance(data, str):
                    print(f"Data is a string of length {len(data)}")
                    patent_text = data
                else:
                    print(f"Unexpected data type in {json_file}: {type(data)}")
        except json.JSONDecodeError as e:
            print(f"JSON decoding error in {json_file}: {e}")
        except Exception as e:
            print(f"Error reading {json_file}: {e}")
    else:
        print(f"File not found: {json_file}")
    
    return patent_text

def extract_docx_text(docx_file):
    try:
        doc = Document(docx_file)
        return '\n'.join([paragraph.text for paragraph in doc.paragraphs])
    except Exception as e:
        print(f"Exception during DOCX text extraction: {e}")
    return ""

def extract_doc_text(doc_file):
    try:
        command = f"antiword '{doc_file}'"
        result = subprocess.run(command, shell=True, capture_output=True, text=True)
        if result.returncode == 0:
            return result.stdout
        else:
            raise Exception(f"antiword failed: {result.stderr}")
    except Exception as e:
        print(f"Exception during DOC text extraction: {e}")
    return ""

def extract_text(file_path):
    if file_path.endswith('.docx'):
        return extract_docx_text(file_path)
    elif file_path.endswith('.doc'):
        return extract_doc_text(file_path)
    else:
        return ""

def ensure_directory_path(directory_path):
    if not directory_path.endswith('/'):
        directory_path += '/'
    return directory_path

def extract_standard_text(standard_dir):
    standard_text = ""
    standard_dir = ensure_directory_path(os.path.splitext(standard_dir)[0])  # Remove the .zip extension
    if os.path.exists(standard_dir):
        for root, _, files in os.walk(standard_dir):
            for file in files:
                file_path = os.path.join(root, file)
                text = extract_text(file_path)
                standard_text += text + "\n"
    else:
        print(f"Standard directory {standard_dir} does not exist.")
    return standard_text

# %%
bert_model_name = 'bert-base-uncased'
bert_model = TFBertModel.from_pretrained(bert_model_name)
tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
# Out:
# 2024-08-04 10:31:11.214271: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.215338: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.217299: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.218300: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.219141: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.220101: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.697198: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.698110: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.698859: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.699716: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.700450: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.701301: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.738740: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.739816: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.740683: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.741700: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.742537: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.743412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0b:00.0, compute capability: 6.1
# 2024-08-04 10:31:11.744144: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-04 10:31:11.744869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10522 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:44:00.0, compute capability: 6.1
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
def parse_tfrecord(example):
    feature_description = {
        'patent': tf.io.FixedLenFeature([], tf.string),
        'standard': tf.io.FixedLenFeature([], tf.string),
        'match': tf.io.FixedLenFeature([], tf.int64),
    }
    example = tf.io.parse_single_example(example, feature_description)
    return example['patent'], example['standard'], example['match']

# Load the TFRecord dataset
dataset = tf.data.TFRecordDataset(tfrecord_file)
parsed_dataset = dataset.map(parse_tfrecord)

# %%
num_samples = 0
for _ in parsed_dataset:
    num_samples += 1
print(f"Total number of samples in the dataset: {num_samples}")

# Define ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate sizes
train_size = int(train_ratio * num_samples)
val_size = int(val_ratio * num_samples)
test_size = num_samples - train_size - val_size  # Ensure we use all remaining samples

print(f"Number of samples in the training set: {train_size}")
print(f"Number of samples in the validation set: {val_size}")
print(f"Number of samples in the test set: {test_size}")

# Split the dataset into training and validation sets
train_dataset = parsed_dataset.take(train_size)
val_dataset = parsed_dataset.take(val_size)
test_dataset = parsed_dataset.take(test_size)
# Out:
# Total number of samples in the dataset: 130476
# Number of samples in the training set: 91333
# Number of samples in the validation set: 19571
# Number of samples in the test set: 19572
# 2024-08-04 10:31:34.057188: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def chunk_text(text, max_length):
    words = text.split()
    chunks = []
    for i in range(0, len(words), max_length):
        chunk = words[i:i + max_length]
        chunk = chunk + [''] * (max_length - len(chunk))  # Pad with empty strings
        chunks.append(' '.join(chunk))
    return chunks

# %%
max_length = 100
def data_generator(dataset, tokenizer, max_length=100, max_chunks=50):
    for patent, standard, match in dataset:
        patent_text = extract_patent_text(os.path.join(patent_folder, patent.numpy().decode()))
        standard_text = extract_standard_text(os.path.join(standard_folder, standard.numpy().decode()))

        if not patent_text.strip() or not standard_text.strip():
            print(f"\nSkipping sample: {patent.numpy().decode()},Standard={standard.numpy().decode()}die to empty text.")
            continue 
        
        patent_chunks = chunk_text(patent_text, max_length)
        print(patent_chunks)
        standard_chunks = chunk_text(standard_text, max_length)
        print(standard_chunks)

        if not patent_chunks or not standard_chunks:
            print(f"\nSkipping sample: Patent={patent.numpy().decode()}, Standard={standard.numpy().decode()} due to empty chunks.")
            continue
        
        patent_inputs = tokenizer(patent_chunks, padding=True, truncation=True, return_tensors='tf', max_length=max_length)
        standard_inputs = tokenizer(standard_chunks, padding=True, truncation=True, return_tensors='tf', max_length=max_length)
        
        patent_input_ids = patent_inputs['input_ids']
        patent_attention_mask = patent_inputs['attention_mask']
        standard_input_ids = standard_inputs['input_ids']
        standard_attention_mask = standard_inputs['attention_mask']
        
        patent_input_ids = patent_input_ids[:max_chunks]
        patent_attention_mask = patent_attention_mask[:max_chunks]
        standard_input_ids = standard_input_ids[:max_chunks]
        standard_attention_mask = standard_attention_mask[:max_chunks]
        
        patent_input_ids = tf.pad(patent_input_ids, [[0, max_chunks - tf.shape(patent_input_ids)[0]], [0, 0]], constant_values=0)
        patent_attention_mask = tf.pad(patent_attention_mask, [[0, max_chunks - tf.shape(patent_attention_mask)[0]], [0, 0]], constant_values=0)
        standard_input_ids = tf.pad(standard_input_ids, [[0, max_chunks - tf.shape(standard_input_ids)[0]], [0, 0]], constant_values=0)
        standard_attention_mask = tf.pad(standard_attention_mask, [[0, max_chunks - tf.shape(standard_attention_mask)[0]], [0, 0]], constant_values=0)
        
        # print("Patent input IDs shape:", patent_input_ids.shape)
        # print("Patent attention mask shape:", patent_attention_mask.shape)
        # print("Standard input IDs shape:", standard_input_ids.shape)
        # print("Standard attention mask shape:", standard_attention_mask.shape)
        # print("Match value:", match.numpy())
        # print("---")
        
        yield (
            {
                'patent_input_ids': tf.reshape(patent_input_ids, [1, max_chunks * max_length]),
                'patent_attention_mask': tf.reshape(patent_attention_mask, [1, max_chunks * max_length]),
                'standard_input_ids': tf.reshape(standard_input_ids, [1, max_chunks * max_length]),
                'standard_attention_mask': tf.reshape(standard_attention_mask, [1, max_chunks * max_length])
            },
            tf.reshape(tf.constant(match, dtype=tf.int64), [1])
        )

max_chunks = 50# Define the max_chunks variable
batch_size= 1
train_tf_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(train_dataset, tokenizer, max_length=100, max_chunks=max_chunks),
    output_signature=(
        {
            'patent_input_ids': tf.TensorSpec(shape=(1, max_chunks*max_length), dtype=tf.int32),
            'patent_attention_mask': tf.TensorSpec(shape=(1,max_chunks*max_length), dtype=tf.int32),
            'standard_input_ids': tf.TensorSpec(shape=(1,max_chunks*max_length), dtype=tf.int32),
            'standard_attention_mask': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
        },
        tf.TensorSpec(shape=(1,), dtype=tf.int32)
    )
).batch(batch_size)

val_tf_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(val_dataset, tokenizer, max_length=100, max_chunks=max_chunks),
    output_signature=(
        {
            'patent_input_ids': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
            'patent_attention_mask': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
            'standard_input_ids': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
            'standard_attention_mask': tf.TensorSpec(shape=(1,max_chunks* max_length), dtype=tf.int32),
        },
        tf.TensorSpec(shape=(1,), dtype=tf.int32)
    )
).batch(batch_size)

test_tf_dataset = tf.data.Dataset.from_generator(
    lambda: data_generator(test_dataset, tokenizer, max_length = 100, max_chunks= max_chunks),
    output_signature = (
        {
            'patent_input_ids' : tf.TensorSpec(shape=(1, max_chunks * max_length), dtype = tf.int32),
            'patent_attention_mask' : tf.TensorSpec(shape =(1, max_chunks * max_length), dtype = tf.int32), 
            'standard_input_ids' : tf.TensorSpec(shape=(1,max_chunks*max_length), dtype = tf.int32),
            'standard_attention_mask': tf.TensorSpec(shape = (1, max_chunks * max_length), dtype= tf.int32),
        },
        tf.TensorSpec(shape=(1,),dtype= tf.int32)
    )
).batch(batch_size)

# %%
class BertModelLayer(keras.layers.Layer):
    def __init__(self, bert_model, **kwargs):
        super(BertModelLayer, self).__init__(**kwargs)
        self.bert_model = bert_model

    def call(self, inputs):
        input_ids, attention_mask = inputs
        input_ids = tf.cast(input_ids, tf.int32)  # Cast input_ids to int32
        attention_mask = tf.cast(attention_mask, tf.int32)  # Cast attention_mask to int32
        outputs = self.bert_model(input_ids, attention_mask=attention_mask)
        return outputs.last_hidden_state

    def get_config(self):
        base_config = super(BertModelLayer, self).get_config()
        config = {
            "bert_model": tf.keras.legacy.saving.serialize_keras_object(self.bert_model),
        }
        return {**base_config, **config}

    @classmethod
    def from_config(cls, config):
        bert_model_config = config.pop("bert_model")
        bert_model = keras.saving.deserialize_keras_object(bert_model_config)
        return cls(bert_model=bert_model, **config)

class ReshapeLayer(Layer):
    def __init__(self, target_shape, **kwargs):
        super(ReshapeLayer, self).__init__(**kwargs)
        self.target_shape = target_shape

    def call(self, inputs):
        return tf.reshape(inputs, shape=self.target_shape)

class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                                 initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[1], 1),
                                 initializer="zeros")
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = K.squeeze(K.tanh(K.dot(x, self.W) + self.b), axis=-1)
        at = K.softmax(et)
        at = K.expand_dims(at, axis=-1)
        output = x * at
        return K.sum(output, axis=1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[-1])

class CrossAttention(Layer):
    def __init__(self, **kwargs):
        super(CrossAttention, self).__init__(**kwargs)

    def call(self, inputs):
        query, key, value = inputs
        attention_scores = tf.matmul(query, key, transpose_b=True)
        attention_scores = tf.nn.softmax(attention_scores, axis=-1)
        return tf.matmul(attention_scores, value)

# def cross_attention(query, key, value):
#     attention_scores = tf.matmul(query, key, transpose_b=True)
#     attention_scores = tf.nn.softmax(attention_scores, axis=-1)
#     return tf.matmul(attention_scores, value)

class ResidualBlock(Layer):
    def __init__(self, units, **kwargs):
        super(ResidualBlock, self).__init__(**kwargs)
        self.units = units
        self.dense1 = Dense(units, activation='relu')
        self.dense2 = Dense(units, activation='linear')

    def build(self, input_shape):
        self.dense2 = Dense(input_shape[-1], activation='linear')
        super(ResidualBlock, self).build(input_shape)

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return Add()([inputs, x])

    def get_config(self):
        config = super(ResidualBlock, self).get_config()
        config.update({"units": self.units})
        return config
        
def create_model(max_length, max_chunks):
    # Input layers
    patent_input_ids = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='patent_input_ids')
    patent_attention_mask = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='patent_attention_mask')
    standard_input_ids = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='standard_input_ids')
    standard_attention_mask = Input(shape=(1, max_chunks*max_length), dtype=tf.int32, name='standard_attention_mask')

    # Reshape layers
    reshape_layer = ReshapeLayer(target_shape=(-1, max_chunks*max_length))
    patent_input_ids_reshaped = reshape_layer(patent_input_ids)
    patent_attention_mask_reshaped = reshape_layer(patent_attention_mask)
    standard_input_ids_reshaped = reshape_layer(standard_input_ids)
    standard_attention_mask_reshaped = reshape_layer(standard_attention_mask)

    # BERT layers
    patent_bert = BertModelLayer(TFBertModel.from_pretrained('bert-base-uncased'), trainable=True)
    standard_bert = BertModelLayer(TFBertModel.from_pretrained('bert-base-uncased'), trainable=True)

    # BERT embeddings
    patent_embeddings = patent_bert([patent_input_ids_reshaped, patent_attention_mask_reshaped])
    standard_embeddings = standard_bert([standard_input_ids_reshaped, standard_attention_mask_reshaped])

    # Cross-attention
    cross_attention_layer = CrossAttention()
    patent_cross = cross_attention_layer([patent_embeddings, standard_embeddings, standard_embeddings])
    standard_cross = cross_attention_layer([standard_embeddings, patent_embeddings, patent_embeddings])

    patent_combined = Concatenate()([patent_embeddings, patent_cross])
    standard_combined = Concatenate()([standard_embeddings, standard_cross])

    # Pooling
    patent_max_pooled = GlobalMaxPooling1D()(patent_combined)
    patent_avg_pooled = GlobalAveragePooling1D()(patent_combined)
    patent_attention = AttentionLayer()(patent_combined)
    patent_pooled = Concatenate()([patent_max_pooled, patent_avg_pooled, patent_attention])

    standard_max_pooled = GlobalMaxPooling1D()(standard_combined)
    standard_avg_pooled = GlobalAveragePooling1D()(standard_combined)
    standard_attention = AttentionLayer()(standard_combined)
    standard_pooled = Concatenate()([standard_max_pooled, standard_avg_pooled, standard_attention])

    # Concatenate pooled outputs
    concatenated = Concatenate()([patent_pooled, standard_pooled])

    # Dense layers with residual connections
    x = Dense(1024, activation='relu')(concatenated)
    x = ResidualBlock(512)(x)
    x = Dropout(0.5)(x)
    x = ResidualBlock(256)(x)
    x = Dropout(0.5)(x)
    x = ResidualBlock(128)(x)
    x = Dropout(0.5)(x)

    # Final dense layers
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)

    # Model
    model = Model(inputs=[patent_input_ids, patent_attention_mask, standard_input_ids, standard_attention_mask], outputs=output)

    return model

# Create and compile the model
model = create_model(max_length, max_chunks)

initial_learning_rate = 0.001  # Assuming this was your initial rate
new_learning_rate = initial_learning_rate * 2  # Double it

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    new_learning_rate,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
num_epochs=2

# Create a directory for saving models if it doesn't exist
model_dir = 'saved_models_BERTcomplex'
os.makedirs(model_dir, exist_ok=True)

# Define a custom callback for periodic saving
class PeriodicSaver(tf.keras.callbacks.Callback):
    def __init__(self, save_freq=300, save_path='saved_models_BERTcomplex'):
        super(PeriodicSaver, self).__init__()
        self.save_freq = save_freq  # Save frequency in seconds
        self.save_path = save_path
        self.last_save_time = time.time()

    def on_batch_end(self, batch, logs=None):
        if time.time() - self.last_save_time > self.save_freq:
            print("\nSaving periodic model checkpoint...")
            self.model.save(os.path.join(self.save_path, f'periodic_model_{int(time.time())}.keras'))
            self.last_save_time = time.time()

# Define the callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),
    tf.keras.callbacks.ModelCheckpoint(
        filepath=os.path.join(model_dir, 'model.{epoch:02d}--{val_loss:.2f}.keras'), 
        monitor='val_accuracy', 
        save_best_only=True
    ),
    PeriodicSaver(save_freq=300, save_path=model_dir)  # Save every 5 minutes
]

final_model_path = None # Initialize the variable

try:
    # Start training
    model.fit(train_tf_dataset,
              epochs=num_epochs,
              callbacks=callbacks,
              validation_data=val_tf_dataset)

    # If training completes successfully, save the final model
    final_model_path = os.path.join(model_dir, 'final_model.keras')
    model.save(final_model_path)
    print("Training completed. Final model saved.")

except Exception as e:
    print(f"An error occurred during training: {e}")
    # The last periodic save will be the most recent model state
    periodic_saves = [f for f in os.listdir(model_dir) if f.startswith('periodic_model_')]
    if periodic_saves:
        latest_save = max(periodic_saves, key=lambda x: int(x.split('_')[2].split('.')[0]))
        final_model_path = os.path.join(model_dir, latest_save)
        print(f"Using the most recent periodic save: {final_model_path}")
    else:
        print("No periodic saves found. Unable to evaluate the model.")

finally:
    # This block will be executed whether there's an exception or not
    print("Training process finished.")
# Out:
# Epoch 1/2
# Data is a string of length 74466
# Data is a string of length 70203
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722782039.742043 2363053 service.cc:145] XLA service 0x2a487910 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1722782039.742099 2363053 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# I0000 00:00:1722782039.742105 2363053 service.cc:153]   StreamExecutor device (1): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2024-08-04 10:34:00.998063: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# W0000 00:00:1722782041.689402 2363053 assert_op.cc:38] Ignoring Assert operator functional_3_1/bert_model_layer_3_1/tf_bert_model_4/bert/embeddings/assert_less/Assert/Assert
# W0000 00:00:1722782041.692162 2363053 assert_op.cc:38] Ignoring Assert operator functional_3_1/bert_model_layer_2_1/tf_bert_model_3/bert/embeddings/assert_less/Assert/Assert
# 2024-08-04 10:34:05.438375: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# I0000 00:00:1722782059.687385 2363053 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#       1/Unknown 43s 43s/step - accuracy: 0.0000e+00 - loss: 1.6963Data is a string of length 66217
#       2/Unknown 45s 1s/step - accuracy: 0.0000e+00 - loss: 1.5697 Data is a string of length 41435
#       3/Unknown 46s 1s/step - accuracy: 0.0000e+00 - loss: 34.7838Data is a string of length 79689
#       4/Unknown 48s 2s/step - accuracy: 0.0625 - loss: 45.0652    Data is a string of length 116738
#       5/Unknown 49s 1s/step - accuracy: 0.1300 - loss: 48.1976Data is a string of length 76258
#       6/Unknown 52s 2s/step - accuracy: 0.1917 - loss: 48.5990Data is a string of length 92048
# Data is a string of length 99918
#       8/Unknown 54s 2s/step - accuracy: 0.2777 - loss: 53.6919Data is a string of length 1158
#       9/Unknown 56s 2s/step - accuracy: 0.2962 - loss: 67.6886Data is a string of length 80657
#      10/Unknown 57s 2s/step - accuracy: 0.3066 - loss: 77.7961Data is a string of length 119004
#      11/Unknown 58s 1s/step - accuracy: 0.3118 - loss: 85.4045Data is a string of length 232200
# Data is a string of length 51929
#      12/Unknown 59s 1s/step - accuracy: 0.3136 - loss: 90.6962Data is a string of length 103652
#      14/Unknown 62s 1s/step - accuracy: 0.3112 - loss: 101.0511Data is a string of length 49709
#      15/Unknown 63s 1s/step - accuracy: 0.3082 - loss: 105.8490Data is a string of length 58826
#      16/Unknown 64s 1s/step - accuracy: 0.3085 - loss: 109.3712Data is a string of length 105344
#      17/Unknown 66s 1s/step - accuracy: 0.3076 - loss: 112.8939
# Data is a string of length 92526
#      19/Unknown 68s 1s/step - accuracy: 0.3065 - loss: 119.9420Data is a string of length 100970
# Data is a string of length 135458
#      20/Unknown 70s 1s/step - accuracy: 0.3062 - loss: 123.9663Data is a string of length 64801
#      22/Unknown 72s 1s/step - accuracy: 0.3100 - loss: 129.6553Data is a string of length 151481
#      23/Unknown 74s 1s/step - accuracy: 0.3135 - loss: 131.5957Data is a string of length 270921
#      24/Unknown 75s 1s/step - accuracy: 0.3178 - loss: 133.0719Data is a string of length 68232
#      25/Unknown 76s 1s/step - accuracy: 0.3227 - loss: 134.1627Data is a string of length 78184
#      26/Unknown 77s 1s/step - accuracy: 0.3281 - loss: 134.9324Data is a string of length 210126
# Data is a string of length 27003
#      27/Unknown 80s 1s/step - accuracy: 0.3337 - loss: 135.4336Data is a string of length 60115
#      29/Unknown 82s 1s/step - accuracy: 0.3446 - loss: 136.8787Data is a string of length 56269
#      30/Unknown 83s 1s/step - accuracy: 0.3498 - loss: 137.7814Data is a string of length 141340
#      31/Unknown 85s 1s/step - accuracy: 0.3541 - loss: 139.0512Data is a string of length 40485
#      32/Unknown 86s 1s/step - accuracy: 0.3577 - loss: 141.1133Data is a string of length 159294
#      33/Unknown 87s 1s/step - accuracy: 0.3616 - loss: 142.8622Data is a string of length 118542
#      34/Unknown 88s 1s/step - accuracy: 0.3648 - loss: 144.7248Data is a string of length 81980
#      35/Unknown 90s 1s/step - accuracy: 0.3674 - loss: 146.7049Data is a string of length 95065
#      36/Unknown 92s 1s/step - accuracy: 0.3703 - loss: 148.4100Data is a string of length 74770
#      37/Unknown 94s 1s/step - accuracy: 0.3735 - loss: 149.8708Data is a string of length 85396
#      38/Unknown 95s 1s/step - accuracy: 0.3768 - loss: 151.1145Data is a string of length 49395
#      39/Unknown 97s 1s/step - accuracy: 0.3796 - loss: 152.2715Data is a string of length 120063
#      40/Unknown 98s 1s/step - accuracy: 0.3826 - loss: 153.2479Data is a string of length 47647
# Data is a string of length 204205
#      41/Unknown 99s 1s/step - accuracy: 0.3858 - loss: 154.0629Data is a string of length 26553
#      43/Unknown 102s 1s/step - accuracy: 0.3925 - loss: 155.2739Data is a string of length 102862
#      44/Unknown 104s 1s/step - accuracy: 0.3954 - loss: 155.7057Data is a string of length 46405
#      45/Unknown 105s 1s/step - accuracy: 0.3980 - loss: 156.1012Data is a string of length 263700
#      46/Unknown 106s 1s/step - accuracy: 0.4007 - loss: 156.3975Data is a string of length 113716
# Data is a string of length 48403
#      48/Unknown 110s 1s/step - accuracy: 0.4055 - loss: 156.8399Data is a string of length 43636
#      49/Unknown 111s 1s/step - accuracy: 0.4076 - loss: 156.9608Data is a string of length 159685
#      50/Unknown 112s 1s/step - accuracy: 0.4099 - loss: 157.0118Data is a string of length 52907
#      51/Unknown 113s 1s/step - accuracy: 0.4122 - loss: 156.9994Data is a string of length 115043
#      52/Unknown 118s 1s/step - accuracy: 0.4146 - loss: 156.9297Data is a string of length 83637
#      53/Unknown 120s 1s/step - accuracy: 0.4171 - loss: 156.8080Data is a string of length 38241
#      54/Unknown 121s 1s/step - accuracy: 0.4197 - loss: 156.6392Data is a string of length 65630
#      55/Unknown 123s 1s/step - accuracy: 0.4223 - loss: 156.4277Data is a string of length 113073
# Data is a string of length 65687
#      57/Unknown 126s 1s/step - accuracy: 0.4274 - loss: 155.8948Data is a string of length 39265
#      58/Unknown 127s 1s/step - accuracy: 0.4298 - loss: 155.5801Data is a string of length 120017
#      59/Unknown 129s 1s/step - accuracy: 0.4323 - loss: 155.2365Data is a string of length 196945
#      60/Unknown 131s 1s/step - accuracy: 0.4348 - loss: 154.8668Data is a string of length 120977
#      61/Unknown 132s 1s/step - accuracy: 0.4374 - loss: 154.4735Data is a string of length 111020
#      62/Unknown 134s 1s/step - accuracy: 0.4397 - loss: 154.2008Data is a string of length 94164
#      63/Unknown 135s 1s/step - accuracy: 0.4420 - loss: 153.9021Data is a string of length 71174
#      64/Unknown 136s 1s/step - accuracy: 0.4444 - loss: 153.5797Data is a string of length 47236
# Data is a string of length 62986
#      66/Unknown 139s 1s/step - accuracy: 0.4492 - loss: 152.8719Data is a string of length 98657
#      67/Unknown 140s 1s/step - accuracy: 0.4516 - loss: 152.4903Data is a string of length 79923
#      68/Unknown 141s 1s/step - accuracy: 0.4538 - loss: 152.1235Data is a string of length 53258
#      69/Unknown 142s 1s/step - accuracy: 0.4561 - loss: 151.7406Data is a string of length 99229
#      70/Unknown 144s 1s/step - accuracy: 0.4581 - loss: 151.3897Data is a string of length 113391
#      71/Unknown 146s 1s/step - accuracy: 0.4600 - loss: 151.0348Data is a string of length 64778
#      72/Unknown 147s 1s/step - accuracy: 0.4619 - loss: 150.6654Data is a string of length 259878
# Data is a string of length 92031
#      74/Unknown 150s 1s/step - accuracy: 0.4658 - loss: 149.8882Data is a string of length 46641
#      75/Unknown 151s 1s/step - accuracy: 0.4678 - loss: 149.4825Data is a string of length 68288
#      76/Unknown 152s 1s/step - accuracy: 0.4696 - loss: 149.0908Data is a string of length 58253
#      77/Unknown 154s 1s/step - accuracy: 0.4712 - loss: 148.7090Data is a string of length 206720
#      78/Unknown 160s 2s/step - accuracy: 0.4729 - loss: 148.3173Data is a string of length 92500
#      79/Unknown 161s 2s/step - accuracy: 0.4745 - loss: 147.9476Data is a string of length 116428
# Data is a string of length 91933
#      81/Unknown 164s 2s/step - accuracy: 0.4776 - loss: 147.1808Data is a string of length 68527
#      82/Unknown 165s 2s/step - accuracy: 0.4792 - loss: 146.7853Data is a string of length 160835
#      83/Unknown 166s 2s/step - accuracy: 0.4809 - loss: 146.3826Data is a string of length 103807
# Data is a string of length 82254
#      85/Unknown 169s 1s/step - accuracy: 0.4839 - loss: 145.6463Data is a string of length 81002
# Data is a string of length 133188
#      86/Unknown 170s 1s/step - accuracy: 0.4853 - loss: 145.2809Data is a string of length 113615
#      88/Unknown 173s 1s/step - accuracy: 0.4879 - loss: 144.5419Data is a string of length 49457
#      89/Unknown 174s 1s/step - accuracy: 0.4892 - loss: 144.1635Data is a string of length 87575
#      90/Unknown 175s 1s/step - accuracy: 0.4906 - loss: 143.7798Data is a string of length 106844
#      91/Unknown 178s 1s/step - accuracy: 0.4920 - loss: 143.3913Data is a string of length 100206
#      92/Unknown 183s 2s/step - accuracy: 0.4934 - loss: 142.9984Data is a string of length 98595
#      93/Unknown 184s 2s/step - accuracy: 0.4946 - loss: 142.6203Data is a string of length 65875
#      94/Unknown 186s 2s/step - accuracy: 0.4959 - loss: 142.2380Data is a string of length 28222
# Data is a string of length 55868
#      96/Unknown 188s 2s/step - accuracy: 0.4985 - loss: 141.4634Data is a string of length 41938
#      97/Unknown 189s 2s/step - accuracy: 0.4996 - loss: 141.0723Data is a string of length 61754
#      98/Unknown 190s 2s/step - accuracy: 0.5007 - loss: 140.6806Data is a string of length 71730
#      99/Unknown 192s 2s/step - accuracy: 0.5017 - loss: 140.2863Data is a string of length 157618
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2003072290 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 68686
#     100/Unknown 193s 2s/step - accuracy: 0.5028 - loss: 139.8898Data is a string of length 82213
#     101/Unknown 194s 2s/step - accuracy: 0.5039 - loss: 139.4912Data is a string of length 61142
#     102/Unknown 196s 2s/step - accuracy: 0.5050 - loss: 139.0909Data is a string of length 95912
# Data is a string of length 97021
#     103/Unknown 197s 2s/step - accuracy: 0.5061 - loss: 138.6937Data is a string of length 77245
#     105/Unknown 200s 2s/step - accuracy: 0.5080 - loss: 137.8958Data is a string of length 40738
#     106/Unknown 201s 2s/step - accuracy: 0.5090 - loss: 137.4953Data is a string of length 83864
#     107/Unknown 202s 2s/step - accuracy: 0.5100 - loss: 137.0939Data is a string of length 198585
#     108/Unknown 204s 1s/step - accuracy: 0.5110 - loss: 136.6918Data is a string of length 38033
# Data is a string of length 172116
#     110/Unknown 206s 1s/step - accuracy: 0.5130 - loss: 135.8876Data is a string of length 216590
#     111/Unknown 207s 1s/step - accuracy: 0.5139 - loss: 135.4868Data is a string of length 47158
#     112/Unknown 209s 1s/step - accuracy: 0.5148 - loss: 135.0860Data is a string of length 108502
#     113/Unknown 210s 1s/step - accuracy: 0.5157 - loss: 134.6851Data is a string of length 131347
#     114/Unknown 211s 1s/step - accuracy: 0.5166 - loss: 134.2874Data is a string of length 316083
#     115/Unknown 213s 1s/step - accuracy: 0.5174 - loss: 133.8905Data is a string of length 73366
#     116/Unknown 214s 1s/step - accuracy: 0.5182 - loss: 133.4940Data is a string of length 41987
#     117/Unknown 215s 1s/step - accuracy: 0.5189 - loss: 133.0979Data is a string of length 110803
#     118/Unknown 216s 1s/step - accuracy: 0.5197 - loss: 132.7022Data is a string of length 76058
#     119/Unknown 218s 1s/step - accuracy: 0.5205 - loss: 132.3071Data is a string of length 66684
#     120/Unknown 219s 1s/step - accuracy: 0.5212 - loss: 131.9206Data is a string of length 37180
#     121/Unknown 220s 1s/step - accuracy: 0.5219 - loss: 131.5397Data is a string of length 47645
#     122/Unknown 221s 1s/step - accuracy: 0.5226 - loss: 131.1593Data is a string of length 30413
#     123/Unknown 223s 1s/step - accuracy: 0.5233 - loss: 130.7795Data is a string of length 62496
#     124/Unknown 224s 1s/step - accuracy: 0.5240 - loss: 130.4003Data is a string of length 84860
#     125/Unknown 226s 1s/step - accuracy: 0.5247 - loss: 130.0219Data is a string of length 71580
#     126/Unknown 228s 1s/step - accuracy: 0.5255 - loss: 129.6442Data is a string of length 58752
# Data is a string of length 52048
#     128/Unknown 230s 1s/step - accuracy: 0.5270 - loss: 128.8923Data is a string of length 160925
#     129/Unknown 232s 1s/step - accuracy: 0.5276 - loss: 128.5182Data is a string of length 51937
#     130/Unknown 233s 1s/step - accuracy: 0.5283 - loss: 128.1451Data is a string of length 65591
#     131/Unknown 234s 1s/step - accuracy: 0.5289 - loss: 127.7736Data is a string of length 162861
#     132/Unknown 235s 1s/step - accuracy: 0.5295 - loss: 127.4036Data is a string of length 102211
#     133/Unknown 237s 1s/step - accuracy: 0.5301 - loss: 127.0355Data is a string of length 76482
#     134/Unknown 238s 1s/step - accuracy: 0.5306 - loss: 126.6685Data is a string of length 180994
#     135/Unknown 239s 1s/step - accuracy: 0.5312 - loss: 126.3027Data is a string of length 146310
#     136/Unknown 241s 1s/step - accuracy: 0.5317 - loss: 125.9385Data is a string of length 50196
#     137/Unknown 242s 1s/step - accuracy: 0.5322 - loss: 125.5763Data is a string of length 195677
#     138/Unknown 244s 1s/step - accuracy: 0.5326 - loss: 125.2163Data is a string of length 47980
#     139/Unknown 245s 1s/step - accuracy: 0.5331 - loss: 124.8576Data is a string of length 185625
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: CN110521146 A,Standard=TS 33.501.501die to empty text.
# Data is a string of length 96904
#     140/Unknown 247s 1s/step - accuracy: 0.5334 - loss: 124.5010Data is a string of length 43086
#     141/Unknown 248s 1s/step - accuracy: 0.5338 - loss: 124.1457Data is a string of length 173725
#     142/Unknown 249s 1s/step - accuracy: 0.5341 - loss: 123.7918Data is a string of length 69435
#     143/Unknown 250s 1s/step - accuracy: 0.5344 - loss: 123.4394Data is a string of length 91003
#     144/Unknown 252s 1s/step - accuracy: 0.5347 - loss: 123.0883Data is a string of length 103230
#     145/Unknown 253s 1s/step - accuracy: 0.5349 - loss: 122.7415Data is a string of length 46349
# Data is a string of length 57884
#     147/Unknown 256s 1s/step - accuracy: 0.5353 - loss: 122.0534Data is a string of length 83341
#     148/Unknown 257s 1s/step - accuracy: 0.5355 - loss: 121.7120Data is a string of length 95185
#     149/Unknown 258s 1s/step - accuracy: 0.5357 - loss: 121.3732Data is a string of length 67936
#     150/Unknown 260s 1s/step - accuracy: 0.5358 - loss: 121.0359Data is a string of length 123531
#     151/Unknown 261s 1s/step - accuracy: 0.5359 - loss: 120.6999Data is a string of length 68362
#     152/Unknown 262s 1s/step - accuracy: 0.5361 - loss: 120.3653Data is a string of length 103658
#     153/Unknown 264s 1s/step - accuracy: 0.5362 - loss: 120.0321Data is a string of length 92301
#     154/Unknown 265s 1s/step - accuracy: 0.5364 - loss: 119.7013Data is a string of length 84021
#     155/Unknown 266s 1s/step - accuracy: 0.5365 - loss: 119.3721Data is a string of length 86533
#     156/Unknown 267s 1s/step - accuracy: 0.5366 - loss: 119.0444Data is a string of length 118791
#     157/Unknown 268s 1s/step - accuracy: 0.5367 - loss: 118.7199Data is a string of length 53379
#     158/Unknown 270s 1s/step - accuracy: 0.5367 - loss: 118.3973Data is a string of length 93335
#     159/Unknown 272s 1s/step - accuracy: 0.5368 - loss: 118.0760Data is a string of length 90601
#     160/Unknown 273s 1s/step - accuracy: 0.5369 - loss: 117.7560Data is a string of length 73497
#     161/Unknown 275s 1s/step - accuracy: 0.5369 - loss: 117.4376Data is a string of length 33822
#     162/Unknown 277s 1s/step - accuracy: 0.5370 - loss: 117.1205Data is a string of length 76423
#     163/Unknown 278s 1s/step - accuracy: 0.5371 - loss: 116.8049Data is a string of length 56162
#     164/Unknown 279s 1s/step - accuracy: 0.5371 - loss: 116.4908Data is a string of length 61629
#     165/Unknown 280s 1s/step - accuracy: 0.5372 - loss: 116.1780Data is a string of length 104515
#     166/Unknown 281s 1s/step - accuracy: 0.5373 - loss: 115.8667Data is a string of length 35673
#     167/Unknown 283s 1s/step - accuracy: 0.5374 - loss: 115.5575Data is a string of length 126824
#     168/Unknown 285s 1s/step - accuracy: 0.5375 - loss: 115.2505Data is a string of length 101990
#     169/Unknown 286s 1s/step - accuracy: 0.5375 - loss: 114.9450Data is a string of length 111196
#     170/Unknown 287s 1s/step - accuracy: 0.5376 - loss: 114.6410Data is a string of length 38477
#     171/Unknown 289s 1s/step - accuracy: 0.5376 - loss: 114.3388Data is a string of length 35724
#     172/Unknown 290s 1s/step - accuracy: 0.5376 - loss: 114.0381Data is a string of length 21393
#     173/Unknown 291s 1s/step - accuracy: 0.5377 - loss: 113.7387Data is a string of length 93214
#     174/Unknown 292s 1s/step - accuracy: 0.5378 - loss: 113.4420Data is a string of length 44513
#     175/Unknown 294s 1s/step - accuracy: 0.5378 - loss: 113.1468Data is a string of length 92686
#     176/Unknown 295s 1s/step - accuracy: 0.5378 - loss: 112.8529Data is a string of length 129617
#     177/Unknown 296s 1s/step - accuracy: 0.5379 - loss: 112.5603Data is a string of length 88257
#     178/Unknown 297s 1s/step - accuracy: 0.5380 - loss: 112.2692Data is a string of length 70967
#     179/Unknown 298s 1s/step - accuracy: 0.5380 - loss: 111.9795Data is a string of length 73027
#     180/Unknown 300s 1s/step - accuracy: 0.5381 - loss: 111.6912Data is a string of length 45490
#
# Saving periodic model checkpoint...
# Data is a string of length 75978
#     181/Unknown 301s 1s/step - accuracy: 0.5381 - loss: 111.4044Data is a string of length 111066
#     182/Unknown 303s 1s/step - accuracy: 0.5382 - loss: 111.1189Data is a string of length 74381
#     184/Unknown 306s 1s/step - accuracy: 0.5382 - loss: 110.5521Data is a string of length 349353
#     185/Unknown 307s 1s/step - accuracy: 0.5382 - loss: 110.2708Data is a string of length 49861
#     186/Unknown 308s 1s/step - accuracy: 0.5383 - loss: 109.9908Data is a string of length 65525
#     187/Unknown 309s 1s/step - accuracy: 0.5383 - loss: 109.7122Data is a string of length 92929
# Data is a string of length 53521
#     189/Unknown 312s 1s/step - accuracy: 0.5383 - loss: 109.1589Data is a string of length 38550
#     190/Unknown 313s 1s/step - accuracy: 0.5384 - loss: 108.8844Data is a string of length 113219
# Data is a string of length 77799
#     192/Unknown 316s 1s/step - accuracy: 0.5384 - loss: 108.3393Data is a string of length 119310
#     193/Unknown 317s 1s/step - accuracy: 0.5383 - loss: 108.0689Data is a string of length 97451
#     194/Unknown 318s 1s/step - accuracy: 0.5383 - loss: 107.7997Data is a string of length 90882
# Data is a string of length 106520
#     195/Unknown 319s 1s/step - accuracy: 0.5383 - loss: 107.5318Data is a string of length 131657
#     197/Unknown 323s 1s/step - accuracy: 0.5383 - loss: 107.0000Data is a string of length 88986
#     198/Unknown 341s 2s/step - accuracy: 0.5382 - loss: 106.7360Data is a string of length 209119
# Data is a string of length 26333
#     199/Unknown 342s 2s/step - accuracy: 0.5382 - loss: 106.4734Data is a string of length 139214
#     200/Unknown 344s 2s/step - accuracy: 0.5381 - loss: 106.2120Data is a string of length 63804
#     202/Unknown 346s 2s/step - accuracy: 0.5380 - loss: 105.6930Data is a string of length 60431
#     203/Unknown 347s 2s/step - accuracy: 0.5380 - loss: 105.4354Data is a string of length 67136
#     204/Unknown 349s 2s/step - accuracy: 0.5379 - loss: 105.1793Data is a string of length 95303
#     205/Unknown 350s 2s/step - accuracy: 0.5379 - loss: 104.9246Data is a string of length 93220
#     206/Unknown 351s 2s/step - accuracy: 0.5378 - loss: 104.6712Data is a string of length 73144
#     207/Unknown 352s 1s/step - accuracy: 0.5378 - loss: 104.4192Data is a string of length 64780
# Data is a string of length 35213
#     209/Unknown 355s 1s/step - accuracy: 0.5377 - loss: 103.9187Data is a string of length 154177
#     210/Unknown 356s 1s/step - accuracy: 0.5376 - loss: 103.6703Data is a string of length 169921
#     211/Unknown 359s 2s/step - accuracy: 0.5375 - loss: 103.4231Data is a string of length 64295
#     212/Unknown 363s 2s/step - accuracy: 0.5375 - loss: 103.1771Data is a string of length 86142
#     213/Unknown 364s 2s/step - accuracy: 0.5375 - loss: 102.9323Data is a string of length 119599
#     214/Unknown 365s 2s/step - accuracy: 0.5374 - loss: 102.6886Data is a string of length 81821
#     215/Unknown 367s 2s/step - accuracy: 0.5374 - loss: 102.4462Data is a string of length 63141
#     216/Unknown 369s 2s/step - accuracy: 0.5373 - loss: 102.2049Data is a string of length 71248
# Data is a string of length 27713
#     218/Unknown 371s 2s/step - accuracy: 0.5373 - loss: 101.7259Data is a string of length 73588
#     219/Unknown 373s 2s/step - accuracy: 0.5372 - loss: 101.4881Data is a string of length 84244
#     220/Unknown 374s 2s/step - accuracy: 0.5372 - loss: 101.2515Data is a string of length 92258
#     221/Unknown 376s 2s/step - accuracy: 0.5371 - loss: 101.0160Data is a string of length 50091
#     222/Unknown 377s 2s/step - accuracy: 0.5371 - loss: 100.7817Data is a string of length 59351
# Data is a string of length 77047
#     224/Unknown 380s 2s/step - accuracy: 0.5370 - loss: 100.3165Data is a string of length 66215
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US11337228 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 146319
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US8850203 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 77140
#     225/Unknown 382s 2s/step - accuracy: 0.5370 - loss: 100.0856Data is a string of length 238754
#     226/Unknown 385s 2s/step - accuracy: 0.5370 - loss: 99.8558 Data is a string of length 115650
# Data is a string of length 41056
#     228/Unknown 388s 2s/step - accuracy: 0.5369 - loss: 99.3995Data is a string of length 84692
#     229/Unknown 389s 2s/step - accuracy: 0.5369 - loss: 99.1730Data is a string of length 71638
#     230/Unknown 391s 2s/step - accuracy: 0.5369 - loss: 98.9476Data is a string of length 36852
#     231/Unknown 398s 2s/step - accuracy: 0.5369 - loss: 98.7232Data is a string of length 118853
# Data is a string of length 53044
#     233/Unknown 400s 2s/step - accuracy: 0.5368 - loss: 98.2777Data is a string of length 78365
#     234/Unknown 401s 2s/step - accuracy: 0.5368 - loss: 98.0566Data is a string of length 48155
#     235/Unknown 402s 2s/step - accuracy: 0.5368 - loss: 97.8365Data is a string of length 124137
#     236/Unknown 404s 2s/step - accuracy: 0.5368 - loss: 97.6174Data is a string of length 128846
#     237/Unknown 405s 2s/step - accuracy: 0.5368 - loss: 97.3994Data is a string of length 113760
#     238/Unknown 408s 2s/step - accuracy: 0.5368 - loss: 97.1824Data is a string of length 36400
#     239/Unknown 410s 2s/step - accuracy: 0.5367 - loss: 96.9665Data is a string of length 44125
#     240/Unknown 412s 2s/step - accuracy: 0.5367 - loss: 96.7515Data is a string of length 61187
#     241/Unknown 413s 2s/step - accuracy: 0.5366 - loss: 96.5376Data is a string of length 206348
#     242/Unknown 414s 2s/step - accuracy: 0.5366 - loss: 96.3247Data is a string of length 91440
#     243/Unknown 416s 2s/step - accuracy: 0.5365 - loss: 96.1128Data is a string of length 56821
#     244/Unknown 417s 2s/step - accuracy: 0.5364 - loss: 95.9019Data is a string of length 104863
#     245/Unknown 418s 2s/step - accuracy: 0.5364 - loss: 95.6919Data is a string of length 175965
#     246/Unknown 419s 2s/step - accuracy: 0.5363 - loss: 95.4830Data is a string of length 79150
# Data is a string of length 41422
#     248/Unknown 423s 2s/step - accuracy: 0.5362 - loss: 95.0681Data is a string of length 141380
#     249/Unknown 424s 2s/step - accuracy: 0.5361 - loss: 94.8621Data is a string of length 120276
#     250/Unknown 426s 2s/step - accuracy: 0.5360 - loss: 94.6570Data is a string of length 57544
#     251/Unknown 428s 2s/step - accuracy: 0.5360 - loss: 94.4529Data is a string of length 163950
#     252/Unknown 429s 2s/step - accuracy: 0.5359 - loss: 94.2498Data is a string of length 174624
#     253/Unknown 430s 2s/step - accuracy: 0.5358 - loss: 94.0476Data is a string of length 90490
#     254/Unknown 432s 2s/step - accuracy: 0.5357 - loss: 93.8463Data is a string of length 103570
#     255/Unknown 433s 2s/step - accuracy: 0.5356 - loss: 93.6460Data is a string of length 43917
#     256/Unknown 434s 2s/step - accuracy: 0.5356 - loss: 93.4466Data is a string of length 130750
#     257/Unknown 436s 2s/step - accuracy: 0.5355 - loss: 93.2481Data is a string of length 163523
#     258/Unknown 438s 2s/step - accuracy: 0.5354 - loss: 93.0505Data is a string of length 56461
#     259/Unknown 439s 2s/step - accuracy: 0.5353 - loss: 92.8538Data is a string of length 146179
#     260/Unknown 441s 2s/step - accuracy: 0.5352 - loss: 92.6580Data is a string of length 97627
# Data is a string of length 79202
#     261/Unknown 442s 2s/step - accuracy: 0.5351 - loss: 92.4632Data is a string of length 121329
#     263/Unknown 444s 2s/step - accuracy: 0.5349 - loss: 92.0760Data is a string of length 94794
# Data is a string of length 52352
#     265/Unknown 447s 2s/step - accuracy: 0.5347 - loss: 91.6925Data is a string of length 61498
#     266/Unknown 448s 2s/step - accuracy: 0.5346 - loss: 91.5020Data is a string of length 31936
#     267/Unknown 449s 2s/step - accuracy: 0.5345 - loss: 91.3123Data is a string of length 39121
#     268/Unknown 450s 2s/step - accuracy: 0.5344 - loss: 91.1236Data is a string of length 44850
#     269/Unknown 452s 2s/step - accuracy: 0.5344 - loss: 90.9356Data is a string of length 57123
#     270/Unknown 453s 2s/step - accuracy: 0.5343 - loss: 90.7486Data is a string of length 63316
#     271/Unknown 454s 2s/step - accuracy: 0.5342 - loss: 90.5625Data is a string of length 169215
#     272/Unknown 455s 2s/step - accuracy: 0.5341 - loss: 90.3772Data is a string of length 255282
#     273/Unknown 457s 2s/step - accuracy: 0.5340 - loss: 90.1927Data is a string of length 52696
#     274/Unknown 458s 2s/step - accuracy: 0.5339 - loss: 90.0090Data is a string of length 109600
# Data is a string of length 53959
#     276/Unknown 462s 2s/step - accuracy: 0.5338 - loss: 89.6441Data is a string of length 88910
#     277/Unknown 464s 2s/step - accuracy: 0.5337 - loss: 89.4629Data is a string of length 67149
#     278/Unknown 465s 2s/step - accuracy: 0.5336 - loss: 89.2824Data is a string of length 73478
#     279/Unknown 484s 2s/step - accuracy: 0.5335 - loss: 89.1028Data is a string of length 98407
#     280/Unknown 485s 2s/step - accuracy: 0.5335 - loss: 88.9240Data is a string of length 55549
# Data is a string of length 88002
#     282/Unknown 490s 2s/step - accuracy: 0.5333 - loss: 88.5686Data is a string of length 56055
#     283/Unknown 492s 2s/step - accuracy: 0.5332 - loss: 88.3921Data is a string of length 115527
#     284/Unknown 493s 2s/step - accuracy: 0.5332 - loss: 88.2164Data is a string of length 109409
#     285/Unknown 494s 2s/step - accuracy: 0.5331 - loss: 88.0415Data is a string of length 115527
#     286/Unknown 496s 2s/step - accuracy: 0.5330 - loss: 87.8673Data is a string of length 118056
#     287/Unknown 498s 2s/step - accuracy: 0.5330 - loss: 87.6938Data is a string of length 101577
#     288/Unknown 499s 2s/step - accuracy: 0.5329 - loss: 87.5212
#     289/Unknown 500s 2s/step - accuracy: 0.5328 - loss: 87.3492Data is a string of length 78500
#     290/Unknown 502s 2s/step - accuracy: 0.5327 - loss: 87.1781Data is a string of length 37835
#     291/Unknown 504s 2s/step - accuracy: 0.5327 - loss: 87.0076Data is a string of length 62584
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2017055152 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 100755
#     292/Unknown 505s 2s/step - accuracy: 0.5326 - loss: 86.8379Data is a string of length 69901
#     293/Unknown 506s 2s/step - accuracy: 0.5325 - loss: 86.6689Data is a string of length 125914
#     294/Unknown 508s 2s/step - accuracy: 0.5324 - loss: 86.5007Data is a string of length 35724
#     295/Unknown 509s 2s/step - accuracy: 0.5323 - loss: 86.3331Data is a string of length 82479
#     296/Unknown 510s 2s/step - accuracy: 0.5322 - loss: 86.1663Data is a string of length 368802
#     297/Unknown 512s 2s/step - accuracy: 0.5321 - loss: 86.0002Data is a string of length 129253
#     298/Unknown 513s 2s/step - accuracy: 0.5320 - loss: 85.8348Data is a string of length 38102
#     299/Unknown 516s 2s/step - accuracy: 0.5319 - loss: 85.6701Data is a string of length 36927
#     300/Unknown 521s 2s/step - accuracy: 0.5318 - loss: 85.5062Data is a string of length 74771
#     301/Unknown 523s 2s/step - accuracy: 0.5317 - loss: 85.3429Data is a string of length 54302
# Data is a string of length 86071
#     303/Unknown 525s 2s/step - accuracy: 0.5315 - loss: 85.0183Data is a string of length 64582
# Data is a string of length 61646
#     304/Unknown 526s 2s/step - accuracy: 0.5314 - loss: 84.8571Data is a string of length 96764
#     306/Unknown 529s 2s/step - accuracy: 0.5313 - loss: 84.5366Data is a string of length 67788
# Data is a string of length 89261
#     308/Unknown 531s 2s/step - accuracy: 0.5311 - loss: 84.2189Data is a string of length 105656
#     309/Unknown 532s 2s/step - accuracy: 0.5310 - loss: 84.0610Data is a string of length 34450
#     310/Unknown 534s 2s/step - accuracy: 0.5310 - loss: 83.9037Data is a string of length 80490
#     311/Unknown 535s 2s/step - accuracy: 0.5309 - loss: 83.7471Data is a string of length 68642
#     312/Unknown 536s 2s/step - accuracy: 0.5309 - loss: 83.5912Data is a string of length 84447
#     313/Unknown 537s 2s/step - accuracy: 0.5308 - loss: 83.4359Data is a string of length 52519
#     314/Unknown 539s 2s/step - accuracy: 0.5307 - loss: 83.2813Data is a string of length 153871
#     315/Unknown 540s 2s/step - accuracy: 0.5307 - loss: 83.1273Data is a string of length 93761
#     316/Unknown 541s 2s/step - accuracy: 0.5306 - loss: 82.9739Data is a string of length 115415
#     317/Unknown 543s 2s/step - accuracy: 0.5306 - loss: 82.8211Data is a string of length 61049
#     318/Unknown 544s 2s/step - accuracy: 0.5305 - loss: 82.6690Data is a string of length 63581
#     319/Unknown 545s 2s/step - accuracy: 0.5305 - loss: 82.5175Data is a string of length 71340
#     320/Unknown 546s 2s/step - accuracy: 0.5304 - loss: 82.3666Data is a string of length 112228
#     321/Unknown 548s 2s/step - accuracy: 0.5304 - loss: 82.2164Data is a string of length 111580
#     322/Unknown 549s 2s/step - accuracy: 0.5304 - loss: 82.0667Data is a string of length 114197
#     323/Unknown 552s 2s/step - accuracy: 0.5303 - loss: 81.9177Data is a string of length 43515
#     324/Unknown 553s 2s/step - accuracy: 0.5303 - loss: 81.7692Data is a string of length 43001
#     325/Unknown 554s 2s/step - accuracy: 0.5303 - loss: 81.6214Data is a string of length 78418
#     326/Unknown 556s 2s/step - accuracy: 0.5302 - loss: 81.4741Data is a string of length 98656
#     327/Unknown 557s 2s/step - accuracy: 0.5302 - loss: 81.3274Data is a string of length 37236
#     328/Unknown 558s 2s/step - accuracy: 0.5302 - loss: 81.1814Data is a string of length 82669
#     329/Unknown 559s 2s/step - accuracy: 0.5301 - loss: 81.0359Data is a string of length 50063
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2022104021 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 53586
#     330/Unknown 560s 2s/step - accuracy: 0.5301 - loss: 80.8910Data is a string of length 59343
#     331/Unknown 562s 2s/step - accuracy: 0.5301 - loss: 80.7467Data is a string of length 50146
#     332/Unknown 563s 2s/step - accuracy: 0.5301 - loss: 80.6029Data is a string of length 57472
#     333/Unknown 564s 2s/step - accuracy: 0.5301 - loss: 80.4597Data is a string of length 65329
#     334/Unknown 565s 2s/step - accuracy: 0.5300 - loss: 80.3171Data is a string of length 42437
#     335/Unknown 567s 2s/step - accuracy: 0.5300 - loss: 80.1750Data is a string of length 82407
# Data is a string of length 72756
#     336/Unknown 568s 2s/step - accuracy: 0.5300 - loss: 80.0336Data is a string of length 62029
#     338/Unknown 570s 2s/step - accuracy: 0.5300 - loss: 79.7523Data is a string of length 45738
#     339/Unknown 572s 2s/step - accuracy: 0.5300 - loss: 79.6125Data is a string of length 80144
#     340/Unknown 574s 2s/step - accuracy: 0.5300 - loss: 79.4732Data is a string of length 66705
#     341/Unknown 575s 2s/step - accuracy: 0.5300 - loss: 79.3345Data is a string of length 80619
#     342/Unknown 576s 2s/step - accuracy: 0.5300 - loss: 79.1963Data is a string of length 117272
#     343/Unknown 577s 2s/step - accuracy: 0.5300 - loss: 79.0586Data is a string of length 57749
#     344/Unknown 579s 2s/step - accuracy: 0.5300 - loss: 78.9215Data is a string of length 71331
#     345/Unknown 580s 2s/step - accuracy: 0.5300 - loss: 78.7852Data is a string of length 51838
# Data is a string of length 60473
#     347/Unknown 583s 2s/step - accuracy: 0.5300 - loss: 78.5144Data is a string of length 56194
#     348/Unknown 585s 2s/step - accuracy: 0.5300 - loss: 78.3798Data is a string of length 108815
#     349/Unknown 586s 2s/step - accuracy: 0.5300 - loss: 78.2457Data is a string of length 76268
#     350/Unknown 588s 2s/step - accuracy: 0.5300 - loss: 78.1121Data is a string of length 99311
#     351/Unknown 589s 2s/step - accuracy: 0.5300 - loss: 77.9791Data is a string of length 46449
#     352/Unknown 590s 2s/step - accuracy: 0.5300 - loss: 77.8465Data is a string of length 137885
# Data is a string of length 45856
#     353/Unknown 592s 2s/step - accuracy: 0.5301 - loss: 77.7145Data is a string of length 40583
#     354/Unknown 593s 2s/step - accuracy: 0.5301 - loss: 77.5829Data is a string of length 230108
#     356/Unknown 595s 2s/step - accuracy: 0.5301 - loss: 77.3213Data is a string of length 77581
#     357/Unknown 597s 2s/step - accuracy: 0.5302 - loss: 77.1912Data is a string of length 218579
#     358/Unknown 598s 2s/step - accuracy: 0.5302 - loss: 77.0617Data is a string of length 59714
# Data is a string of length 115253
#     360/Unknown 601s 2s/step - accuracy: 0.5303 - loss: 76.8040Data is a string of length 104024
#
# Saving periodic model checkpoint...
# Data is a string of length 58244
# Data is a string of length 146140
# Data is a string of length 55289
#     364/Unknown 610s 2s/step - accuracy: 0.5305 - loss: 76.2944Data is a string of length 357556
#     365/Unknown 612s 2s/step - accuracy: 0.5305 - loss: 76.1682Data is a string of length 90429
#     366/Unknown 613s 2s/step - accuracy: 0.5306 - loss: 76.0424Data is a string of length 85682
#     367/Unknown 614s 2s/step - accuracy: 0.5306 - loss: 75.9171Data is a string of length 67201
#     368/Unknown 615s 2s/step - accuracy: 0.5306 - loss: 75.7923Data is a string of length 60728
#     369/Unknown 617s 2s/step - accuracy: 0.5307 - loss: 75.6680Data is a string of length 204055
#     370/Unknown 618s 2s/step - accuracy: 0.5307 - loss: 75.5441Data is a string of length 95379
#     371/Unknown 619s 2s/step - accuracy: 0.5307 - loss: 75.4207Data is a string of length 155374
#     372/Unknown 620s 2s/step - accuracy: 0.5308 - loss: 75.2977Data is a string of length 41909
#     373/Unknown 622s 2s/step - accuracy: 0.5308 - loss: 75.1751Data is a string of length 129201
#     374/Unknown 623s 2s/step - accuracy: 0.5309 - loss: 75.0531Data is a string of length 62804
#     375/Unknown 625s 2s/step - accuracy: 0.5309 - loss: 74.9314Data is a string of length 65746
#     376/Unknown 626s 2s/step - accuracy: 0.5309 - loss: 74.8102Data is a string of length 95035
#     377/Unknown 627s 2s/step - accuracy: 0.5310 - loss: 74.6895Data is a string of length 90327
#     378/Unknown 628s 2s/step - accuracy: 0.5310 - loss: 74.5692Data is a string of length 105508
#     379/Unknown 630s 2s/step - accuracy: 0.5310 - loss: 74.4493Data is a string of length 344211
#     380/Unknown 633s 2s/step - accuracy: 0.5311 - loss: 74.3299Data is a string of length 93107
#     381/Unknown 634s 2s/step - accuracy: 0.5311 - loss: 74.2108Data is a string of length 91621
#     382/Unknown 635s 2s/step - accuracy: 0.5312 - loss: 74.0923Data is a string of length 79122
#     383/Unknown 636s 2s/step - accuracy: 0.5312 - loss: 73.9741Data is a string of length 128892
#     384/Unknown 638s 2s/step - accuracy: 0.5313 - loss: 73.8564Data is a string of length 37343
#     385/Unknown 639s 2s/step - accuracy: 0.5313 - loss: 73.7391Data is a string of length 147031
#     386/Unknown 640s 2s/step - accuracy: 0.5314 - loss: 73.6222Data is a string of length 37163
#     387/Unknown 642s 2s/step - accuracy: 0.5314 - loss: 73.5057Data is a string of length 73340
#     388/Unknown 643s 2s/step - accuracy: 0.5315 - loss: 73.3896Data is a string of length 34852
#     389/Unknown 644s 2s/step - accuracy: 0.5315 - loss: 73.2740Data is a string of length 52440
#     390/Unknown 646s 2s/step - accuracy: 0.5316 - loss: 73.1588Data is a string of length 60305
#     391/Unknown 647s 2s/step - accuracy: 0.5316 - loss: 73.0439Data is a string of length 84466
#     392/Unknown 649s 2s/step - accuracy: 0.5317 - loss: 72.9295Data is a string of length 158371
#     393/Unknown 655s 2s/step - accuracy: 0.5317 - loss: 72.8155Data is a string of length 140725
# Data is a string of length 43493
#     395/Unknown 658s 2s/step - accuracy: 0.5318 - loss: 72.5887Data is a string of length 61636
# Data is a string of length 87469
#     397/Unknown 660s 2s/step - accuracy: 0.5319 - loss: 72.3638Data is a string of length 149366
#     398/Unknown 662s 2s/step - accuracy: 0.5320 - loss: 72.2522Data is a string of length 38843
#     399/Unknown 663s 2s/step - accuracy: 0.5320 - loss: 72.1409Data is a string of length 48357
#     400/Unknown 664s 2s/step - accuracy: 0.5321 - loss: 72.0302Data is a string of length 94461
# Data is a string of length 220296
#     402/Unknown 667s 2s/step - accuracy: 0.5322 - loss: 71.8099Data is a string of length 102275
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2016294811 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 97243
# Data is a string of length 43515
#     404/Unknown 670s 2s/step - accuracy: 0.5322 - loss: 71.5910Data is a string of length 47725
#     405/Unknown 673s 2s/step - accuracy: 0.5323 - loss: 71.4822Data is a string of length 46225
# Data is a string of length 39761
#     407/Unknown 675s 2s/step - accuracy: 0.5324 - loss: 71.2656Data is a string of length 61177
#     408/Unknown 677s 2s/step - accuracy: 0.5324 - loss: 71.1579Data is a string of length 73158
#     409/Unknown 679s 2s/step - accuracy: 0.5325 - loss: 71.0505Data is a string of length 87406
#     410/Unknown 680s 2s/step - accuracy: 0.5326 - loss: 70.9435Data is a string of length 65768
#     411/Unknown 682s 2s/step - accuracy: 0.5326 - loss: 70.8369Data is a string of length 56633
#     412/Unknown 683s 2s/step - accuracy: 0.5327 - loss: 70.7307Data is a string of length 26738
# Data is a string of length 51481
#     414/Unknown 685s 2s/step - accuracy: 0.5328 - loss: 70.5194Data is a string of length 102361
#     415/Unknown 687s 2s/step - accuracy: 0.5328 - loss: 70.4143Data is a string of length 106871
#     416/Unknown 688s 2s/step - accuracy: 0.5329 - loss: 70.3095Data is a string of length 75155
#     417/Unknown 689s 2s/step - accuracy: 0.5330 - loss: 70.2051Data is a string of length 76122
#     418/Unknown 691s 2s/step - accuracy: 0.5330 - loss: 70.1011Data is a string of length 75272
#     419/Unknown 692s 2s/step - accuracy: 0.5331 - loss: 69.9974Data is a string of length 70040
#     420/Unknown 693s 2s/step - accuracy: 0.5332 - loss: 69.8940Data is a string of length 19765
# Data is a string of length 160498
#     422/Unknown 696s 2s/step - accuracy: 0.5333 - loss: 69.6883Data is a string of length 55758
#     423/Unknown 697s 2s/step - accuracy: 0.5334 - loss: 69.5863Data is a string of length 71231
#     424/Unknown 699s 2s/step - accuracy: 0.5334 - loss: 69.4845Data is a string of length 114218
#     425/Unknown 700s 2s/step - accuracy: 0.5335 - loss: 69.3831Data is a string of length 91072
#     426/Unknown 701s 2s/step - accuracy: 0.5336 - loss: 69.2821Data is a string of length 128230
#     427/Unknown 703s 2s/step - accuracy: 0.5337 - loss: 69.1814Data is a string of length 133825
# Data is a string of length 53434
#     429/Unknown 705s 2s/step - accuracy: 0.5338 - loss: 68.9810Data is a string of length 53963
#     430/Unknown 707s 2s/step - accuracy: 0.5339 - loss: 68.8814Data is a string of length 67443
#     431/Unknown 708s 2s/step - accuracy: 0.5340 - loss: 68.7820Data is a string of length 72414
#     432/Unknown 709s 2s/step - accuracy: 0.5340 - loss: 68.6830Data is a string of length 31805
# Data is a string of length 104305
#     434/Unknown 712s 2s/step - accuracy: 0.5342 - loss: 68.4859Data is a string of length 61222
#     435/Unknown 713s 2s/step - accuracy: 0.5343 - loss: 68.3879Data is a string of length 69127
#     436/Unknown 714s 2s/step - accuracy: 0.5343 - loss: 68.2901Data is a string of length 139263
#     437/Unknown 715s 2s/step - accuracy: 0.5344 - loss: 68.1927Data is a string of length 336404
#     438/Unknown 717s 2s/step - accuracy: 0.5345 - loss: 68.0956Data is a string of length 51168
#     439/Unknown 719s 2s/step - accuracy: 0.5346 - loss: 67.9988Data is a string of length 266892
#     440/Unknown 721s 2s/step - accuracy: 0.5346 - loss: 67.9023Data is a string of length 71352
#     441/Unknown 722s 2s/step - accuracy: 0.5347 - loss: 67.8062Data is a string of length 52222
#     442/Unknown 723s 2s/step - accuracy: 0.5348 - loss: 67.7103Data is a string of length 50536
#     443/Unknown 725s 2s/step - accuracy: 0.5348 - loss: 67.6147Data is a string of length 57660
#     444/Unknown 726s 2s/step - accuracy: 0.5349 - loss: 67.5195Data is a string of length 71076
#     445/Unknown 727s 2s/step - accuracy: 0.5350 - loss: 67.4245Data is a string of length 61524
#     446/Unknown 728s 2s/step - accuracy: 0.5350 - loss: 67.3299Data is a string of length 90436
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.203/ does not exist.
#
# Skipping sample: US9660713 B2,Standard=TS 33.203.203die to empty text.
# Data is a string of length 56224
#     447/Unknown 730s 2s/step - accuracy: 0.5351 - loss: 67.2355Data is a string of length 33146
#     448/Unknown 731s 2s/step - accuracy: 0.5351 - loss: 67.1415Data is a string of length 30489
#     449/Unknown 733s 2s/step - accuracy: 0.5352 - loss: 67.0478Data is a string of length 238109
#     450/Unknown 735s 2s/step - accuracy: 0.5352 - loss: 66.9543Data is a string of length 175315
#     451/Unknown 736s 2s/step - accuracy: 0.5353 - loss: 66.8612Data is a string of length 60738
#     452/Unknown 737s 2s/step - accuracy: 0.5354 - loss: 66.7683Data is a string of length 60773
#     453/Unknown 738s 2s/step - accuracy: 0.5354 - loss: 66.6757Data is a string of length 112821
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US10299115 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 65329
#     454/Unknown 740s 2s/step - accuracy: 0.5355 - loss: 66.5839Data is a string of length 75461
#     455/Unknown 741s 2s/step - accuracy: 0.5355 - loss: 66.4924Data is a string of length 94799
#     456/Unknown 742s 2s/step - accuracy: 0.5356 - loss: 66.4012Data is a string of length 51589
#     457/Unknown 744s 2s/step - accuracy: 0.5357 - loss: 66.3102Data is a string of length 25995
# Data is a string of length 184530
#     459/Unknown 746s 2s/step - accuracy: 0.5358 - loss: 66.1292Data is a string of length 68493
#     460/Unknown 747s 2s/step - accuracy: 0.5358 - loss: 66.0391Data is a string of length 53807
#     461/Unknown 749s 2s/step - accuracy: 0.5359 - loss: 65.9492Data is a string of length 83134
#     462/Unknown 750s 2s/step - accuracy: 0.5360 - loss: 65.8597Data is a string of length 95659
#     463/Unknown 751s 2s/step - accuracy: 0.5360 - loss: 65.7705Data is a string of length 102570
#     464/Unknown 753s 2s/step - accuracy: 0.5361 - loss: 65.6815Data is a string of length 81061
#     465/Unknown 754s 2s/step - accuracy: 0.5361 - loss: 65.5929Data is a string of length 116496
#     466/Unknown 755s 2s/step - accuracy: 0.5362 - loss: 65.5045Data is a string of length 78272
#     467/Unknown 756s 2s/step - accuracy: 0.5363 - loss: 65.4163Data is a string of length 79773
#     468/Unknown 758s 2s/step - accuracy: 0.5363 - loss: 65.3285Data is a string of length 76929
#     469/Unknown 760s 2s/step - accuracy: 0.5364 - loss: 65.2409Data is a string of length 80286
#     470/Unknown 761s 2s/step - accuracy: 0.5364 - loss: 65.1536Data is a string of length 187814
#     471/Unknown 762s 2s/step - accuracy: 0.5365 - loss: 65.0665
#     472/Unknown 763s 2s/step - accuracy: 0.5365 - loss: 64.9797Data is a string of length 58359
#     473/Unknown 766s 2s/step - accuracy: 0.5366 - loss: 64.8932Data is a string of length 144165
#     474/Unknown 767s 2s/step - accuracy: 0.5367 - loss: 64.8069Data is a string of length 154172
# Data is a string of length 49038
#     476/Unknown 770s 2s/step - accuracy: 0.5367 - loss: 64.6352Data is a string of length 65253
#     477/Unknown 772s 2s/step - accuracy: 0.5368 - loss: 64.5497Data is a string of length 173602
#     478/Unknown 773s 2s/step - accuracy: 0.5368 - loss: 64.4645Data is a string of length 89551
# Data is a string of length 88809
#     480/Unknown 775s 2s/step - accuracy: 0.5369 - loss: 64.2948Data is a string of length 145506
#     481/Unknown 777s 2s/step - accuracy: 0.5370 - loss: 64.2103Data is a string of length 33677
#     482/Unknown 778s 2s/step - accuracy: 0.5370 - loss: 64.1261Data is a string of length 246961
#     483/Unknown 779s 2s/step - accuracy: 0.5371 - loss: 64.0421Data is a string of length 90292
#     484/Unknown 781s 2s/step - accuracy: 0.5371 - loss: 63.9584Data is a string of length 69701
#     485/Unknown 782s 2s/step - accuracy: 0.5372 - loss: 63.8749Data is a string of length 71640
#     486/Unknown 784s 2s/step - accuracy: 0.5372 - loss: 63.7917Data is a string of length 36590
#     487/Unknown 785s 2s/step - accuracy: 0.5372 - loss: 63.7087Data is a string of length 107893
#     488/Unknown 787s 2s/step - accuracy: 0.5373 - loss: 63.6260Data is a string of length 190690
# Data is a string of length 58831
#     490/Unknown 789s 2s/step - accuracy: 0.5374 - loss: 63.4612Data is a string of length 95035
# Data is a string of length 55154
#     492/Unknown 808s 2s/step - accuracy: 0.5375 - loss: 63.2975Data is a string of length 54145
#     493/Unknown 810s 2s/step - accuracy: 0.5375 - loss: 63.2159Data is a string of length 102766
#     494/Unknown 812s 2s/step - accuracy: 0.5376 - loss: 63.1346Data is a string of length 164183
#     495/Unknown 813s 2s/step - accuracy: 0.5376 - loss: 63.0536Data is a string of length 67525
#     496/Unknown 814s 2s/step - accuracy: 0.5377 - loss: 62.9728Data is a string of length 74118
# Data is a string of length 68885
#     498/Unknown 817s 2s/step - accuracy: 0.5377 - loss: 62.8118Data is a string of length 97631
#     499/Unknown 819s 2s/step - accuracy: 0.5378 - loss: 62.7317Data is a string of length 98177
#     500/Unknown 820s 2s/step - accuracy: 0.5378 - loss: 62.6518Data is a string of length 53380
#     501/Unknown 821s 2s/step - accuracy: 0.5378 - loss: 62.5722Data is a string of length 66994
#     502/Unknown 822s 2s/step - accuracy: 0.5379 - loss: 62.4928Data is a string of length 114057
# ...
#    2881/Unknown 4908s 2s/step - accuracy: 0.5692 - loss: 18.6149Data is a string of length 159435
#    2882/Unknown 4909s 2s/step - accuracy: 0.5692 - loss: 18.6103Data is a string of length 60079
#    2883/Unknown 4910s 2s/step - accuracy: 0.5692 - loss: 18.6057Data is a string of length 59968
#    2884/Unknown 4912s 2s/step - accuracy: 0.5692 - loss: 18.6011Data is a string of length 172085
#    2885/Unknown 4913s 2s/step - accuracy: 0.5692 - loss: 18.5965Data is a string of length 74414
#    2886/Unknown 4914s 2s/step - accuracy: 0.5692 - loss: 18.5919Data is a string of length 95608
# Data is a string of length 147285
#    2888/Unknown 4918s 2s/step - accuracy: 0.5692 - loss: 18.5827Data is a string of length 222869
# Data is a string of length 83567
#    2890/Unknown 4920s 2s/step - accuracy: 0.5692 - loss: 18.5735Data is a string of length 67032
#    2891/Unknown 4922s 2s/step - accuracy: 0.5692 - loss: 18.5690Data is a string of length 38671
#    2892/Unknown 4924s 2s/step - accuracy: 0.5692 - loss: 18.5645Data is a string of length 41737
#    2893/Unknown 4929s 2s/step - accuracy: 0.5692 - loss: 18.5599Data is a string of length 52356
#    2894/Unknown 4931s 2s/step - accuracy: 0.5693 - loss: 18.5554Data is a string of length 73899
#    2895/Unknown 4932s 2s/step - accuracy: 0.5693 - loss: 18.5508Data is a string of length 66962
#    2896/Unknown 4934s 2s/step - accuracy: 0.5693 - loss: 18.5463Data is a string of length 140473
#    2897/Unknown 4935s 2s/step - accuracy: 0.5693 - loss: 18.5418Data is a string of length 59636
#    2898/Unknown 4940s 2s/step - accuracy: 0.5693 - loss: 18.5372Data is a string of length 164395
#    2899/Unknown 4941s 2s/step - accuracy: 0.5693 - loss: 18.5327Data is a string of length 89552
#    2900/Unknown 4943s 2s/step - accuracy: 0.5693 - loss: 18.5282Data is a string of length 69063
#    2901/Unknown 4944s 2s/step - accuracy: 0.5693 - loss: 18.5237Data is a string of length 94063
#    2902/Unknown 4946s 2s/step - accuracy: 0.5693 - loss: 18.5192Data is a string of length 48724
#    2903/Unknown 4947s 2s/step - accuracy: 0.5693 - loss: 18.5146Data is a string of length 45503
#    2904/Unknown 4949s 2s/step - accuracy: 0.5693 - loss: 18.5101Data is a string of length 68733
#    2905/Unknown 4950s 2s/step - accuracy: 0.5693 - loss: 18.5056Data is a string of length 85400
#    2906/Unknown 4951s 2s/step - accuracy: 0.5693 - loss: 18.5011Data is a string of length 74453
#    2907/Unknown 4952s 2s/step - accuracy: 0.5693 - loss: 18.4966Data is a string of length 94084
# Data is a string of length 41938
#    2909/Unknown 4956s 2s/step - accuracy: 0.5694 - loss: 18.4876Data is a string of length 36847
#    2910/Unknown 4957s 2s/step - accuracy: 0.5694 - loss: 18.4831Data is a string of length 95068
#    2911/Unknown 4958s 2s/step - accuracy: 0.5694 - loss: 18.4786Data is a string of length 116817
#    2912/Unknown 4959s 2s/step - accuracy: 0.5694 - loss: 18.4741Data is a string of length 90955
#    2913/Unknown 4961s 2s/step - accuracy: 0.5694 - loss: 18.4696
#    2914/Unknown 4962s 2s/step - accuracy: 0.5694 - loss: 18.4651Data is a string of length 93303
#    2915/Unknown 4965s 2s/step - accuracy: 0.5694 - loss: 18.4606Data is a string of length 71383
#    2916/Unknown 4966s 2s/step - accuracy: 0.5694 - loss: 18.4562Data is a string of length 122485
# Data is a string of length 76128
#    2918/Unknown 4969s 2s/step - accuracy: 0.5694 - loss: 18.4472Data is a string of length 46751
#    2919/Unknown 4971s 2s/step - accuracy: 0.5694 - loss: 18.4427Data is a string of length 79345
#    2920/Unknown 4972s 2s/step - accuracy: 0.5694 - loss: 18.4383Data is a string of length 105361
#    2921/Unknown 4973s 2s/step - accuracy: 0.5694 - loss: 18.4338Data is a string of length 102973
#    2922/Unknown 4974s 2s/step - accuracy: 0.5694 - loss: 18.4293Data is a string of length 80897
#    2923/Unknown 4976s 2s/step - accuracy: 0.5695 - loss: 18.4249Data is a string of length 82111
#    2924/Unknown 4981s 2s/step - accuracy: 0.5695 - loss: 18.4204Data is a string of length 175995
#    2925/Unknown 4982s 2s/step - accuracy: 0.5695 - loss: 18.4159Data is a string of length 56931
#    2926/Unknown 4983s 2s/step - accuracy: 0.5695 - loss: 18.4115Data is a string of length 160054
#    2927/Unknown 4984s 2s/step - accuracy: 0.5695 - loss: 18.4070Data is a string of length 210849
#    2928/Unknown 4986s 2s/step - accuracy: 0.5695 - loss: 18.4026Data is a string of length 69051
#    2929/Unknown 4988s 2s/step - accuracy: 0.5695 - loss: 18.3981Data is a string of length 100499
#    2930/Unknown 4989s 2s/step - accuracy: 0.5695 - loss: 18.3937Data is a string of length 227442
#    2931/Unknown 4991s 2s/step - accuracy: 0.5695 - loss: 18.3892Data is a string of length 143300
#    2932/Unknown 4993s 2s/step - accuracy: 0.5695 - loss: 18.3848Data is a string of length 172153
#    2933/Unknown 4994s 2s/step - accuracy: 0.5695 - loss: 18.3803Data is a string of length 81533
#    2934/Unknown 4995s 2s/step - accuracy: 0.5695 - loss: 18.3759Data is a string of length 98775
#    2935/Unknown 4996s 2s/step - accuracy: 0.5695 - loss: 18.3715Data is a string of length 109342
#    2936/Unknown 5001s 2s/step - accuracy: 0.5695 - loss: 18.3670Data is a string of length 61955
#    2937/Unknown 5003s 2s/step - accuracy: 0.5696 - loss: 18.3626Data is a string of length 46469
#    2938/Unknown 5004s 2s/step - accuracy: 0.5696 - loss: 18.3582Data is a string of length 71741
#    2939/Unknown 5006s 2s/step - accuracy: 0.5696 - loss: 18.3537Data is a string of length 85360
# Data is a string of length 97489
#    2941/Unknown 5013s 2s/step - accuracy: 0.5696 - loss: 18.3449Data is a string of length 130747
#    2942/Unknown 5014s 2s/step - accuracy: 0.5696 - loss: 18.3405Data is a string of length 230554
#    2943/Unknown 5016s 2s/step - accuracy: 0.5696 - loss: 18.3361Data is a string of length 195125
#    2944/Unknown 5017s 2s/step - accuracy: 0.5696 - loss: 18.3317Data is a string of length 145113
#    2945/Unknown 5018s 2s/step - accuracy: 0.5696 - loss: 18.3272Data is a string of length 40691
#    2946/Unknown 5019s 2s/step - accuracy: 0.5696 - loss: 18.3228Data is a string of length 95656
#    2947/Unknown 5022s 2s/step - accuracy: 0.5696 - loss: 18.3184Data is a string of length 80266
#    2948/Unknown 5027s 2s/step - accuracy: 0.5696 - loss: 18.3140Data is a string of length 65110
#    2949/Unknown 5029s 2s/step - accuracy: 0.5696 - loss: 18.3096Data is a string of length 149856
# Data is a string of length 40613
#    2951/Unknown 5046s 2s/step - accuracy: 0.5697 - loss: 18.3008Data is a string of length 113102
# Data is a string of length 205062
#    2953/Unknown 5048s 2s/step - accuracy: 0.5697 - loss: 18.2920Data is a string of length 215225
#    2954/Unknown 5049s 2s/step - accuracy: 0.5697 - loss: 18.2877Data is a string of length 52396
#    2955/Unknown 5051s 2s/step - accuracy: 0.5697 - loss: 18.2833Data is a string of length 98157
#    2956/Unknown 5052s 2s/step - accuracy: 0.5697 - loss: 18.2789Data is a string of length 131732
# Data is a string of length 77885
#    2958/Unknown 5054s 2s/step - accuracy: 0.5697 - loss: 18.2701Data is a string of length 111376
#    2959/Unknown 5056s 2s/step - accuracy: 0.5697 - loss: 18.2657Data is a string of length 94814
# Data is a string of length 53310
#    2961/Unknown 5058s 2s/step - accuracy: 0.5697 - loss: 18.2570Data is a string of length 50605
# Data is a string of length 70957
#    2963/Unknown 5064s 2s/step - accuracy: 0.5697 - loss: 18.2483Data is a string of length 123446
#    2964/Unknown 5065s 2s/step - accuracy: 0.5697 - loss: 18.2439Data is a string of length 39242
#    2965/Unknown 5066s 2s/step - accuracy: 0.5697 - loss: 18.2395Data is a string of length 72418
#    2966/Unknown 5068s 2s/step - accuracy: 0.5697 - loss: 18.2352Data is a string of length 57457
#    2967/Unknown 5069s 2s/step - accuracy: 0.5698 - loss: 18.2308Data is a string of length 45851
#    2968/Unknown 5070s 2s/step - accuracy: 0.5698 - loss: 18.2265Data is a string of length 42686
#    2969/Unknown 5072s 2s/step - accuracy: 0.5698 - loss: 18.2221Data is a string of length 61616
#    2970/Unknown 5073s 2s/step - accuracy: 0.5698 - loss: 18.2178Data is a string of length 159246
#    2971/Unknown 5074s 2s/step - accuracy: 0.5698 - loss: 18.2134Data is a string of length 68308
#    2972/Unknown 5075s 2s/step - accuracy: 0.5698 - loss: 18.2091Data is a string of length 73926
#    2973/Unknown 5077s 2s/step - accuracy: 0.5698 - loss: 18.2047Data is a string of length 100699
#    2974/Unknown 5083s 2s/step - accuracy: 0.5698 - loss: 18.2004Data is a string of length 156623
#    2975/Unknown 5084s 2s/step - accuracy: 0.5698 - loss: 18.1961Data is a string of length 113575
#    2976/Unknown 5089s 2s/step - accuracy: 0.5698 - loss: 18.1917Data is a string of length 123036
#    2977/Unknown 5091s 2s/step - accuracy: 0.5698 - loss: 18.1874Data is a string of length 56418
# Data is a string of length 59360
#    2979/Unknown 5094s 2s/step - accuracy: 0.5698 - loss: 18.1787Data is a string of length 40351
#    2980/Unknown 5095s 2s/step - accuracy: 0.5698 - loss: 18.1744Data is a string of length 91695
#    2981/Unknown 5098s 2s/step - accuracy: 0.5698 - loss: 18.1701Data is a string of length 200218
# Data is a string of length 57900
#    2983/Unknown 5100s 2s/step - accuracy: 0.5699 - loss: 18.1614Data is a string of length 75131
#    2984/Unknown 5101s 2s/step - accuracy: 0.5699 - loss: 18.1571Data is a string of length 144201
#    2985/Unknown 5103s 2s/step - accuracy: 0.5699 - loss: 18.1528Data is a string of length 66008
# Data is a string of length 90261
#    2987/Unknown 5106s 2s/step - accuracy: 0.5699 - loss: 18.1442Data is a string of length 56932
#    2988/Unknown 5108s 2s/step - accuracy: 0.5699 - loss: 18.1399Data is a string of length 222986
#    2989/Unknown 5109s 2s/step - accuracy: 0.5699 - loss: 18.1356Data is a string of length 50971
#    2990/Unknown 5111s 2s/step - accuracy: 0.5699 - loss: 18.1313Data is a string of length 75884
#    2991/Unknown 5112s 2s/step - accuracy: 0.5699 - loss: 18.1270Data is a string of length 75586
# Data is a string of length 186335
#    2993/Unknown 5115s 2s/step - accuracy: 0.5699 - loss: 18.1184Data is a string of length 145003
# Data is a string of length 114666
#    2995/Unknown 5118s 2s/step - accuracy: 0.5699 - loss: 18.1098Data is a string of length 68171
#    2996/Unknown 5119s 2s/step - accuracy: 0.5699 - loss: 18.1055Data is a string of length 42669
#
# Saving periodic model checkpoint...
# Data is a string of length 92076
# Data is a string of length 227597
# Data is a string of length 94406
#    2998/Unknown 5126s 2s/step - accuracy: 0.5700 - loss: 18.0969Data is a string of length 59042
#    2999/Unknown 5127s 2s/step - accuracy: 0.5700 - loss: 18.0927Data is a string of length 80673
#    3000/Unknown 5128s 2s/step - accuracy: 0.5700 - loss: 18.0884Data is a string of length 112653
#    3001/Unknown 5130s 2s/step - accuracy: 0.5700 - loss: 18.0841Data is a string of length 45925
#    3002/Unknown 5131s 2s/step - accuracy: 0.5700 - loss: 18.0798Data is a string of length 44326
#    3004/Unknown 5133s 2s/step - accuracy: 0.5700 - loss: 18.0713Data is a string of length 111157
#    3005/Unknown 5134s 2s/step - accuracy: 0.5700 - loss: 18.0670Data is a string of length 88173
#    3006/Unknown 5136s 2s/step - accuracy: 0.5700 - loss: 18.0628Data is a string of length 94972
#    3007/Unknown 5137s 2s/step - accuracy: 0.5700 - loss: 18.0585Data is a string of length 145591
#    3008/Unknown 5138s 2s/step - accuracy: 0.5700 - loss: 18.0542Data is a string of length 42487
#    3009/Unknown 5139s 2s/step - accuracy: 0.5700 - loss: 18.0500Data is a string of length 90039
#    3010/Unknown 5141s 2s/step - accuracy: 0.5700 - loss: 18.0457Data is a string of length 28974
#    3011/Unknown 5142s 2s/step - accuracy: 0.5700 - loss: 18.0415Data is a string of length 91923
#    3012/Unknown 5143s 2s/step - accuracy: 0.5700 - loss: 18.0372Data is a string of length 110235
#    3013/Unknown 5144s 2s/step - accuracy: 0.5700 - loss: 18.0330Data is a string of length 61250
#    3015/Unknown 5147s 2s/step - accuracy: 0.5701 - loss: 18.0245Data is a string of length 76026
#    3016/Unknown 5148s 2s/step - accuracy: 0.5701 - loss: 18.0202Data is a string of length 87734
#    3017/Unknown 5150s 2s/step - accuracy: 0.5701 - loss: 18.0160Data is a string of length 87018
# Data is a string of length 72883
#    3018/Unknown 5151s 2s/step - accuracy: 0.5701 - loss: 18.0118Data is a string of length 66466
#    3019/Unknown 5153s 2s/step - accuracy: 0.5701 - loss: 18.0075Data is a string of length 57111
#    3021/Unknown 5155s 2s/step - accuracy: 0.5701 - loss: 17.9991Data is a string of length 85832
# Data is a string of length 46926
#    3022/Unknown 5157s 2s/step - accuracy: 0.5701 - loss: 17.9948Data is a string of length 122607
#    3023/Unknown 5158s 2s/step - accuracy: 0.5701 - loss: 17.9906Data is a string of length 41745
#    3025/Unknown 5160s 2s/step - accuracy: 0.5701 - loss: 17.9822Data is a string of length 166594
#    3026/Unknown 5162s 2s/step - accuracy: 0.5701 - loss: 17.9780Data is a string of length 62038
# Data is a string of length 73903
#    3027/Unknown 5163s 2s/step - accuracy: 0.5701 - loss: 17.9737Data is a string of length 64091
#    3029/Unknown 5165s 2s/step - accuracy: 0.5701 - loss: 17.9653Data is a string of length 134926
# Data is a string of length 56216
#    3031/Unknown 5168s 2s/step - accuracy: 0.5702 - loss: 17.9569Data is a string of length 36579
#    3032/Unknown 5169s 2s/step - accuracy: 0.5702 - loss: 17.9527Data is a string of length 197454
# Data is a string of length 132632
#    3034/Unknown 5172s 2s/step - accuracy: 0.5702 - loss: 17.9443Data is a string of length 62208
# Data is a string of length 179489
#    3036/Unknown 5174s 2s/step - accuracy: 0.5702 - loss: 17.9359Data is a string of length 33006
#    3037/Unknown 5176s 2s/step - accuracy: 0.5702 - loss: 17.9317Data is a string of length 183103
#    3038/Unknown 5177s 2s/step - accuracy: 0.5702 - loss: 17.9275Data is a string of length 86192
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2019097657 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 32885
#    3039/Unknown 5178s 2s/step - accuracy: 0.5702 - loss: 17.9233Data is a string of length 37656
#    3040/Unknown 5181s 2s/step - accuracy: 0.5702 - loss: 17.9191Data is a string of length 39462
#    3041/Unknown 5182s 2s/step - accuracy: 0.5702 - loss: 17.9150Data is a string of length 50922
#    3042/Unknown 5184s 2s/step - accuracy: 0.5702 - loss: 17.9108Data is a string of length 101899
# Data is a string of length 170249
#    3043/Unknown 5185s 2s/step - accuracy: 0.5702 - loss: 17.9066Data is a string of length 106214
#    3044/Unknown 5186s 2s/step - accuracy: 0.5702 - loss: 17.9024Data is a string of length 31031
#    3046/Unknown 5189s 2s/step - accuracy: 0.5702 - loss: 17.8941Data is a string of length 44469
# Data is a string of length 73069
#    3048/Unknown 5191s 2s/step - accuracy: 0.5703 - loss: 17.8857Data is a string of length 47526
# Data is a string of length 102035
#    3050/Unknown 5194s 2s/step - accuracy: 0.5703 - loss: 17.8774Data is a string of length 80222
# Data is a string of length 63337
#    3052/Unknown 5197s 2s/step - accuracy: 0.5703 - loss: 17.8691Data is a string of length 57596
#    3053/Unknown 5198s 2s/step - accuracy: 0.5703 - loss: 17.8649Data is a string of length 152604
# Data is a string of length 161183
#    3055/Unknown 5201s 2s/step - accuracy: 0.5703 - loss: 17.8566Data is a string of length 44726
# Data is a string of length 24081
#    3057/Unknown 5206s 2s/step - accuracy: 0.5703 - loss: 17.8483Data is a string of length 99414
# Training process finished.
# Exception during DOC text extraction: antiword failed:
#
# Skipping sample: US2011243094 A1,Standard=TS 36.331 v9.9.0.zipdie to empty text.
# Data is a string of length 118688
# KeyboardInterrupt
# Data is a string of length 139923
# Data is a string of length 74291
# Data is a string of length 164736
# Data is a string of length 71018
# Data is a string of length 200959
# Data is a string of length 191600
# Data is a string of length 101439

# %%
predictions = model.predict(test_tf_dataset)
# Out:
# Data is a string of length 74466
# Data is a string of length 70203
# W0000 00:00:1722787238.222414 2363054 assert_op.cc:38] Ignoring Assert operator functional_3_1/bert_model_layer_3_1/tf_bert_model_4/bert/embeddings/assert_less/Assert/Assert
# W0000 00:00:1722787238.228208 2363054 assert_op.cc:38] Ignoring Assert operator functional_3_1/bert_model_layer_2_1/tf_bert_model_3/bert/embeddings/assert_less/Assert/Assert
#       1/Unknown 10s 10s/stepData is a string of length 66217
#       2/Unknown 11s 1s/step Data is a string of length 41435
#       3/Unknown 12s 1s/stepData is a string of length 79689
#       4/Unknown 13s 1s/stepData is a string of length 116738
#       5/Unknown 15s 1s/stepData is a string of length 76258
#       6/Unknown 17s 1s/stepData is a string of length 92048
#       7/Unknown 18s 1s/stepData is a string of length 99918
#       8/Unknown 19s 1s/stepData is a string of length 115843
#       9/Unknown 20s 1s/stepData is a string of length 80657
#      10/Unknown 22s 1s/stepData is a string of length 119004
#      11/Unknown 23s 1s/stepData is a string of length 232200
#      12/Unknown 24s 1s/stepData is a string of length 51929
#      13/Unknown 25s 1s/stepData is a string of length 103652
#      14/Unknown 26s 1s/stepData is a string of length 49709
#      15/Unknown 28s 1s/stepData is a string of length 58826
#      16/Unknown 29s 1s/stepData is a string of length 105344
#      17/Unknown 30s 1s/stepData is a string of length 76603
#      18/Unknown 31s 1s/stepData is a string of length 92526
#      19/Unknown 33s 1s/stepData is a string of length 100970
#      20/Unknown 35s 1s/stepData is a string of length 135458
#      21/Unknown 36s 1s/stepData is a string of length 64801
#      22/Unknown 37s 1s/stepData is a string of length 151481
#      23/Unknown 38s 1s/stepData is a string of length 270921
#      24/Unknown 39s 1s/stepData is a string of length 68232
#      25/Unknown 41s 1s/stepData is a string of length 78184
#      26/Unknown 43s 1s/stepData is a string of length 210126
#      27/Unknown 45s 1s/stepData is a string of length 27003
#      28/Unknown 46s 1s/stepData is a string of length 60115
#      29/Unknown 47s 1s/stepData is a string of length 56269
#      30/Unknown 48s 1s/stepData is a string of length 141340
#      31/Unknown 49s 1s/stepData is a string of length 40485
#      32/Unknown 51s 1s/stepData is a string of length 159294
#      33/Unknown 52s 1s/stepData is a string of length 118542
#      34/Unknown 53s 1s/stepData is a string of length 81980
#      35/Unknown 54s 1s/stepData is a string of length 95065
#      36/Unknown 56s 1s/stepData is a string of length 74770
#      37/Unknown 58s 1s/stepData is a string of length 85396
#      38/Unknown 60s 1s/stepData is a string of length 49395
#      39/Unknown 61s 1s/stepData is a string of length 120063
#      40/Unknown 63s 1s/stepData is a string of length 47647
#      41/Unknown 64s 1s/stepData is a string of length 204205
#      42/Unknown 65s 1s/stepData is a string of length 26553
#      43/Unknown 66s 1s/stepData is a string of length 102862
#      44/Unknown 69s 1s/stepData is a string of length 46405
#      45/Unknown 71s 1s/stepData is a string of length 263700
#      46/Unknown 72s 1s/stepData is a string of length 113716
#      47/Unknown 73s 1s/stepData is a string of length 48403
#      48/Unknown 74s 1s/stepData is a string of length 43636
#      49/Unknown 76s 1s/stepData is a string of length 159685
#      50/Unknown 77s 1s/stepData is a string of length 52907
#      51/Unknown 78s 1s/stepData is a string of length 115043
#      52/Unknown 83s 1s/stepData is a string of length 83637
#      53/Unknown 85s 1s/stepData is a string of length 38241
#      54/Unknown 86s 1s/stepData is a string of length 65630
#      55/Unknown 88s 1s/stepData is a string of length 113073
#      56/Unknown 90s 1s/stepData is a string of length 65687
#      57/Unknown 92s 1s/stepData is a string of length 39265
#      58/Unknown 93s 1s/stepData is a string of length 120017
#      59/Unknown 94s 1s/stepData is a string of length 196945
#      60/Unknown 97s 1s/stepData is a string of length 120977
#      61/Unknown 98s 1s/stepData is a string of length 111020
#      62/Unknown 100s 1s/stepData is a string of length 94164
#      63/Unknown 101s 1s/stepData is a string of length 71174
#      64/Unknown 102s 1s/stepData is a string of length 47236
#      65/Unknown 103s 1s/stepData is a string of length 62986
#      66/Unknown 105s 1s/stepData is a string of length 98657
#      67/Unknown 106s 1s/stepData is a string of length 79923
#      68/Unknown 107s 1s/stepData is a string of length 53258
#      69/Unknown 108s 1s/stepData is a string of length 99229
#      70/Unknown 110s 1s/stepData is a string of length 113391
#      71/Unknown 112s 1s/stepData is a string of length 64778
#      72/Unknown 114s 1s/stepData is a string of length 259878
#      73/Unknown 115s 1s/stepData is a string of length 92031
#      74/Unknown 116s 1s/stepData is a string of length 46641
#      75/Unknown 117s 1s/stepData is a string of length 68288
#      76/Unknown 118s 1s/stepData is a string of length 58253
#      77/Unknown 120s 1s/stepData is a string of length 206720
#      78/Unknown 125s 2s/stepData is a string of length 92500
#      79/Unknown 127s 2s/stepData is a string of length 116428
#      80/Unknown 128s 2s/stepData is a string of length 91933
#      81/Unknown 129s 1s/stepData is a string of length 68527
#      82/Unknown 131s 1s/stepData is a string of length 160835
#      83/Unknown 132s 1s/stepData is a string of length 103807
#      84/Unknown 133s 1s/stepData is a string of length 82254
#      85/Unknown 134s 1s/stepData is a string of length 81002
#      86/Unknown 136s 1s/stepData is a string of length 133188
#      87/Unknown 137s 1s/stepData is a string of length 113615
#      88/Unknown 138s 1s/stepData is a string of length 49457
#      89/Unknown 139s 1s/stepData is a string of length 87575
#      90/Unknown 141s 1s/stepData is a string of length 106844
#      91/Unknown 143s 1s/stepData is a string of length 100206
#      92/Unknown 148s 2s/stepData is a string of length 98595
#      93/Unknown 149s 2s/stepData is a string of length 65875
#      94/Unknown 151s 2s/stepData is a string of length 28222
#      95/Unknown 152s 2s/stepData is a string of length 55868
#      96/Unknown 153s 2s/stepData is a string of length 41938
#      97/Unknown 155s 2s/stepData is a string of length 61754
#      98/Unknown 156s 2s/stepData is a string of length 71730
#      99/Unknown 157s 2s/stepData is a string of length 157618
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2003072290 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 68686
#     100/Unknown 158s 2s/stepData is a string of length 82213
#     101/Unknown 159s 1s/stepData is a string of length 61142
#     102/Unknown 161s 2s/stepData is a string of length 95912
#     103/Unknown 163s 1s/stepData is a string of length 97021
#     104/Unknown 165s 2s/stepData is a string of length 77245
#     105/Unknown 166s 2s/stepData is a string of length 40738
#     106/Unknown 167s 2s/stepData is a string of length 83864
#     107/Unknown 168s 1s/stepData is a string of length 198585
#     108/Unknown 170s 1s/stepData is a string of length 38033
#     109/Unknown 171s 1s/stepData is a string of length 172116
#     110/Unknown 172s 1s/stepData is a string of length 216590
#     111/Unknown 173s 1s/stepData is a string of length 47158
#     112/Unknown 175s 1s/stepData is a string of length 108502
#     113/Unknown 176s 1s/stepData is a string of length 131347
#     114/Unknown 177s 1s/stepData is a string of length 316083
#     115/Unknown 179s 1s/stepData is a string of length 73366
#     116/Unknown 180s 1s/stepData is a string of length 41987
#     117/Unknown 181s 1s/stepData is a string of length 110803
#     118/Unknown 183s 1s/stepData is a string of length 76058
#     119/Unknown 184s 1s/stepData is a string of length 66684
#     120/Unknown 185s 1s/stepData is a string of length 37180
#     121/Unknown 186s 1s/stepData is a string of length 47645
#     122/Unknown 187s 1s/stepData is a string of length 30413
#     123/Unknown 189s 1s/stepData is a string of length 62496
#     124/Unknown 190s 1s/stepData is a string of length 84860
#     125/Unknown 191s 1s/stepData is a string of length 71580
#     126/Unknown 193s 1s/stepData is a string of length 58752
#     127/Unknown 195s 1s/stepData is a string of length 52048
#     128/Unknown 196s 1s/stepData is a string of length 160925
#     129/Unknown 198s 1s/stepData is a string of length 51937
#     130/Unknown 199s 1s/stepData is a string of length 65591
#     131/Unknown 200s 1s/stepData is a string of length 162861
#     132/Unknown 201s 1s/stepData is a string of length 102211
#     133/Unknown 203s 1s/stepData is a string of length 76482
#     134/Unknown 204s 1s/stepData is a string of length 180994
#     135/Unknown 205s 1s/stepData is a string of length 146310
#     136/Unknown 207s 1s/stepData is a string of length 50196
#     137/Unknown 208s 1s/stepData is a string of length 195677
#     138/Unknown 210s 1s/stepData is a string of length 47980
#     139/Unknown 211s 1s/stepData is a string of length 185625
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: CN110521146 A,Standard=TS 33.501.501die to empty text.
# Data is a string of length 96904
#     140/Unknown 212s 1s/stepData is a string of length 43086
#     141/Unknown 213s 1s/stepData is a string of length 173725
#     142/Unknown 214s 1s/stepData is a string of length 69435
#     143/Unknown 216s 1s/stepData is a string of length 91003
#     144/Unknown 217s 1s/stepData is a string of length 103230
#     145/Unknown 218s 1s/stepData is a string of length 46349
#     146/Unknown 220s 1s/stepData is a string of length 57884
#     147/Unknown 221s 1s/stepData is a string of length 83341
#     148/Unknown 223s 1s/stepData is a string of length 95185
#     149/Unknown 224s 1s/stepData is a string of length 67936
#     150/Unknown 226s 1s/stepData is a string of length 123531
#     151/Unknown 227s 1s/stepData is a string of length 68362
#     152/Unknown 228s 1s/stepData is a string of length 103658
#     153/Unknown 230s 1s/stepData is a string of length 92301
#     154/Unknown 231s 1s/stepData is a string of length 84021
#     155/Unknown 232s 1s/stepData is a string of length 86533
#     156/Unknown 233s 1s/stepData is a string of length 118791
#     157/Unknown 235s 1s/stepData is a string of length 53379
#     158/Unknown 236s 1s/stepData is a string of length 93335
#     159/Unknown 237s 1s/stepData is a string of length 90601
#     160/Unknown 238s 1s/stepData is a string of length 73497
#     161/Unknown 240s 1s/stepData is a string of length 33822
#     162/Unknown 241s 1s/stepData is a string of length 76423
#     163/Unknown 243s 1s/stepData is a string of length 56162
#     164/Unknown 244s 1s/stepData is a string of length 61629
#     165/Unknown 245s 1s/stepData is a string of length 104515
#     166/Unknown 246s 1s/stepData is a string of length 35673
#     167/Unknown 248s 1s/stepData is a string of length 126824
#     168/Unknown 249s 1s/stepData is a string of length 101990
#     169/Unknown 251s 1s/stepData is a string of length 111196
#     170/Unknown 252s 1s/stepData is a string of length 38477
#     171/Unknown 255s 1s/stepData is a string of length 35724
#     172/Unknown 256s 1s/stepData is a string of length 21393
#     173/Unknown 257s 1s/stepData is a string of length 93214
#     174/Unknown 259s 1s/stepData is a string of length 44513
#     175/Unknown 260s 1s/stepData is a string of length 92686
#     176/Unknown 261s 1s/stepData is a string of length 129617
#     177/Unknown 262s 1s/stepData is a string of length 88257
#     178/Unknown 264s 1s/stepData is a string of length 70967
#     179/Unknown 265s 1s/stepData is a string of length 73027
#     180/Unknown 266s 1s/stepData is a string of length 45490
#     181/Unknown 267s 1s/stepData is a string of length 75978
#     182/Unknown 269s 1s/stepData is a string of length 111066
#     183/Unknown 270s 1s/stepData is a string of length 74381
#     184/Unknown 271s 1s/stepData is a string of length 349353
#     185/Unknown 273s 1s/stepData is a string of length 49861
#     186/Unknown 274s 1s/stepData is a string of length 65525
#     187/Unknown 275s 1s/stepData is a string of length 92929
#     188/Unknown 277s 1s/stepData is a string of length 53521
#     189/Unknown 278s 1s/stepData is a string of length 38550
#     190/Unknown 279s 1s/stepData is a string of length 113219
#     191/Unknown 280s 1s/stepData is a string of length 77799
#     192/Unknown 282s 1s/stepData is a string of length 119310
#     193/Unknown 284s 1s/stepData is a string of length 97451
#     194/Unknown 285s 1s/stepData is a string of length 90882
#     195/Unknown 286s 1s/stepData is a string of length 106520
#     196/Unknown 288s 1s/stepData is a string of length 131657
#     197/Unknown 289s 1s/stepData is a string of length 88986
#     198/Unknown 310s 2s/stepData is a string of length 209119
#     199/Unknown 312s 2s/stepData is a string of length 26333
#     200/Unknown 313s 2s/stepData is a string of length 139214
#     201/Unknown 314s 2s/stepData is a string of length 63804
#     202/Unknown 315s 2s/stepData is a string of length 60431
#     203/Unknown 317s 2s/stepData is a string of length 67136
#     204/Unknown 318s 2s/stepData is a string of length 95303
#     205/Unknown 319s 2s/stepData is a string of length 93220
#     206/Unknown 320s 2s/stepData is a string of length 73144
#     207/Unknown 321s 2s/stepData is a string of length 64780
#     208/Unknown 323s 2s/stepData is a string of length 35213
#     209/Unknown 324s 2s/stepData is a string of length 154177
#     210/Unknown 325s 2s/stepData is a string of length 169921
#     211/Unknown 326s 2s/stepData is a string of length 64295
#     212/Unknown 329s 2s/stepData is a string of length 86142
#     213/Unknown 330s 2s/stepData is a string of length 119599
#     214/Unknown 332s 2s/stepData is a string of length 81821
#     215/Unknown 334s 2s/stepData is a string of length 63141
#     216/Unknown 335s 2s/stepData is a string of length 71248
#     217/Unknown 336s 2s/stepData is a string of length 27713
#     218/Unknown 337s 2s/stepData is a string of length 73588
#     219/Unknown 339s 2s/stepData is a string of length 84244
#     220/Unknown 341s 2s/stepData is a string of length 92258
#     221/Unknown 343s 2s/stepData is a string of length 50091
#     222/Unknown 344s 2s/stepData is a string of length 59351
#     223/Unknown 346s 2s/stepData is a string of length 77047
#     224/Unknown 347s 2s/stepData is a string of length 66215
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US11337228 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 146319
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US8850203 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 77140
#     225/Unknown 348s 2s/stepData is a string of length 238754
#     226/Unknown 351s 2s/stepData is a string of length 115650
#     227/Unknown 352s 2s/stepData is a string of length 41056
#     228/Unknown 354s 2s/stepData is a string of length 84692
#     229/Unknown 355s 2s/stepData is a string of length 71638
#     230/Unknown 357s 2s/stepData is a string of length 36852
#     231/Unknown 363s 2s/stepData is a string of length 118853
#     232/Unknown 364s 2s/stepData is a string of length 53044
#     233/Unknown 365s 2s/stepData is a string of length 78365
#     234/Unknown 367s 2s/stepData is a string of length 48155
#     235/Unknown 368s 2s/stepData is a string of length 124137
#     236/Unknown 369s 2s/stepData is a string of length 128846
#     237/Unknown 370s 2s/stepData is a string of length 113760
#     238/Unknown 372s 2s/stepData is a string of length 36400
#     239/Unknown 374s 2s/stepData is a string of length 44125
#     240/Unknown 375s 2s/stepData is a string of length 61187
#     241/Unknown 376s 2s/stepData is a string of length 206348
#     242/Unknown 378s 2s/stepData is a string of length 91440
#     243/Unknown 379s 2s/stepData is a string of length 56821
#     244/Unknown 380s 2s/stepData is a string of length 104863
#     245/Unknown 382s 2s/stepData is a string of length 175965
#     246/Unknown 383s 2s/stepData is a string of length 79150
#     247/Unknown 384s 2s/stepData is a string of length 41422
#     248/Unknown 385s 2s/stepData is a string of length 141380
#     249/Unknown 387s 2s/stepData is a string of length 120276
#     250/Unknown 389s 2s/stepData is a string of length 57544
#     251/Unknown 390s 2s/stepData is a string of length 163950
#     252/Unknown 391s 2s/stepData is a string of length 174624
#     253/Unknown 393s 2s/stepData is a string of length 90490
#     254/Unknown 394s 2s/stepData is a string of length 103570
#     255/Unknown 396s 2s/stepData is a string of length 43917
#     256/Unknown 397s 2s/stepData is a string of length 130750
#     257/Unknown 398s 2s/stepData is a string of length 163523
#     258/Unknown 400s 2s/stepData is a string of length 56461
#     259/Unknown 401s 2s/stepData is a string of length 146179
#     260/Unknown 403s 2s/stepData is a string of length 97627
#     261/Unknown 404s 2s/stepData is a string of length 79202
#     262/Unknown 405s 2s/stepData is a string of length 121329
#     263/Unknown 406s 2s/stepData is a string of length 94794
#     264/Unknown 407s 2s/stepData is a string of length 52352
#     265/Unknown 409s 2s/stepData is a string of length 61498
#     266/Unknown 410s 2s/stepData is a string of length 31936
#     267/Unknown 411s 2s/stepData is a string of length 39121
#     268/Unknown 412s 2s/stepData is a string of length 44850
#     269/Unknown 414s 2s/stepData is a string of length 57123
#     270/Unknown 415s 2s/stepData is a string of length 63316
#     271/Unknown 416s 2s/stepData is a string of length 169215
#     272/Unknown 417s 2s/stepData is a string of length 255282
#     273/Unknown 419s 2s/stepData is a string of length 52696
#     274/Unknown 420s 2s/stepData is a string of length 109600
#     275/Unknown 422s 2s/stepData is a string of length 53959
#     276/Unknown 423s 2s/stepData is a string of length 88910
#     277/Unknown 425s 2s/stepData is a string of length 67149
#     278/Unknown 426s 2s/stepData is a string of length 73478
#     279/Unknown 442s 2s/stepData is a string of length 98407
#     280/Unknown 443s 2s/stepData is a string of length 55549
#     281/Unknown 447s 2s/stepData is a string of length 88002
#     282/Unknown 448s 2s/stepData is a string of length 56055
#     283/Unknown 450s 2s/stepData is a string of length 115527
#     284/Unknown 451s 2s/stepData is a string of length 109409
#     285/Unknown 452s 2s/stepData is a string of length 115527
#     286/Unknown 454s 2s/stepData is a string of length 118056
#     287/Unknown 456s 2s/stepData is a string of length 101577
#     288/Unknown 457s 2s/stepData is a string of length 42861
#     289/Unknown 458s 2s/stepData is a string of length 78500
#     290/Unknown 460s 2s/stepData is a string of length 37835
#     291/Unknown 461s 2s/stepData is a string of length 62584
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2017055152 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 100755
#     292/Unknown 462s 2s/stepData is a string of length 69901
#     293/Unknown 464s 2s/stepData is a string of length 125914
#     294/Unknown 465s 2s/stepData is a string of length 35724
#     295/Unknown 468s 2s/stepData is a string of length 82479
#     296/Unknown 469s 2s/stepData is a string of length 368802
#     297/Unknown 471s 2s/stepData is a string of length 129253
#     298/Unknown 472s 2s/stepData is a string of length 38102
#     299/Unknown 474s 2s/stepData is a string of length 36927
#     300/Unknown 479s 2s/stepData is a string of length 74771
#     301/Unknown 480s 2s/stepData is a string of length 54302
#     302/Unknown 481s 2s/stepData is a string of length 86071
#     303/Unknown 483s 2s/stepData is a string of length 64582
#     304/Unknown 484s 2s/stepData is a string of length 61646
#     305/Unknown 485s 2s/stepData is a string of length 96764
#     306/Unknown 486s 2s/stepData is a string of length 67788
#     307/Unknown 488s 2s/stepData is a string of length 89261
#     308/Unknown 490s 2s/stepData is a string of length 105656
#     309/Unknown 491s 2s/stepData is a string of length 34450
#     310/Unknown 493s 2s/stepData is a string of length 80490
#     311/Unknown 494s 2s/stepData is a string of length 68642
#     312/Unknown 495s 2s/stepData is a string of length 84447
#     313/Unknown 496s 2s/stepData is a string of length 52519
#     314/Unknown 497s 2s/stepData is a string of length 153871
#     315/Unknown 499s 2s/stepData is a string of length 93761
#     316/Unknown 500s 2s/stepData is a string of length 115415
#     317/Unknown 501s 2s/stepData is a string of length 61049
#     318/Unknown 502s 2s/stepData is a string of length 63581
#     319/Unknown 504s 2s/stepData is a string of length 71340
#     320/Unknown 505s 2s/stepData is a string of length 112228
#     321/Unknown 506s 2s/stepData is a string of length 111580
#     322/Unknown 507s 2s/stepData is a string of length 114197
#     323/Unknown 509s 2s/stepData is a string of length 43515
#     324/Unknown 510s 2s/stepData is a string of length 43001
#     325/Unknown 512s 2s/stepData is a string of length 78418
#     326/Unknown 513s 2s/stepData is a string of length 98656
#     327/Unknown 514s 2s/stepData is a string of length 37236
#     328/Unknown 515s 2s/stepData is a string of length 82669
#     329/Unknown 517s 2s/stepData is a string of length 50063
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2022104021 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 53586
#     330/Unknown 518s 2s/stepData is a string of length 59343
#     331/Unknown 519s 2s/stepData is a string of length 50146
#     332/Unknown 520s 2s/stepData is a string of length 57472
#     333/Unknown 521s 2s/stepData is a string of length 65329
#     334/Unknown 523s 2s/stepData is a string of length 42437
#     335/Unknown 524s 2s/stepData is a string of length 82407
#     336/Unknown 525s 2s/stepData is a string of length 72756
#     337/Unknown 526s 2s/stepData is a string of length 62029
#     338/Unknown 528s 2s/stepData is a string of length 45738
#     339/Unknown 529s 2s/stepData is a string of length 80144
#     340/Unknown 531s 2s/stepData is a string of length 66705
#     341/Unknown 532s 2s/stepData is a string of length 80619
#     342/Unknown 533s 2s/stepData is a string of length 117272
#     343/Unknown 535s 2s/stepData is a string of length 57749
#     344/Unknown 536s 2s/stepData is a string of length 71331
#     345/Unknown 537s 2s/stepData is a string of length 51838
#     346/Unknown 540s 2s/stepData is a string of length 60473
#     347/Unknown 541s 2s/stepData is a string of length 56194
#     348/Unknown 543s 2s/stepData is a string of length 108815
#     349/Unknown 544s 2s/stepData is a string of length 76268
#     350/Unknown 546s 2s/stepData is a string of length 99311
#     351/Unknown 547s 2s/stepData is a string of length 46449
#     352/Unknown 548s 2s/stepData is a string of length 137885
#     353/Unknown 550s 2s/stepData is a string of length 45856
#     354/Unknown 551s 2s/stepData is a string of length 40583
#     355/Unknown 552s 2s/stepData is a string of length 230108
#     356/Unknown 553s 2s/stepData is a string of length 77581
#     357/Unknown 555s 2s/stepData is a string of length 218579
#     358/Unknown 556s 2s/stepData is a string of length 59714
#     359/Unknown 558s 2s/stepData is a string of length 115253
#     360/Unknown 559s 2s/stepData is a string of length 104024
#     361/Unknown 565s 2s/stepData is a string of length 58244
#     362/Unknown 567s 2s/stepData is a string of length 146140
#     363/Unknown 568s 2s/stepData is a string of length 55289
#     364/Unknown 569s 2s/stepData is a string of length 357556
#     365/Unknown 571s 2s/stepData is a string of length 90429
#     366/Unknown 573s 2s/stepData is a string of length 85682
#     367/Unknown 574s 2s/stepData is a string of length 67201
#     368/Unknown 575s 2s/stepData is a string of length 60728
#     369/Unknown 576s 2s/stepData is a string of length 204055
#     370/Unknown 578s 2s/stepData is a string of length 95379
#     371/Unknown 579s 2s/stepData is a string of length 155374
#     372/Unknown 580s 2s/stepData is a string of length 41909
#     373/Unknown 581s 2s/stepData is a string of length 129201
#     374/Unknown 583s 2s/stepData is a string of length 62804
#     375/Unknown 585s 2s/stepData is a string of length 65746
#     376/Unknown 586s 2s/stepData is a string of length 95035
#     377/Unknown 588s 2s/stepData is a string of length 90327
#     378/Unknown 589s 2s/stepData is a string of length 105508
#     379/Unknown 591s 2s/stepData is a string of length 344211
#     380/Unknown 592s 2s/stepData is a string of length 93107
#     381/Unknown 594s 2s/stepData is a string of length 91621
#     382/Unknown 595s 2s/stepData is a string of length 79122
#     383/Unknown 596s 2s/stepData is a string of length 128892
#     384/Unknown 597s 2s/stepData is a string of length 37343
#     385/Unknown 599s 2s/stepData is a string of length 147031
#     386/Unknown 600s 2s/stepData is a string of length 37163
#     387/Unknown 601s 2s/stepData is a string of length 73340
#     388/Unknown 602s 2s/stepData is a string of length 34852
#     389/Unknown 604s 2s/stepData is a string of length 52440
#     390/Unknown 605s 2s/stepData is a string of length 60305
#     391/Unknown 607s 2s/stepData is a string of length 84466
#     392/Unknown 608s 2s/stepData is a string of length 158371
#     393/Unknown 615s 2s/stepData is a string of length 140725
#     394/Unknown 616s 2s/stepData is a string of length 43493
#     395/Unknown 617s 2s/stepData is a string of length 61636
#     396/Unknown 619s 2s/stepData is a string of length 87469
#     397/Unknown 620s 2s/stepData is a string of length 149366
#     398/Unknown 621s 2s/stepData is a string of length 38843
#     399/Unknown 623s 2s/stepData is a string of length 48357
#     400/Unknown 624s 2s/stepData is a string of length 94461
#     401/Unknown 625s 2s/stepData is a string of length 220296
#     402/Unknown 626s 2s/stepData is a string of length 102275
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US2016294811 A1,Standard=TS 33.501.501die to empty text.
# Data is a string of length 97243
#     403/Unknown 630s 2s/stepData is a string of length 43515
#     404/Unknown 631s 2s/stepData is a string of length 47725
#     405/Unknown 633s 2s/stepData is a string of length 46225
#     406/Unknown 634s 2s/stepData is a string of length 39761
#     407/Unknown 635s 2s/stepData is a string of length 61177
#     408/Unknown 636s 2s/stepData is a string of length 73158
#     409/Unknown 639s 2s/stepData is a string of length 87406
#     410/Unknown 640s 2s/stepData is a string of length 65768
#     411/Unknown 642s 2s/stepData is a string of length 56633
#     412/Unknown 643s 2s/stepData is a string of length 26738
#     413/Unknown 644s 2s/stepData is a string of length 51481
#     414/Unknown 645s 2s/stepData is a string of length 102361
#     415/Unknown 647s 2s/stepData is a string of length 106871
#     416/Unknown 648s 2s/stepData is a string of length 75155
#     417/Unknown 649s 2s/stepData is a string of length 76122
#     418/Unknown 651s 2s/stepData is a string of length 75272
#     419/Unknown 652s 2s/stepData is a string of length 70040
#     420/Unknown 653s 2s/stepData is a string of length 19765
#     421/Unknown 654s 2s/stepData is a string of length 160498
#     422/Unknown 655s 2s/stepData is a string of length 55758
#     423/Unknown 657s 2s/stepData is a string of length 71231
#     424/Unknown 658s 2s/stepData is a string of length 114218
#     425/Unknown 660s 2s/stepData is a string of length 91072
#     426/Unknown 662s 2s/stepData is a string of length 128230
#     427/Unknown 664s 2s/stepData is a string of length 133825
#     428/Unknown 665s 2s/stepData is a string of length 53434
#     429/Unknown 667s 2s/stepData is a string of length 53963
#     430/Unknown 668s 2s/stepData is a string of length 67443
#     431/Unknown 669s 2s/stepData is a string of length 72414
#     432/Unknown 670s 2s/stepData is a string of length 31805
#     433/Unknown 672s 2s/stepData is a string of length 104305
#     434/Unknown 673s 2s/stepData is a string of length 61222
#     435/Unknown 674s 2s/stepData is a string of length 69127
#     436/Unknown 675s 2s/stepData is a string of length 139263
#     437/Unknown 676s 2s/stepData is a string of length 336404
#     438/Unknown 678s 2s/stepData is a string of length 51168
#     439/Unknown 679s 2s/stepData is a string of length 266892
#     440/Unknown 680s 2s/stepData is a string of length 71352
#     441/Unknown 682s 2s/stepData is a string of length 52222
#     442/Unknown 683s 2s/stepData is a string of length 50536
#     443/Unknown 684s 2s/stepData is a string of length 57660
#     444/Unknown 685s 2s/stepData is a string of length 71076
#     445/Unknown 687s 2s/stepData is a string of length 61524
#     446/Unknown 688s 2s/stepData is a string of length 90436
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.203/ does not exist.
#
# Skipping sample: US9660713 B2,Standard=TS 33.203.203die to empty text.
# Data is a string of length 56224
#     447/Unknown 689s 2s/stepData is a string of length 33146
#     448/Unknown 691s 2s/stepData is a string of length 30489
#     449/Unknown 693s 2s/stepData is a string of length 238109
#     450/Unknown 696s 2s/stepData is a string of length 175315
#     451/Unknown 697s 2s/stepData is a string of length 60738
#     452/Unknown 698s 2s/stepData is a string of length 60773
#     453/Unknown 699s 2s/stepData is a string of length 112821
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.501/ does not exist.
#
# Skipping sample: US10299115 B2,Standard=TS 33.501.501die to empty text.
# Data is a string of length 65329
#     454/Unknown 700s 2s/stepData is a string of length 75461
#     455/Unknown 702s 2s/stepData is a string of length 94799
#     456/Unknown 703s 2s/stepData is a string of length 51589
#     457/Unknown 704s 2s/stepData is a string of length 25995
#     458/Unknown 705s 2s/stepData is a string of length 184530
#     459/Unknown 707s 2s/stepData is a string of length 68493
#     460/Unknown 708s 2s/stepData is a string of length 53807
#     461/Unknown 709s 2s/stepData is a string of length 83134
#     462/Unknown 711s 2s/stepData is a string of length 95659
#     463/Unknown 712s 2s/stepData is a string of length 102570
#     464/Unknown 713s 2s/stepData is a string of length 81061
#     465/Unknown 714s 2s/stepData is a string of length 116496
#     466/Unknown 715s 2s/stepData is a string of length 78272
#     467/Unknown 717s 2s/stepData is a string of length 79773
#     468/Unknown 720s 2s/stepData is a string of length 76929
#     469/Unknown 721s 2s/stepData is a string of length 80286
#     470/Unknown 723s 2s/stepData is a string of length 187814
#     471/Unknown 724s 2s/stepData is a string of length 66390
#     472/Unknown 725s 2s/stepData is a string of length 58359
#     473/Unknown 726s 2s/stepData is a string of length 144165
#     474/Unknown 728s 2s/stepData is a string of length 154172
#     475/Unknown 729s 2s/stepData is a string of length 49038
#     476/Unknown 730s 2s/stepData is a string of length 65253
#     477/Unknown 732s 2s/stepData is a string of length 173602
#     478/Unknown 733s 2s/stepData is a string of length 89551
#     479/Unknown 735s 2s/stepData is a string of length 88809
#     480/Unknown 736s 2s/stepData is a string of length 145506
#     481/Unknown 737s 2s/stepData is a string of length 33677
#     482/Unknown 738s 2s/stepData is a string of length 246961
#     483/Unknown 739s 2s/stepData is a string of length 90292
#     484/Unknown 741s 2s/stepData is a string of length 69701
#     485/Unknown 743s 2s/stepData is a string of length 71640
#     486/Unknown 745s 2s/stepData is a string of length 36590
#     487/Unknown 746s 2s/stepData is a string of length 107893
#     488/Unknown 747s 2s/stepData is a string of length 190690
#     489/Unknown 748s 2s/stepData is a string of length 58831
#     490/Unknown 749s 2s/stepData is a string of length 95035
#     491/Unknown 769s 2s/stepData is a string of length 55154
#     492/Unknown 770s 2s/stepData is a string of length 54145
#     493/Unknown 772s 2s/stepData is a string of length 102766
#     494/Unknown 774s 2s/stepData is a string of length 164183
#     495/Unknown 775s 2s/stepData is a string of length 67525
#     496/Unknown 777s 2s/stepData is a string of length 74118
#     497/Unknown 779s 2s/stepData is a string of length 68885
#     498/Unknown 783s 2s/stepData is a string of length 97631
#     499/Unknown 784s 2s/stepData is a string of length 98177
#     500/Unknown 785s 2s/stepData is a string of length 53380
#     501/Unknown 786s 2s/stepData is a string of length 66994
#     502/Unknown 788s 2s/stepData is a string of length 114057
#     503/Unknown 789s 2s/stepData is a string of length 156297
#     504/Unknown 790s 2s/stepData is a string of length 142562
#     505/Unknown 791s 2s/stepData is a string of length 290922
#     506/Unknown 793s 2s/stepData is a string of length 102491
#     507/Unknown 794s 2s/stepData is a string of length 230585
#     508/Unknown 796s 2s/stepData is a string of length 67172
#     509/Unknown 797s 2s/stepData is a string of length 115030
#     510/Unknown 799s 2s/stepData is a string of length 79690
#     511/Unknown 800s 2s/stepData is a string of length 115453
#     512/Unknown 801s 2s/stepData is a string of length 49521
#     513/Unknown 802s 2s/stepData is a string of length 153898
#     514/Unknown 804s 2s/stepData is a string of length 45734
#     515/Unknown 805s 2s/stepData is a string of length 82836
#     516/Unknown 806s 2s/stepData is a string of length 73743
#     517/Unknown 808s 2s/stepData is a string of length 94452
#     518/Unknown 809s 2s/stepData is a string of length 82429
#     519/Unknown 810s 2s/stepData is a string of length 143824
#     520/Unknown 811s 2s/stepData is a string of length 54105
#     521/Unknown 812s 2s/stepData is a string of length 94414
#     522/Unknown 814s 2s/stepData is a string of length 51397
#     523/Unknown 817s 2s/stepData is a string of length 58517
#     524/Unknown 818s 2s/stepData is a string of length 79581
#     525/Unknown 819s 2s/stepData is a string of length 59482
#     526/Unknown 820s 2s/stepData is a string of length 90167
#     527/Unknown 821s 2s/stepData is a string of length 122828
#     528/Unknown 823s 2s/stepData is a string of length 116734
#     529/Unknown 824s 2s/stepData is a string of length 71710
#     530/Unknown 825s 2s/stepData is a string of length 89353
#     531/Unknown 827s 2s/stepData is a string of length 52519
#     532/Unknown 828s 2s/stepData is a string of length 119670
#     533/Unknown 831s 2s/stepData is a string of length 84395
#     534/Unknown 832s 2s/stepData is a string of length 102519
#     535/Unknown 833s 2s/stepData is a string of length 212896
#     536/Unknown 834s 2s/stepData is a string of length 48546
#     537/Unknown 836s 2s/stepData is a string of length 183976
#     538/Unknown 837s 2s/stepData is a string of length 67045
#     539/Unknown 839s 2s/stepData is a string of length 139548
#     540/Unknown 840s 2s/stepData is a string of length 121852
#     541/Unknown 841s 2s/stepData is a string of length 138310
#     542/Unknown 843s 2s/stepData is a string of length 241601
#     543/Unknown 845s 2s/stepData is a string of length 110203
#     544/Unknown 847s 2s/stepData is a string of length 36964
#     545/Unknown 848s 2s/stepData is a string of length 105441
#     546/Unknown 849s 2s/stepData is a string of length 97353
#     547/Unknown 851s 2s/stepData is a string of length 33183
#     548/Unknown 854s 2s/stepData is a string of length 59120
#     549/Unknown 855s 2s/stepData is a string of length 84198
#     550/Unknown 856s 2s/stepData is a string of length 79738
#     551/Unknown 857s 2s/stepData is a string of length 47590
#     552/Unknown 858s 2s/stepData is a string of length 33804
#     553/Unknown 860s 2s/stepData is a string of length 67198
#     554/Unknown 861s 2s/stepData is a string of length 78495
#     555/Unknown 862s 2s/stepData is a string of length 66762
#     556/Unknown 864s 2s/stepData is a string of length 115300
#     557/Unknown 865s 2s/stepData is a string of length 59376
#     558/Unknown 866s 2s/stepData is a string of length 107212
#     559/Unknown 867s 2s/stepData is a string of length 46468
#     560/Unknown 868s 2s/stepData is a string of length 69959
#     561/Unknown 870s 2s/stepData is a string of length 34580
#     562/Unknown 871s 2s/stepData is a string of length 144289
#     563/Unknown 872s 2s/stepData is a string of length 196158
#     564/Unknown 873s 2s/stepData is a string of length 140077
#     565/Unknown 876s 2s/stepData is a string of length 78850
#     566/Unknown 877s 2s/stepData is a string of length 89225
#     567/Unknown 878s 2s/stepData is a string of length 83221
#     568/Unknown 879s 2s/stepData is a string of length 57749
#     569/Unknown 881s 2s/stepData is a string of length 64680
#     570/Unknown 883s 2s/stepData is a string of length 79510
#     571/Unknown 884s 2s/stepData is a string of length 55594
#     572/Unknown 885s 2s/stepData is a string of length 57665
#     573/Unknown 886s 2s/stepData is a string of length 53809
#     574/Unknown 888s 2s/stepData is a string of length 99597
#     575/Unknown 889s 2s/stepData is a string of length 65919
#     576/Unknown 890s 2s/stepData is a string of length 50603
#     577/Unknown 892s 2s/stepData is a string of length 42917
#     578/Unknown 893s 2s/stepData is a string of length 54622
#     579/Unknown 894s 2s/stepData is a string of length 158371
#     580/Unknown 895s 2s/stepData is a string of length 112952
#     581/Unknown 897s 2s/stepData is a string of length 57836
#     582/Unknown 901s 2s/stepData is a string of length 53705
#     583/Unknown 902s 2s/stepData is a string of length 59731
#     584/Unknown 903s 2s/stepData is a string of length 86154
#     585/Unknown 908s 2s/stepData is a string of length 116739
#     586/Unknown 910s 2s/stepData is a string of length 43900
#     587/Unknown 912s 2s/stepData is a string of length 76750
#     588/Unknown 913s 2s/stepData is a string of length 349919
#     589/Unknown 914s 2s/stepData is a string of length 63363
#     590/Unknown 916s 2s/stepData is a string of length 58344
#     591/Unknown 919s 2s/stepData is a string of length 100693
#     592/Unknown 920s 2s/stepData is a string of length 101993
#     593/Unknown 922s 2s/stepData is a string of length 157431
#     594/Unknown 923s 2s/stepData is a string of length 63243
#     595/Unknown 924s 2s/stepData is a string of length 120659
#     596/Unknown 925s 2s/stepData is a string of length 80896
#     597/Unknown 927s 2s/stepData is a string of length 155243
#     598/Unknown 928s 2s/stepData is a string of length 53342
#     599/Unknown 930s 2s/stepData is a string of length 58287
#     600/Unknown 931s 2s/stepData is a string of length 39972
#     601/Unknown 932s 2s/stepData is a string of length 73288
#     602/Unknown 934s 2s/stepData is a string of length 108766
#     603/Unknown 935s 2s/stepData is a string of length 128340
#     604/Unknown 936s 2s/stepData is a string of length 122505
#     605/Unknown 938s 2s/stepData is a string of length 126588
#     606/Unknown 943s 2s/stepData is a string of length 44676
#     607/Unknown 950s 2s/stepData is a string of length 61136
#     608/Unknown 951s 2s/stepData is a string of length 83946
#     609/Unknown 952s 2s/stepData is a string of length 46021
#     610/Unknown 953s 2s/stepData is a string of length 87133
#     611/Unknown 954s 2s/stepData is a string of length 178158
#     612/Unknown 956s 2s/stepData is a string of length 93128
#     613/Unknown 958s 2s/stepData is a string of length 53859
#     614/Unknown 959s 2s/stepData is a string of length 60345
#     615/Unknown 960s 2s/stepData is a string of length 60972
#     616/Unknown 961s 2s/stepData is a string of length 56055
#     617/Unknown 963s 2s/stepData is a string of length 70747
#     618/Unknown 964s 2s/stepData is a string of length 71630
#     619/Unknown 965s 2s/stepData is a string of length 89157
#     620/Unknown 966s 2s/stepData is a string of length 132233
#     621/Unknown 968s 2s/stepData is a string of length 72223
#     622/Unknown 969s 2s/stepData is a string of length 104462
#     623/Unknown 970s 2s/stepData is a string of length 57256
#     624/Unknown 972s 2s/stepData is a string of length 143776
#     625/Unknown 973s 2s/stepData is a string of length 91916
#     626/Unknown 974s 2s/stepData is a string of length 92889
#     627/Unknown 976s 2s/stepData is a string of length 53284
#     628/Unknown 977s 2s/stepData is a string of length 81703
#     629/Unknown 979s 2s/stepData is a string of length 38516
#     630/Unknown 980s 2s/stepData is a string of length 104171
#     631/Unknown 981s 2s/stepData is a string of length 42255
#     632/Unknown 982s 2s/stepData is a string of length 73689
#     633/Unknown 984s 2s/stepData is a string of length 55146
#     634/Unknown 986s 2s/stepData is a string of length 60577
#     635/Unknown 987s 2s/stepData is a string of length 63666
#     636/Unknown 990s 2s/stepData is a string of length 61483
#     637/Unknown 992s 2s/stepData is a string of length 59468
#     638/Unknown 993s 2s/stepData is a string of length 176668
#     639/Unknown 995s 2s/stepData is a string of length 77113
#     640/Unknown 996s 2s/stepData is a string of length 97497
#     641/Unknown 997s 2s/stepData is a string of length 53420
#     642/Unknown 999s 2s/stepData is a string of length 66747
#     643/Unknown 1000s 2s/stepData is a string of length 36103
#     644/Unknown 1001s 2s/stepData is a string of length 215273
#     645/Unknown 1003s 2s/stepData is a string of length 51348
#     646/Unknown 1004s 2s/stepData is a string of length 38209
#     647/Unknown 1005s 2s/stepData is a string of length 65668
#     648/Unknown 1007s 2s/stepData is a string of length 81291
#     649/Unknown 1008s 2s/stepData is a string of length 36669
#     650/Unknown 1011s 2s/stepData is a string of length 54024
#     651/Unknown 1012s 2s/stepData is a string of length 93492
#     652/Unknown 1013s 2s/stepData is a string of length 45101
#     653/Unknown 1016s 2s/stepData is a string of length 111348
#     654/Unknown 1017s 2s/stepData is a string of length 82957
#     655/Unknown 1018s 2s/stepData is a string of length 60690
#     656/Unknown 1019s 2s/stepData is a string of length 217373
#     657/Unknown 1021s 2s/stepData is a string of length 76594
#     658/Unknown 1022s 2s/stepData is a string of length 55945
#     659/Unknown 1024s 2s/stepData is a string of length 118194
#     660/Unknown 1025s 2s/stepData is a string of length 66496
#     661/Unknown 1031s 2s/stepData is a string of length 82106
#     662/Unknown 1033s 2s/stepData is a string of length 105995
#     663/Unknown 1034s 2s/stepData is a string of length 64947
#     664/Unknown 1035s 2s/stepData is a string of length 83717
#     665/Unknown 1037s 2s/stepData is a string of length 40231
#     666/Unknown 1038s 2s/stepData is a string of length 140079
#     667/Unknown 1039s 2s/stepData is a string of length 82054
#     668/Unknown 1040s 2s/stepData is a string of length 120063
#     669/Unknown 1042s 2s/stepData is a string of length 103658
#     670/Unknown 1043s 2s/stepData is a string of length 42461
#     671/Unknown 1044s 2s/stepData is a string of length 72320
#     672/Unknown 1045s 2s/stepData is a string of length 60660
#     673/Unknown 1046s 2s/stepData is a string of length 440272
#     674/Unknown 1048s 2s/stepData is a string of length 137846
#     675/Unknown 1049s 2s/stepData is a string of length 73891
#     676/Unknown 1050s 2s/stepData is a string of length 109407
#     677/Unknown 1052s 2s/stepData is a string of length 115381
#     678/Unknown 1053s 2s/stepData is a string of length 88851
#     679/Unknown 1054s 2s/stepData is a string of length 22445
#     680/Unknown 1055s 2s/stepData is a string of length 67451
#     681/Unknown 1057s 2s/stepData is a string of length 64446
#     682/Unknown 1058s 2s/stepData is a string of length 79548
#     683/Unknown 1060s 2s/stepData is a string of length 109301
#     684/Unknown 1061s 2s/stepData is a string of length 121167
#     685/Unknown 1062s 2s/stepData is a string of length 96780
#     686/Unknown 1064s 2s/stepData is a string of length 126452
#     687/Unknown 1065s 2s/stepData is a string of length 262085
#     688/Unknown 1067s 2s/stepData is a string of length 82085
#     689/Unknown 1069s 2s/stepData is a string of length 89415
#     690/Unknown 1070s 2s/stepData is a string of length 83249
#     691/Unknown 1071s 2s/stepData is a string of length 106037
#     692/Unknown 1073s 2s/stepData is a string of length 102489
#     693/Unknown 1074s 2s/stepData is a string of length 108221
#     694/Unknown 1076s 2s/stepData is a string of length 120835
#     695/Unknown 1077s 2s/stepData is a string of length 113130
#     696/Unknown 1078s 2s/stepData is a string of length 84701
#     697/Unknown 1079s 2s/stepData is a string of length 159419
#     698/Unknown 1081s 2s/stepData is a string of length 52398
#     699/Unknown 1082s 2s/stepData is a string of length 70843
#     700/Unknown 1083s 2s/stepData is a string of length 129096
#     701/Unknown 1084s 2s/stepData is a string of length 101480
#     702/Unknown 1086s 2s/stepData is a string of length 82977
#     703/Unknown 1087s 2s/stepData is a string of length 278479
#     704/Unknown 1088s 2s/stepData is a string of length 49937
#     705/Unknown 1089s 2s/stepData is a string of length 128831
#     706/Unknown 1090s 2s/stepData is a string of length 67255
#     707/Unknown 1092s 2s/stepData is a string of length 91781
#     708/Unknown 1094s 2s/stepData is a string of length 50589
#     709/Unknown 1095s 2s/stepData is a string of length 65545
#     710/Unknown 1096s 2s/stepData is a string of length 167634
#     711/Unknown 1097s 2s/stepData is a string of length 73912
#     712/Unknown 1099s 2s/stepData is a string of length 119525
#     713/Unknown 1100s 2s/stepData is a string of length 75093
#     714/Unknown 1101s 2s/stepData is a string of length 149560
#     715/Unknown 1120s 2s/stepData is a string of length 51746
#     716/Unknown 1121s 2s/stepData is a string of length 163161
#     717/Unknown 1123s 2s/stepData is a string of length 166137
#     718/Unknown 1124s 2s/stepData is a string of length 81936
#     719/Unknown 1125s 2s/stepData is a string of length 46321
#     720/Unknown 1126s 2s/stepData is a string of length 65102
#     721/Unknown 1128s 2s/stepData is a string of length 98192
#     722/Unknown 1129s 2s/stepData is a string of length 97387
#     723/Unknown 1130s 2s/stepData is a string of length 69922
#     724/Unknown 1132s 2s/stepData is a string of length 66087
#     725/Unknown 1137s 2s/stepData is a string of length 83904
#     726/Unknown 1138s 2s/stepData is a string of length 78067
#     727/Unknown 1139s 2s/stepData is a string of length 81931
#     728/Unknown 1140s 2s/stepData is a string of length 47862
#     729/Unknown 1144s 2s/stepData is a string of length 58478
#     730/Unknown 1145s 2s/stepData is a string of length 98315
#     731/Unknown 1147s 2s/stepData is a string of length 43272
#     732/Unknown 1148s 2s/stepData is a string of length 101866
#     733/Unknown 1149s 2s/stepData is a string of length 71652
#     734/Unknown 1150s 2s/stepData is a string of length 101905
#     735/Unknown 1155s 2s/stepData is a string of length 52057
#     736/Unknown 1157s 2s/stepData is a string of length 102390
#     737/Unknown 1158s 2s/stepData is a string of length 62666
#     738/Unknown 1159s 2s/stepData is a string of length 128254
#     739/Unknown 1160s 2s/stepData is a string of length 124818
#     740/Unknown 1165s 2s/stepData is a string of length 60815
#     741/Unknown 1167s 2s/stepData is a string of length 78203
#     742/Unknown 1169s 2s/stepData is a string of length 39033
#     743/Unknown 1170s 2s/stepData is a string of length 194113
#     744/Unknown 1171s 2s/stepData is a string of length 118589
#     745/Unknown 1173s 2s/stepData is a string of length 26623
#     746/Unknown 1175s 2s/stepData is a string of length 68625
#     747/Unknown 1176s 2s/stepData is a string of length 62081
# ...
#   19126/Unknown 31875s 2s/stepData is a string of length 38310
#   19127/Unknown 31876s 2s/stepData is a string of length 99202
#   19128/Unknown 31878s 2s/stepData is a string of length 104365
#   19129/Unknown 31879s 2s/stepData is a string of length 41473
#   19130/Unknown 31882s 2s/stepData is a string of length 89573
#   19131/Unknown 31883s 2s/stepData is a string of length 84190
#   19132/Unknown 31884s 2s/stepData is a string of length 87571
#   19133/Unknown 31885s 2s/stepData is a string of length 94463
#   19134/Unknown 31887s 2s/stepData is a string of length 76401
#   19135/Unknown 31888s 2s/stepData is a string of length 95622
#   19136/Unknown 31889s 2s/stepData is a string of length 96802
#   19137/Unknown 31892s 2s/stepData is a string of length 66814
#   19138/Unknown 31893s 2s/stepData is a string of length 145476
#   19139/Unknown 31894s 2s/stepData is a string of length 79551
#   19140/Unknown 31896s 2s/stepData is a string of length 109313
#   19141/Unknown 31897s 2s/stepData is a string of length 41566
#   19142/Unknown 31899s 2s/stepData is a string of length 35609
#   19143/Unknown 31900s 2s/stepData is a string of length 29959
#   19144/Unknown 31902s 2s/stepData is a string of length 60108
#   19145/Unknown 31904s 2s/stepData is a string of length 145792
#   19146/Unknown 31905s 2s/stepData is a string of length 87801
#   19147/Unknown 31911s 2s/stepData is a string of length 97349
#   19148/Unknown 31913s 2s/stepData is a string of length 73552
#   19149/Unknown 31914s 2s/stepData is a string of length 71225
#   19150/Unknown 31915s 2s/stepData is a string of length 229952
#   19151/Unknown 31916s 2s/stepData is a string of length 68539
#   19152/Unknown 31918s 2s/stepData is a string of length 117504
#   19153/Unknown 31919s 2s/stepData is a string of length 49025
#   19154/Unknown 31920s 2s/stepData is a string of length 96811
#   19155/Unknown 31921s 2s/stepData is a string of length 71599
#   19156/Unknown 31923s 2s/stepData is a string of length 60037
#   19157/Unknown 31924s 2s/stepData is a string of length 208397
#   19158/Unknown 31926s 2s/stepData is a string of length 71422
#   19159/Unknown 31927s 2s/stepData is a string of length 295993
#   19160/Unknown 31928s 2s/stepData is a string of length 69909
#   19161/Unknown 31929s 2s/stepData is a string of length 76339
#   19162/Unknown 31930s 2s/stepData is a string of length 58623
#   19163/Unknown 31932s 2s/stepData is a string of length 80033
#   19164/Unknown 31933s 2s/stepData is a string of length 184046
#   19165/Unknown 31934s 2s/stepData is a string of length 65316
#   19166/Unknown 31936s 2s/stepData is a string of length 208812
#   19167/Unknown 31937s 2s/stepData is a string of length 85994
#   19168/Unknown 31939s 2s/stepData is a string of length 43217
#   19169/Unknown 31940s 2s/stepData is a string of length 84860
#   19170/Unknown 31941s 2s/stepData is a string of length 99013
#   19171/Unknown 31943s 2s/stepData is a string of length 146932
#   19172/Unknown 31944s 2s/stepData is a string of length 98872
#   19173/Unknown 31946s 2s/stepData is a string of length 219650
#   19174/Unknown 31947s 2s/stepData is a string of length 78282
#   19175/Unknown 31948s 2s/stepData is a string of length 45439
#   19176/Unknown 31950s 2s/stepData is a string of length 140429
#   19177/Unknown 31952s 2s/stepData is a string of length 99943
#   19178/Unknown 31953s 2s/stepData is a string of length 216869
#   19179/Unknown 31954s 2s/stepData is a string of length 111270
#   19180/Unknown 31955s 2s/stepData is a string of length 56310
#   19181/Unknown 31957s 2s/stepData is a string of length 149005
#   19182/Unknown 31958s 2s/stepData is a string of length 50987
#   19183/Unknown 31960s 2s/stepData is a string of length 85866
#   19184/Unknown 31962s 2s/stepData is a string of length 44162
#   19185/Unknown 31963s 2s/stepData is a string of length 139869
#   19186/Unknown 31964s 2s/stepData is a string of length 99030
#   19187/Unknown 31966s 2s/stepData is a string of length 156849
#   19188/Unknown 31967s 2s/stepData is a string of length 83641
#   19189/Unknown 31968s 2s/stepData is a string of length 88082
#   19190/Unknown 31969s 2s/stepData is a string of length 44606
#   19191/Unknown 31976s 2s/stepData is a string of length 100649
#   19192/Unknown 31977s 2s/stepData is a string of length 166353
#   19193/Unknown 31978s 2s/stepData is a string of length 38761
#   19194/Unknown 31980s 2s/stepData is a string of length 74313
#   19195/Unknown 31981s 2s/stepData is a string of length 176393
#   19196/Unknown 31982s 2s/stepData is a string of length 49178
#   19197/Unknown 31983s 2s/stepData is a string of length 79785
#   19198/Unknown 31985s 2s/stepData is a string of length 97041
#   19199/Unknown 31986s 2s/stepData is a string of length 182428
#   19200/Unknown 31987s 2s/stepData is a string of length 124587
#   19201/Unknown 31989s 2s/stepData is a string of length 43636
#   19202/Unknown 31990s 2s/stepData is a string of length 58920
#   19203/Unknown 31992s 2s/stepData is a string of length 92027
#   19204/Unknown 31993s 2s/stepData is a string of length 68536
#   19205/Unknown 31995s 2s/stepData is a string of length 142128
#   19206/Unknown 31996s 2s/stepData is a string of length 144637
#   19207/Unknown 31998s 2s/stepData is a string of length 26515
# Standard directory /home/vignes/Patent_Files/Mount_Std/TS 33.402/ does not exist.
#
# Skipping sample: US2005003829 A1,Standard=TS 33.402.402die to empty text.
# Data is a string of length 109152
#   19208/Unknown 31999s 2s/stepData is a string of length 77657
#   19209/Unknown 32000s 2s/stepData is a string of length 146270
#   19210/Unknown 32005s 2s/stepData is a string of length 95352
#   19211/Unknown 32006s 2s/stepData is a string of length 111093
#   19212/Unknown 32008s 2s/stepData is a string of length 83592
#   19213/Unknown 32009s 2s/stepData is a string of length 82804
#   19214/Unknown 32010s 2s/stepData is a string of length 56703
#   19215/Unknown 32011s 2s/stepData is a string of length 68834
#   19216/Unknown 32013s 2s/stepData is a string of length 133417
#   19217/Unknown 32014s 2s/stepData is a string of length 70768
#   19218/Unknown 32020s 2s/stepData is a string of length 55902
#   19219/Unknown 32021s 2s/stepData is a string of length 146425
#   19220/Unknown 32022s 2s/stepData is a string of length 93536
#   19221/Unknown 32024s 2s/stepData is a string of length 79001
#   19222/Unknown 32025s 2s/stepData is a string of length 58623
#   19223/Unknown 32026s 2s/stepData is a string of length 100067
#   19224/Unknown 32027s 2s/stepData is a string of length 80007
#   19225/Unknown 32029s 2s/stepData is a string of length 99964
#   19226/Unknown 32030s 2s/stepData is a string of length 95622
#   19227/Unknown 32031s 2s/stepData is a string of length 51752
#   19228/Unknown 32033s 2s/stepData is a string of length 104610
#   19229/Unknown 32034s 2s/stepData is a string of length 51408
#   19230/Unknown 32035s 2s/stepData is a string of length 129032
#   19231/Unknown 32037s 2s/stepData is a string of length 152874
#   19232/Unknown 32038s 2s/stepData is a string of length 83549
#   19233/Unknown 32041s 2s/stepData is a string of length 79542
#   19234/Unknown 32042s 2s/stepData is a string of length 79595
#   19235/Unknown 32043s 2s/stepData is a string of length 107363
#   19236/Unknown 32045s 2s/stepData is a string of length 42060
#   19237/Unknown 32046s 2s/stepData is a string of length 59464
#   19238/Unknown 32048s 2s/stepData is a string of length 79356
#   19239/Unknown 32049s 2s/stepData is a string of length 47701
#   19240/Unknown 32050s 2s/stepData is a string of length 187814
#   19241/Unknown 32051s 2s/stepData is a string of length 68849
#   19242/Unknown 32053s 2s/stepData is a string of length 150911
#   19243/Unknown 32054s 2s/stepData is a string of length 179550
#   19244/Unknown 32056s 2s/stepData is a string of length 50136
#   19245/Unknown 32057s 2s/stepData is a string of length 81309
#   19246/Unknown 32058s 2s/stepData is a string of length 48836
#   19247/Unknown 32059s 2s/stepData is a string of length 167152
#   19248/Unknown 32061s 2s/stepData is a string of length 70892
#   19249/Unknown 32062s 2s/stepData is a string of length 146943
#   19250/Unknown 32063s 2s/stepData is a string of length 109392
#   19251/Unknown 32064s 2s/stepData is a string of length 81632
#   19252/Unknown 32066s 2s/stepData is a string of length 64887
#   19253/Unknown 32069s 2s/stepData is a string of length 92239
#   19254/Unknown 32070s 2s/stepData is a string of length 149353
#   19255/Unknown 32071s 2s/stepData is a string of length 93986
#   19256/Unknown 32073s 2s/stepData is a string of length 159890
#   19257/Unknown 32074s 2s/stepData is a string of length 47566
#   19258/Unknown 32075s 2s/stepData is a string of length 83890
#   19259/Unknown 32076s 2s/stepData is a string of length 989034
#   19260/Unknown 32077s 2s/stepData is a string of length 115144
#   19261/Unknown 32079s 2s/stepData is a string of length 55338
#   19262/Unknown 32080s 2s/stepData is a string of length 85515
#   19263/Unknown 32082s 2s/stepData is a string of length 84072
#   19264/Unknown 32083s 2s/stepData is a string of length 142761
#   19265/Unknown 32084s 2s/stepData is a string of length 97010
#   19266/Unknown 32086s 2s/stepData is a string of length 40396
#   19267/Unknown 32087s 2s/stepData is a string of length 95119
#   19268/Unknown 32088s 2s/stepData is a string of length 110003
#   19269/Unknown 32090s 2s/stepData is a string of length 247697
#   19270/Unknown 32091s 2s/stepData is a string of length 70864
#   19271/Unknown 32093s 2s/stepData is a string of length 32970
#   19272/Unknown 32094s 2s/stepData is a string of length 57400
#   19273/Unknown 32096s 2s/stepData is a string of length 98731
#   19274/Unknown 32098s 2s/stepData is a string of length 184336
#   19275/Unknown 32099s 2s/stepData is a string of length 111335
#   19276/Unknown 32101s 2s/stepData is a string of length 53578
#   19277/Unknown 32102s 2s/stepData is a string of length 40542
#   19278/Unknown 32103s 2s/stepData is a string of length 48382
#   19279/Unknown 32105s 2s/stepData is a string of length 47192
#   19280/Unknown 32106s 2s/stepData is a string of length 88114
#   19281/Unknown 32107s 2s/stepData is a string of length 61304
#   19282/Unknown 32108s 2s/stepData is a string of length 55082
#   19283/Unknown 32110s 2s/stepData is a string of length 34086
#   19284/Unknown 32111s 2s/stepData is a string of length 104664
#   19285/Unknown 32113s 2s/stepData is a string of length 76633
#   19286/Unknown 32114s 2s/stepData is a string of length 70880
#   19287/Unknown 32116s 2s/stepData is a string of length 63502
#   19288/Unknown 32117s 2s/stepData is a string of length 46614
#   19289/Unknown 32118s 2s/stepData is a string of length 83221
#   19290/Unknown 32120s 2s/stepData is a string of length 70312
#   19291/Unknown 32121s 2s/stepData is a string of length 103644
#   19292/Unknown 32122s 2s/stepData is a string of length 99892
#   19293/Unknown 32123s 2s/stepData is a string of length 64079
#   19294/Unknown 32125s 2s/stepData is a string of length 62152
#   19295/Unknown 32126s 2s/stepData is a string of length 47756
#   19296/Unknown 32127s 2s/stepData is a string of length 170127
#   19297/Unknown 32128s 2s/stepData is a string of length 36563
#   19298/Unknown 32130s 2s/stepData is a string of length 64040
#   19299/Unknown 32131s 2s/stepData is a string of length 78616
#   19300/Unknown 32132s 2s/stepData is a string of length 110128
#   19301/Unknown 32135s 2s/stepData is a string of length 99305
#   19302/Unknown 32137s 2s/stepData is a string of length 158801
#   19303/Unknown 32138s 2s/stepData is a string of length 66694
#   19304/Unknown 32140s 2s/stepData is a string of length 65095
#   19305/Unknown 32141s 2s/stepData is a string of length 69372
#   19306/Unknown 32142s 2s/stepData is a string of length 226690
#   19307/Unknown 32143s 2s/stepData is a string of length 47789
#   19308/Unknown 32145s 2s/stepData is a string of length 73477
#   19309/Unknown 32147s 2s/stepData is a string of length 106560
#   19310/Unknown 32148s 2s/stepData is a string of length 91041
#   19311/Unknown 32149s 2s/stepData is a string of length 55902
#   19312/Unknown 32150s 2s/stepData is a string of length 63531
#   19313/Unknown 32155s 2s/stepData is a string of length 42749
#   19314/Unknown 32156s 2s/stepData is a string of length 53880
#   19315/Unknown 32158s 2s/stepData is a string of length 80474
#   19316/Unknown 32160s 2s/stepData is a string of length 49405
#   19317/Unknown 32162s 2s/stepData is a string of length 93501
#   19318/Unknown 32163s 2s/stepData is a string of length 146824
#   19319/Unknown 32164s 2s/stepData is a string of length 66567
#   19320/Unknown 32166s 2s/stepData is a string of length 97298
#   19321/Unknown 32167s 2s/stepData is a string of length 99635
#   19322/Unknown 32169s 2s/stepData is a string of length 94999
#   19323/Unknown 32174s 2s/stepData is a string of length 190990
#   19324/Unknown 32175s 2s/stepData is a string of length 44570
#   19325/Unknown 32177s 2s/stepData is a string of length 52722
#   19326/Unknown 32179s 2s/stepData is a string of length 64917
#   19327/Unknown 32180s 2s/stepData is a string of length 59040
#   19328/Unknown 32181s 2s/stepData is a string of length 31016
#   19329/Unknown 32182s 2s/stepData is a string of length 38323
#   19330/Unknown 32184s 2s/stepData is a string of length 115509
#   19331/Unknown 32185s 2s/stepData is a string of length 255078
#   19332/Unknown 32186s 2s/stepData is a string of length 77070
#   19333/Unknown 32188s 2s/stepData is a string of length 141046
#   19334/Unknown 32189s 2s/stepData is a string of length 78785
#   19335/Unknown 32190s 2s/stepData is a string of length 75663
#   19336/Unknown 32191s 2s/stepData is a string of length 95068
#   19337/Unknown 32196s 2s/stepData is a string of length 44048
#   19338/Unknown 32197s 2s/stepData is a string of length 97178
#   19339/Unknown 32219s 2s/stepData is a string of length 87014
#   19340/Unknown 32220s 2s/stepData is a string of length 68081
#   19341/Unknown 32222s 2s/stepData is a string of length 95298
#   19342/Unknown 32223s 2s/stepData is a string of length 112222
#   19343/Unknown 32224s 2s/stepData is a string of length 52779
#   19344/Unknown 32225s 2s/stepData is a string of length 100510
#   19345/Unknown 32227s 2s/stepData is a string of length 116153
#   19346/Unknown 32228s 2s/stepData is a string of length 77929
#   19347/Unknown 32229s 2s/stepData is a string of length 57463
#   19348/Unknown 32231s 2s/stepData is a string of length 106402
#   19349/Unknown 32232s 2s/stepData is a string of length 112161
#   19350/Unknown 32234s 2s/stepData is a string of length 193325
#   19351/Unknown 32235s 2s/stepData is a string of length 110756
#   19352/Unknown 32236s 2s/stepData is a string of length 86085
#   19353/Unknown 32238s 2s/stepData is a string of length 71138
#   19354/Unknown 32239s 2s/stepData is a string of length 34745
#   19355/Unknown 32240s 2s/stepData is a string of length 35259
#   19356/Unknown 32241s 2s/stepData is a string of length 88257
#   19357/Unknown 32243s 2s/stepData is a string of length 129301
#   19358/Unknown 32244s 2s/stepData is a string of length 62918
#   19359/Unknown 32245s 2s/stepData is a string of length 127677
#   19360/Unknown 32246s 2s/stepData is a string of length 120124
#   19361/Unknown 32248s 2s/stepData is a string of length 39507
#   19362/Unknown 32249s 2s/stepData is a string of length 137637
#   19363/Unknown 32250s 2s/stepData is a string of length 107189
# 19365/19365 ━━━━━━━━━━━━━━━━━━━━ 32253s 2s/step
# 2024-08-04 20:58:05.739346: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-08-04 20:58:05.760426: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# /home/vignes/miniconda3/envs/patents/lib/python3.12/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)

# %%
predictions
# Out:
# array([[0.39790002],
#        [0.39790002],
#        [0.39790002],
#        ...,
#        [0.39790002],
#        [0.39790002],
#        [0.39790002]], dtype=float32)
